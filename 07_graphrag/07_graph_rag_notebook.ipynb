# %% [markdown]
# ---
# # 7. GraphRAG

# %% [markdown]
# ---
# ## 7.1. Introducción

# %% [markdown]
# ### De los RAG a los GraphRAG
#
# La generación aumentada por recuperación (RAG) es un enfoque establecido para responder preguntas de usuarios sobre colecciones privadas de documentos. Sin embargo, los RAG's están diseñados para situaciones donde las respuestas se encuentran localmente en regiones de texto, es decir, cuando la información necesaria para responder una pregunta se puede encontrar en fragmentos específicos y delimitados del texto, en lugar de estar dispersa o requerir la síntesis de múltiples partes del documento. De este modo, una vez que se han identificado y recuperado estos fragmentos relevantes de texto, éstos contienen suficiente información para que el modelo pueda generar una respuesta adecuada. Este enfoque tiene un problema muy evidente: mostrará un desempeño muy pobre en preguntas generales tales como *"¿Cuáles son los principales temas de este documento?"*
#
# En los últimos años, el campo del procesamiento del lenguaje natural (NLP) ha experimentado una transformación significativa, especialmente en lo que respecta a las tareas de resumen de texto. Tradicionalmente, se hacían distinciones claras entre diferentes tipos de resúmenes:
#
# - abstractivos vs. extractivos
# - genéricos vs. enfocados en consultas
# - de documento único vs. de múltiples documentos
#
# Sin embargo, estas categorías han perdido relevancia en la actualidad. La razón principal es el avance tecnológico en los modelos de lenguaje. Inicialmente, la arquitectura *transformer* mostró mejoras sustanciales en todas estas tareas de resumen. Pero el verdadero salto cualitativo vino con los LLMs, tales como GPT, Llama o Gemini.
#
# #### Avances en Modelos de Lenguaje
#
# Estos LLMs han simplificado enormemente las tareas de resumen. Para ello, utilizan una técnica llamada "aprendizaje en contexto". Esto significa que pueden adaptar su comprensión y generación de texto basándose en el contexto proporcionado, sin necesidad de entrenamiento adicional. En la práctica, esto implica que estos modelos pueden realizar cualquier tipo de resumen independientemente de si es abstractivo o extractivo, genérico o específico, de un solo documento o de varios. Todo lo que necesitan es que el contenido a resumir esté dentro de su "ventana de contexto", es decir, la cantidad de texto que pueden procesar de una vez.
#
# #### Problemas en Resúmenes de Grandes Corpus
#
# A pesar de estos progresos, aún existen problemas importantes a tratar. Uno de los más notables corresponde al resumen abstractivo enfocado en consultas (query-focused abstractive summarization) cuando se trata de trabajar con corpus de texto muy extensos. Podríamos decir que hay tres razones fundamentales al tratar con este tipo de resúmenes:
#
# 1. **Limitaciones de contexto en LLMs:** Los LLMs tienen una capacidad limitada para procesar texto, conocida como "ventana de contexto". Cuando se trata de resumir grandes volúmenes de texto, como corpus enteros de documentos, esta limitación se vuelve evidente.
#
# 2. **El problema de "perderse en el medio":** Incluso si se ampliara la ventana de contexto de los LLMs, surge un nuevo problema: la información puede "perderse en el medio" de contextos más largos. Esto significa que el modelo puede tener dificultades para mantener la coherencia y relevancia a lo largo de textos muy extensos.
#
# 3. **Insuficiencia del RAG tradicional:** El RAG en su forma básica, que implica recuperar fragmentos de texto directamente, no es adecuada para tareas de resumen enfocado en consultas (QFS) a gran escala. Esto se debe a que la información relevante puede estar dispersa en todo el corpus y no concentrada en fragmentos específicos.
#
# #### GraphRAG: Una Solución Innovadora
#
# Para responder a estos problemas, surge GraphRAG (Generación Aumentada por Recuperación basada en Grafos), que se fundamenta en la creación de resúmenes globales a partir del grafo de conocimiento generado por un LLM.
#
# La elección del uso de grafos de conocimiento es natural debido principalmente a dos razones:
#
# - Su modularidad. Esta propiedad se refiere a la capacidad de los grafos para organizarse naturalmente en grupos o módulos.
# - La existencia de algoritmos para la detección de comunidades, tales como Louvain o Leiden, que nos van a permitir dividir el grafo en comunidades de nodos estrechamente relacionados. Estas comunidades representan grupos de información interconectada.
#
# #### Estrategia Map-Reduce
#
# Una vez halladas estas comunidades, se utilizará un LLM para generar resúmenes de las descripciones de éstas. De esta manera, será posible realizar resúmenes enfocados en consultas de un corpus completo, empleamos una estrategia de *map-reduce*:
#
# 1. **Map:** Cada resumen de comunidad se utiliza para responder a la consulta de forma independiente y en paralelo.
#
# 2. **Reduce:** Luego, sintetizamos todas las respuestas parciales relevantes en una respuesta global final.
#
# Este método permite abordar el problema de resumir grandes volúmenes de texto de manera eficiente y efectiva, superando las limitaciones de contexto de los LLMs y aprovechando la estructura natural de la información representada en forma de grafo.

# %% [markdown]
# ### PipeLine del GraphRAG
# Ahora vamos a desglosar el flujo de datos del enfoque GraphRAG descrito en [1].
# <div style="text-align: justify;">
#
# Ahora vamos a desglosar el flujo de datos del enfoque **GraphRAG** descrito en [@graphrag2024].
#
# ### Documentos Fuente → *Text Chunks*
#
# Una decisión fundamental en el diseño de este sistema es determinar la granularidad con la que los textos extraídos de los documentos fuente deben dividirse en fragmentos para su procesamiento. Esta decisión afecta directamente a la eficiencia del sistema: fragmentos más largos requieren menos llamadas a los modelos de lenguaje, pero pueden perder precisión, mientras que fragmentos más cortos ofrecen mayor detalle pero son más costosos de procesar.
#
# ### *Text Chunks* → Instancias de Elementos
#
# En esta etapa, el objetivo es identificar y extraer nodos y aristas del grafo a partir de cada fragmento de texto. Esto se logra mediante un prompt de LLM en varias partes que identifica entidades (con nombre, tipo y descripción) y sus relaciones.
#
# Un aspecto clave es que, para mejorar la eficiencia y calidad, se implementa un sistema de “recolección” múltiple, en el que el LLM revisa si se han extraído todas las entidades posibles. Si se detectan entidades faltantes, se realiza una extracción adicional. Este enfoque permite usar fragmentos de texto más grandes sin perder calidad en la extracción.
#
# Además, se pueden extraer covariables adicionales, como afirmaciones vinculadas a las entidades detectadas, incluyendo detalles como sujeto, objeto, tipo, descripción o fechas relevantes.
#
# ### Instancias de Elementos → Resúmenes de Elementos
#
# En esta fase se utiliza un LLM para extraer descripciones de entidades, relaciones y afirmaciones representadas en los documentos. Este proceso ya es una forma de resumen abstractivo, ya que el LLM crea resúmenes significativos de conceptos que pueden estar implícitos pero no explícitamente mencionados en el texto.
#
# Para convertir todos estos resúmenes a nivel de instancia en bloques únicos de texto descriptivo para cada elemento del grafo (es decir, nodos de entidad y aristas de relación), se requiere una ronda adicional de resumen por parte del LLM sobre grupos coincidentes de instancias, es decir, aquellos que se refieren al mismo elemento o concepto en el texto fuente.
#
# ### Resúmenes de Elementos → *Graph Communities*
#
# En esta etapa, se transforman los resúmenes de elementos obtenidos en la fase anterior en una estructura de grafo. Así, el índice creado en la etapa anterior se modela como un grafo homogéneo no dirigido y ponderado. En dicho grafo:
# - **Nodos:** Representan las entidades.
# - **Aristas:** Representan las relaciones entre entidades, con un peso basado en la frecuencia normalizada de las relaciones detectadas.
#
# Además, se aplican algoritmos de detección de comunidades para dividir el grafo en grupos de nodos más fuertemente conectados entre sí que con el resto del grafo. Esto permite identificar estructuras y patrones significativos en los datos. Concretamente, se usa el algoritmo **Leiden**, que permite obtener una jerarquía de comunidades, donde cada nivel proporciona una partición que cubre todos los nodos del grafo de manera mutuamente exclusiva.
#
# Esta estructura jerárquica permite un enfoque de “divide y vencerás” para el resumen global, haciendo posible procesar y sintetizar información de grandes corpus de manera más eficiente.
#
# ### *Graph Communities* → Resúmenes de Comunidad
#
# El siguiente paso en el proceso de GraphRAG es la creación de resúmenes estructurados para cada comunidad de la jerarquía de Leiden. Este método está diseñado para ser escalable a conjuntos de datos muy grandes y nos permite:
#
# - Obtener una comprensión global de la estructura y semántica del conjunto de datos.
# - Explorar el corpus de información sin necesidad de formular preguntas específicas.
# - Facilitar la navegación temática, permitiendo explorar temas generales y profundizar en subtemas de interés.
#
# ### Generación de Resúmenes de Comunidades
#
# El proceso de generación de resúmenes se adapta según el nivel jerárquico de la comunidad.
#
# **Comunidades de Nivel Hoja**
#
# Para las comunidades en el nivel más bajo de la jerarquía:
# - *i.* Se priorizan los resúmenes de elementos (nodos, aristas y covariables) de la comunidad. La priorización sigue este orden:
#   - Se ordenan las aristas de la comunidad según la suma de los grados de sus nodos fuente y destino.
#   - Para cada arista, se añaden las descripciones del nodo fuente, nodo destino, covariables vinculadas y la propia arista.
# - *ii.* Estos resúmenes se añaden iterativamente a la ventana de contexto del LLM hasta alcanzar el límite de tokens.
#
# **Comunidades de Nivel Superior**
#
# Para las comunidades en niveles más altos de la jerarquía:
# - Si todos los resúmenes de elementos caben en la ventana de contexto, se procede como en las comunidades de nivel hoja.
# - Si no caben, se sigue este proceso:
#   - Se ordenan las subcomunidades de mayor a menor según la cantidad de tokens de sus resúmenes de elementos.
#   - Se sustituyen iterativamente los resúmenes de elementos, que son más largos, por los resúmenes de subcomunidades, de menor extensión, hasta que todo quepa en la ventana de contexto.
#
# ### Resúmenes de Comunidad → Respuestas de Comunidad → Respuesta Global
#
# La fase final del pipeline de GraphRAG se centra en la generación de una respuesta global a partir de los resúmenes de las comunidades. Este proceso se divide en tres etapas principales:
#
# 1. **Preparación de los Resúmenes de Comunidades**
#    Los resúmenes de las comunidades se reorganizan de manera aleatoria y se dividen en *chunks* de un tamaño predeterminado. Este enfoque:
#    - Asegura que la información relevante se distribuya uniformemente entre los fragmentos.
#    - Evita que información crucial se concentre en una sola ventana de contexto, lo que podría resultar en la pérdida de datos importantes.
#
# 2. **Generación de Respuestas Intermedias**
#    Para cada *chunk* de texto, se generan respuestas intermedias de forma paralela utilizando el LLM, que:
#    - Crea una respuesta basada en cada *chunk*.
#    - Asigna una puntuación de 0 a 100 a cada respuesta, indicando su relevancia para la pregunta del usuario.
#    - Filtra y elimina las respuestas con puntuación 0, consideradas no relevantes.
#
# 3. **Síntesis de la Respuesta Global**
#    Finalmente, se construye la respuesta global mediante un proceso de reducción:
#    - Las respuestas intermedias se ordenan de mayor a menor según su puntuación de relevancia.
#    - Se van añadiendo a una nueva ventana de contexto hasta alcanzar el límite de tokens establecido.
#    - Utilizando este contexto final, se genera la respuesta global que se presentará al usuario.
#
# Así, este enfoque multietapa permite a GraphRAG proporcionar respuestas más completas y contextualizadas, aprovechando la estructura de conocimiento generada en las fases anteriores del pipeline. En la [Figura 1](#fig-pipeline), se muestra un resumen gráfico del proceso descrito.
#
# ![Representación Gráfica del Pipeline usado en el enfoque GraphRAG](../Figures/pipeline.png)
#
# </div>

# %% [markdown]
# Para indexar los documentos se ha seguido un proceso de inicialización y configuración que permite poner en marcha el sistema GraphRAG. En primer lugar, se instaló la librería de Python **graphrag** con el comando:
#
# ```bash
# pip install graphrag
# ```
# A continuación, se preparó el entorno creando un directorio de trabajo (por ejemplo, `./ragtest/input`) y se descargó el libro *A Christmas Carol* de Charles Dickens  Luego, se inicializó el espacio de trabajo ejecutando:
#
# ```bash
# graphrag init --root ./ragtest
# ```
#
# Este comando crea dos archivos importantes en el directorio `./ragtest`:
# - **.env**: Contiene las variables de entorno necesarias para ejecutar el pipeline, incluyendo `GRAPHRAG_API_KEY`, que debe sustituirse por tu clave de API de OpenAI o Azure OpenAI.
# - **settings.yaml**: Define la configuración del pipeline, permitiendo ajustar parámetros como el modelo LLM, el tamaño de los fragmentos de texto y otros aspectos del procesamiento.
#
# Una vez configurado el entorno, se ejecuta el pipeline de indexación con:
#
# ```bash
# graphrag index --root ./ragtest
# ```
# Este proceso indexa el documento y genera una serie de archivos Parquet en el directorio `./ragtest/output`, que contienen la información estructurada y enriquecida del texto. Con estos datos, es posible realizar consultas sobre el contenido indexado para responder preguntas específicas o extraer insights a un nivel global.
#
# En resumen, este procedimiento transforma el libro *A Christmas Carol* en una base de conocimiento estructurada y accesible, lista para ser consultada mediante el motor de búsqueda de GraphRAG.

# %% [markdown]
# ---
# ## 7.2. Importación de los documentos resultantes de la indexación

# %%
import os

import pandas as pd
import tiktoken
import numpy as np

from graphrag.query.context_builder.entity_extraction import EntityVectorStoreKey
from graphrag.query.indexer_adapters import (
    read_indexer_covariates,
    read_indexer_entities,
    read_indexer_relationships,
    read_indexer_reports,
    read_indexer_text_units,
)
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.embedding import OpenAIEmbedding
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.local_search.mixed_context import (
    LocalSearchMixedContext,
)
from graphrag.query.structured_search.local_search.search import LocalSearch
from graphrag.vector_stores.lancedb import LanceDBVectorStore


from typing import cast

# %% [markdown]
# <div style="text-align: justify;">
#
# En este fragmento de código se establecen parámetros fundamentales que definirán cómo se gestionará el flujo de datos en nuestro sistema. Primero, se definen las rutas para los directorios de entrada y salida mediante las variables `INPUT_DIR` y `OUTPUT_DIR`, respectivamente. Esto nos permite centralizar y organizar los archivos de datos y resultados, lo que es clave para mantener un flujo de trabajo ordenado y reproducible.
#
# A continuación, se configura la variable `LANCEDB_URI` a partir del directorio de salida, apuntando a la ubicación donde se almacenarán los datos transformados y el índice generado. Este URI es fundamental para la integración con LanceDB, la base de datos utilizada para gestionar y consultar eficientemente nuestros datos.
#
# El resto de las variables definen los nombres de las tablas que se crearán durante el proceso de indexación y generación del modelo de conocimiento. Cada una de estas variables —como `COMMUNITY_REPORT_TABLE`, `ENTITY_TABLE`, `ENTITY_EMBEDDING_TABLE`, `RELATIONSHIP_TABLE`, `COVARIATE_TABLE` y `TEXT_UNIT_TABLE`— representa una colección específica de datos. Por ejemplo, la tabla de reportes de comunidades (`COMMUNITY_REPORT_TABLE`) contendrá los resúmenes finales de las comunidades detectadas, mientras que `ENTITY_TABLE` y `ENTITY_EMBEDDING_TABLE` se encargarán de almacenar, respectivamente, los nodos finales y sus representaciones vectoriales. Estas definiciones facilitan la alineación de los datos transformados con el modelo de conocimiento que estamos implementando.
#
# Finalmente, la variable `COMMUNITY_LEVEL` se utiliza para especificar el nivel de la jerarquía de comunidades que se empleará en el proceso de resumen y análisis. Esta configuración es esencial, ya que determina la granularidad con la que se agruparán y resumirán los datos.
#
# En resumen, este bloque inicial establece la estructura de directorios y las convenciones de nomenclatura que serán utilizadas a lo largo del pipeline, permitiéndonos cargar los outputs de indexación (por ejemplo, desde archivos parquet a dataframes) y, posteriormente, convertir dichos dataframes en colecciones de objetos de datos que se alinean con nuestro modelo de conocimiento. Esto sienta las bases para un procesamiento de datos coherente y escalable a lo largo del proyecto.
#
# </div>

# %% [markdown]
# ### Carga de los datos en DataFrames

# %%
INPUT_DIR = "input"
OUTPUT_DIR = "output"

LANCEDB_URI = f"{OUTPUT_DIR}/lancedb"

COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
RELATIONSHIP_TABLE = "create_final_relationships"
COVARIATE_TABLE = "create_final_covariates"
TEXT_UNIT_TABLE = "create_final_text_units"
COMMUNITY_LEVEL = 2

# %% [markdown]
# #### Lectura de entidades

# %% [markdown]
# <div style="text-align: justify;">
#
#
# Posteriormente, se lee la tabla de nodos (entidades) a partir de un archivo Parquet, utilizando la función `pd.read_parquet`. Esta tabla contiene información sobre cada nodo, como a qué comunidad pertenece y el grado del nodo, lo que es crucial para el análisis estructural del grafo.
#
# Una vez leída la tabla, se procede a reemplazar los valores `NaN` por `None` mediante el método `replace` de pandas, utilizando la función de numpy para detectar los valores nulos. Este paso es importante para unificar el tratamiento de los valores faltantes, facilitando así su manipulación en pasos posteriores del pipeline.
#
# A continuación, se lee otra tabla, que contiene los embeddings de las entidades, también desde un archivo Parquet. Esta tabla proporciona una representación vectorial de cada nodo, lo cual es fundamental para calcular similitudes y realizar operaciones de clustering o agrupamiento en el grafo.
#
# Es importante destacar que, en la segunda asignación, se utiliza nuevamente el método `replace` para sustituir los valores `NaN` por `None`.
#
# En resumen, este bloque de código carga y limpia los datos correspondientes a las entidades y sus embeddings.
#
# Después, hacemos lo propio con las relaciones.
#
# </div>

# %%
import pandas as pd
import numpy as np
# read nodes table to get community and degree data
entity_df = pd.read_parquet(f"{OUTPUT_DIR}/{ENTITY_TABLE}.parquet")
entity_df = entity_df.replace({np.nan: None})

entity_embedding_df = pd.read_parquet(f"{OUTPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")
entity_embedding_df = entity_df.replace({np.nan: None})

# %%
#pd.set_option('display.max_rows', None)
#pd.set_option('display.max_columns', None)
#pd.set_option('display.width', None)
#pd.set_option('display.max_colwidth', None)
entity_df
# Out:
#                                     id  human_readable_id  \
# 0     4f370d7f0d734f92b6118d88e79d886a                  0
# 1     8e5be5b1e63343b8a2f0af6baba70337                  1
# 2     73b0e0a551dc454690bad3d6756912be                  2
# 7     cf70df771d6c464e93b7ff99d2ea8142                  3
# 12    3dfdd81803b74b3a8d3244af70df4f83                  4
# ...                                ...                ...
# 1681  9efdb8d321d5445e9dfea1fa29a1b173                209
# 1682  c4e8ca318c6046a58ed833be1aa86732                210
# 1683  ea84881a96d644c5884e6675ee1ff591                211
# 1684  3ce8510deb354206b7dbcbd0f7b0d8b8                212
# 1685  1351e738a2d84f7cbf27734dd86ec10b                213
#
#                      title  community  level  degree          x         y
# 0        PROJECT GUTENBERG          8      0       7  -1.930967  17.19829
# 1            UNITED STATES          8      0       2  19.662577  8.599833
# 2        A CHRISTMAS CAROL          0      0       8 -11.451687   2.69545
# 7          CHARLES DICKENS          0      0       1 -12.506288   1.64068
# 12          ARTHUR RACKHAM          0      0       1 -11.712614  2.434599
# ...                    ...        ...    ...     ...        ...       ...
# 1681  SCROOGE AND MARLEY'S         38      4       2   14.64785  1.287843
# 1682  THE PORTLY GENTLEMAN         38      4       2  16.623621  2.794902
# 1683               THE BOY         37      4       1   8.075386 -3.995178
# 1684                OFFICE         37      4       2  14.349295   1.01974
# 1685        NEPHEW'S HOUSE         37      4       1  15.178712  1.686115
#
# [649 rows x 8 columns]

# %% [markdown]
# #### Lectura de relaciones

# %%
relationship_df = pd.read_parquet(f"{OUTPUT_DIR}/{RELATIONSHIP_TABLE}.parquet")

# Para relationship_df
relationship_df = relationship_df.replace({np.nan: None})

titles = entity_df['title'].tolist()

# Filtramos el DataFrame de relaciones
relationship_df = relationship_df[
    relationship_df['source'].isin(titles) & 
    relationship_df['target'].isin(titles)
]
relationship_df
# Out:
#                                    id  human_readable_id  \
# 0    27f628f3ac9e44cfb4fba4efb6104d88                  0
# 1    40c306c8012c4f499359a608dcb020e7                  1
# 2    74294f1a9ee947d8879a245e1c19d5e8                  2
# 3    e74897d5b27a48cdbc346676663a269a                  3
# 4    348a412fd97a40aea938af6e5f34d0d9                  4
# ..                                ...                ...
# 313  e5446a8a991640f1bfb33a18489be572                313
# 314  a7b558f7b329426dade7b8cd6d471da0                314
# 315  a27982d1672a40fa9d27e61af39c9119                315
# 316  a60835b9d9eb45d3a6d0fbecd1176718                316
# 317  f6f1a2438b5543efb7b8dbc64d99b581                317
#
#                        source                                         target  \
# 0           PROJECT GUTENBERG                              A CHRISTMAS CAROL
# 1           PROJECT GUTENBERG                                  UNITED STATES
# 2           PROJECT GUTENBERG  PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION
# 3           PROJECT GUTENBERG                              WWW.GUTENBERG.ORG
# 4           PROJECT GUTENBERG                                MICHAEL S. HART
# ..                        ...                                            ...
# 313        PROJECT GUTENBERG™                                      INDEMNITY
# 314  INTERNAL REVENUE SERVICE                                     FOUNDATION
# 315               MISSISSIPPI                                     FOUNDATION
# 316            SALT LAKE CITY                                     FOUNDATION
# 317                      U.S.                                     FOUNDATION
#
#                                            description  weight  \
# 0    Project Gutenberg released the eBook version o...     1.0
# 1    Project Gutenberg, a collection of individual ...     2.0
# 2    The Project Gutenberg Literary Archive Foundat...    19.0
# 3    Project Gutenberg's works are posted and can b...     1.0
# 4    Michael S. Hart was the originator of the Proj...     1.0
# ..                                                 ...     ...
# 313  Project Gutenberg™ has an Indemnity policy for...     8.0
# 314  The Foundation has been granted tax exempt sta...     7.0
# 315  The Foundation is organized under the laws of ...     6.0
# 316  The business office of the Foundation is locat...     5.0
# 317                The Foundation operates in the U.S.     1.0
#
#      combined_degree                                      text_unit_ids
# 0                 15                 [d6583840046247f428a9f02738842a7c]
# 1                  9  [2b5ecb7fba1301d1f3d307e194a6c435, aa8d2310a20...
# 2                 15  [aa8d2310a206001404282ddb3fd645aa, cd4234ed6ca...
# 3                  8                 [aa8d2310a206001404282ddb3fd645aa]
# 4                  8                 [cd4234ed6caba8f15d09a2e3ee604b2a]
# ..               ...                                                ...
# 313                7                 [0ddc17ea5e566006c000b4013f2181a5]
# 314                7                 [cd4234ed6caba8f15d09a2e3ee604b2a]
# 315                7                 [cd4234ed6caba8f15d09a2e3ee604b2a]
# 316                7                 [cd4234ed6caba8f15d09a2e3ee604b2a]
# 317                6                 [cd4234ed6caba8f15d09a2e3ee604b2a]
#
# [318 rows x 8 columns]

# %%
pd.set_option('display.max_colwidth', None)

relationship_df["description"].iloc[10]
# Out:
# 'J. B. Lippincott Company is the original publisher of A Christmas Carol'

# %%
## Tiene el mismo contenido que relationship_df, pero organizado de otra manera
relationships = read_indexer_relationships(relationship_df)
relationships
# Out:
# [Relationship(id='27f628f3ac9e44cfb4fba4efb6104d88', short_id='0', source='PROJECT GUTENBERG', target='A CHRISTMAS CAROL', weight=1.0, description='Project Gutenberg released the eBook version of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=15, attributes=None),
#  Relationship(id='40c306c8012c4f499359a608dcb020e7', short_id='1', source='PROJECT GUTENBERG', target='UNITED STATES', weight=2.0, description='Project Gutenberg, a collection of individual works, is predominantly composed of materials that are in the public domain in the United States. This means that the works within Project Gutenberg are not protected by copyright law in the United States.', description_embedding=None, text_unit_ids=['2b5ecb7fba1301d1f3d307e194a6c435', 'aa8d2310a206001404282ddb3fd645aa'], rank=9, attributes=None),
#  Relationship(id='74294f1a9ee947d8879a245e1c19d5e8', short_id='2', source='PROJECT GUTENBERG', target='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', weight=19.0, description='The Project Gutenberg Literary Archive Foundation, which owns a compilation copyright in the collection of Project Gutenberg electronic works, was created to provide a secure and permanent future for Project Gutenberg.', description_embedding=None, text_unit_ids=['aa8d2310a206001404282ddb3fd645aa', 'cd4234ed6caba8f15d09a2e3ee604b2a'], rank=15, attributes=None),
#  Relationship(id='e74897d5b27a48cdbc346676663a269a', short_id='3', source='PROJECT GUTENBERG', target='WWW.GUTENBERG.ORG', weight=1.0, description="Project Gutenberg's works are posted and can be accessed on www.gutenberg.org.", description_embedding=None, text_unit_ids=['aa8d2310a206001404282ddb3fd645aa'], rank=8, attributes=None),
#  Relationship(id='348a412fd97a40aea938af6e5f34d0d9', short_id='4', source='PROJECT GUTENBERG', target='MICHAEL S. HART', weight=1.0, description='Michael S. Hart was the originator of the Project Gutenberg concept', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=8, attributes=None),
#  Relationship(id='b4503b731f2c4225adb0ce4483a9186d', short_id='5', source='PROJECT GUTENBERG', target='FOUNDATION', weight=9.0, description='The Foundation was created to provide a secure and permanent future for Project Gutenberg', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=12, attributes=None),
#  Relationship(id='4928c7ad1165494292a39b0eed069dc4', short_id='6', source='PROJECT GUTENBERG', target='PROFESSOR MICHAEL S. HART', weight=8.0, description='Professor Michael S. Hart was the originator of the Project Gutenberg concept', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=8, attributes=None),
#  Relationship(id='ac347464a74f478b89a18d997307ce00', short_id='7', source='UNITED STATES', target='SCROOGE', weight=1.0, description="Scrooge's financial dealings are compared to a United States security", description_embedding=None, text_unit_ids=['8435b078474636a989a8c22f5493e1b6'], rank=125, attributes=None),
#  Relationship(id='2a238fb19702455ea908bc7f6cb646ba', short_id='8', source='A CHRISTMAS CAROL', target='CHARLES DICKENS', weight=10.0, description='Charles Dickens is the author of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='7ce4b0c4ced84a5cbfb5d689b76dd463', short_id='9', source='A CHRISTMAS CAROL', target='ARTHUR RACKHAM', weight=10.0, description='Arthur Rackham is the illustrator of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='6b62957820284e01b5dddab42da62c14', short_id='10', source='A CHRISTMAS CAROL', target='J. B. LIPPINCOTT COMPANY', weight=10.0, description='J. B. Lippincott Company is the original publisher of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='f04cb909b8264316956780a5aff3e7ab', short_id='11', source='A CHRISTMAS CAROL', target='SUZANNE SHELL', weight=10.0, description='Suzanne Shell is a producer of the eBook version of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='520e5b61d354470da4057726eb3c2e55', short_id='12', source='A CHRISTMAS CAROL', target='JANET BLENKINSHIP', weight=10.0, description='Janet Blenkinship is a producer of the eBook version of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='c1e5881730ca4132a03d6ca9be155fbd', short_id='13', source='A CHRISTMAS CAROL', target='ONLINE DISTRIBUTED PROOFREADING TEAM', weight=10.0, description='The Online Distributed Proofreading Team helped produce the eBook version of A Christmas Carol', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=9, attributes=None),
#  Relationship(id='ad0b90d08e2f48d8856e0cc5ce720a53', short_id='14', source='A CHRISTMAS CAROL', target='SCROOGE', weight=1.0, description='Scrooge is the main character in A Christmas Carol who changes his ways', description_embedding=None, text_unit_ids=['2b5ecb7fba1301d1f3d307e194a6c435'], rank=131, attributes=None),
#  Relationship(id='86eecbc0e64d44d8a9f161e6c7d9e528', short_id='15', source='PETER CRATCHIT', target='BOB CRATCHIT', weight=20.0, description='Peter Cratchit is the son of Bob Cratchit.', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae', 'd6583840046247f428a9f02738842a7c'], rank=25, attributes=None),
#  Relationship(id='baabb058259b4ea983f6258f459de0f2', short_id='16', source='PETER CRATCHIT', target='MRS. CRATCHIT', weight=10.0, description='Peter Cratchit is the son of Mrs. Cratchit', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=17, attributes=None),
#  Relationship(id='f900b22bd4904e8896d26ca35a42f5c9', short_id='17', source='PETER CRATCHIT', target='CHRISTMAS DAY', weight=5.0, description='The story of Peter Cratchit takes place on Christmas Day', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=10, attributes=None),
#  Relationship(id='7661c462c78b48be9f9d9f6a4b94147e', short_id='18', source='TIM CRATCHIT', target='BOB CRATCHIT', weight=10.0, description='Tim Cratchit is the youngest son of Bob Cratchit', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=23, attributes=None),
#  Relationship(id='c115f823d8cb4060a09352bd9d912bae', short_id='19', source='MR. FEZZIWIG', target='MRS. FEZZIWIG', weight=1.0, description='Mrs. Fezziwig is the wife of Mr. Fezziwig', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=5, attributes=None),
#  Relationship(id='cc2cdab573904a9cb0efb55df3d93eef', short_id='20', source='FRED', target='EBENEZER SCROOGE', weight=10.0, description="Fred is Scrooge's nephew", description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=19, attributes=None),
#  Relationship(id='bbd1bb9e7bca472e80b37960694a882f', short_id='21', source='FRED', target='SCROOGE', weight=16.0, description="Scrooge is Fred's uncle, a relationship confirmed by Scrooge's own statement. They share a close bond, often spending time together. This includes visiting for dinner and engaging in playful activities such as games.", description_embedding=None, text_unit_ids=['04e5c071e4ee5496d5380662e1339f45', '10730234d6ccc7cee08f3cfc58d8a9a1', '61a042016835080f3d334560b13b0e35'], rank=130, attributes=None),
#  Relationship(id='14579249ca8e4359a66c730891e864ef', short_id='22', source='FRED', target='UNCLE SCROOGE', weight=5.0, description='Fred refers to Scrooge as Uncle Scrooge', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=9, attributes=None),
#  Relationship(id='e4a8196deda141668299e353a285df68', short_id='23', source='FRED', target='THE PLUMP SISTER', weight=6.0, description='Fred is playing a game with the plump sister', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=12, attributes=None),
#  Relationship(id='4bd2822388b34ec8ba9e30a341d15366', short_id='24', source='FRED', target='CHRISTMAS', weight=4.0, description='Fred is celebrating Christmas in the text', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=16, attributes=None),
#  Relationship(id='d2ec050a506c476b97f2d85692a1bb69', short_id='25', source='FRED', target='YES AND NO', weight=7.0, description='Fred is playing the game Yes and No with the others', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=10, attributes=None),
#  Relationship(id='07db3cf4430d44dcb25c2bea515b3806', short_id='26', source='FRED', target='MULLED WINE', weight=6.0, description='Fred proposes a toast to Uncle Scrooge with the mulled wine', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=9, attributes=None),
#  Relationship(id='059f09b2659a4f729fd754c41750d5d3', short_id='27', source='GHOST OF CHRISTMAS PAST', target='SCROOGE', weight=19.0, description="The Ghost of Christmas Past visits Scrooge, showing him scenes from his past Christmases. This spectral entity's purpose is to provide Scrooge with a glimpse into his own history, allowing him to reflect on his past actions and decisions.", description_embedding=None, text_unit_ids=['3763b08136628f77304cb4eb1136ea48', '4cf4deeb7f61acb7b7db4ce0e57fb1e6'], rank=124, attributes=None),
#  Relationship(id='7d2d86bc935649748c39ddb4941e4be2', short_id='28', source='GHOST OF CHRISTMAS PRESENT', target='SCROOGE', weight=27.0, description='The Ghost of Christmas Present visits Scrooge to provide him with a glimpse into the present Christmas. This spectral entity guides Scrooge through scenes from his current life, specifically focusing on events occurring during the current Christmas season.', description_embedding=None, text_unit_ids=['0f9b4e5a7cfc0c3c89a8898a45383588', '4cf4deeb7f61acb7b7db4ce0e57fb1e6', '77ae3762a0b062ca5350ea54a05450ae'], rank=124, attributes=None),
#  Relationship(id='c4f45971c22c472e8375f4f6d3c05799', short_id='29', source='GHOST OF CHRISTMAS YET TO COME', target='SCROOGE', weight=18.0, description="The Ghost of Christmas Yet to Come, also known as the Spirit, is a spectral entity that plays a significant role in Scrooge's life. This ghost is responsible for showing Scrooge visions of the future, providing him with a glimpse into what lies ahead.", description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d', '98f3970b31dfa1d7391cdaa453d6ade7'], rank=124, attributes=None),
#  Relationship(id='a71e256151f64f588f6d0b073a531c5b', short_id='30', source='GHOST OF JACOB MARLEY', target='EBENEZER SCROOGE', weight=10.0, description="The Ghost of Jacob Marley is a spectre of Scrooge's former partner in business", description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=14, attributes=None),
#  Relationship(id='bdb536fca4424dee8e8fa28c6103a165', short_id='31', source='GHOST OF JACOB MARLEY', target='SCROOGE', weight=10.0, description='The ghost of Jacob Marley visits Scrooge', description_embedding=None, text_unit_ids=['0f9b4e5a7cfc0c3c89a8898a45383588'], rank=125, attributes=None),
#  Relationship(id='5690b7ae4b5c4ad9b8a403eb458de263', short_id='32', source='EBENEZER SCROOGE', target='BOB CRATCHIT', weight=10.0, description='Bob Cratchit is a clerk to Ebenezer Scrooge', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=34, attributes=None),
#  Relationship(id='3528c2ba352847be9b9b06c1756bb7a1', short_id='33', source='EBENEZER SCROOGE', target='DICK WILKINS', weight=17.0, description="Ebenezer Scrooge and Dick Wilkins are fellow apprentices. They work together under the same employer, Fezziwig. Dick Wilkins is specifically identified as a fellow apprentice of Scrooge's, indicating a close working relationship between the two.", description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d', 'd6583840046247f428a9f02738842a7c'], rank=15, attributes=None),
#  Relationship(id='fcf4d46f529e4e47a3a4af65761fd197', short_id='34', source='EBENEZER SCROOGE', target='BELLE', weight=10.0, description="Belle is an old sweetheart of Scrooge's", description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=15, attributes=None),
#  Relationship(id='293333ff826345d4829269755c461c6c', short_id='35', source='EBENEZER SCROOGE', target='CAROLINE', weight=10.0, description="Caroline is the wife of one of Scrooge's debtors", description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=17, attributes=None),
#  Relationship(id='9114fce3a9e945aa8e7ded44b868d392', short_id='36', source='EBENEZER SCROOGE', target='FAN', weight=10.0, description='Fan is the sister of Scrooge', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=15, attributes=None),
#  Relationship(id='0f7af7b7a6ed4c94ae7c272e2e339fb2', short_id='37', source='EBENEZER SCROOGE', target='JACOB MARLEY', weight=8.0, description='Jacob Marley visits Ebenezer Scrooge to warn him about his life choices', description_embedding=None, text_unit_ids=['e3bef9514042131cf477476725497416'], rank=14, attributes=None),
#  Relationship(id='2929c3e4ebe948e0b35110aea982a439', short_id='38', source='EBENEZER SCROOGE', target='THE GHOST', weight=1.0, description='The Ghost, who is Jacob Marley, visits Ebenezer Scrooge to warn him about his life choices', description_embedding=None, text_unit_ids=['e3bef9514042131cf477476725497416'], rank=25, attributes=None),
#  Relationship(id='70e29d3722244902aa91d5dc91935dd1', short_id='39', source='EBENEZER SCROOGE', target='FEZZIWIG', weight=8.0, description='Fezziwig is the employer of Ebenezer Scrooge', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=23, attributes=None),
#  Relationship(id='b3a2be1c9a61439985448661a2c2bdbb', short_id='40', source='EBENEZER SCROOGE', target='CHRISTMAS EVE PARTY', weight=6.0, description='Ebenezer Scrooge is a guest at the Christmas Eve party', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=24, attributes=None),
#  Relationship(id='6b862dff33d94d6cb19e1d0cfd98e44b', short_id='41', source='EBENEZER SCROOGE', target='SCROOGE', weight=1.0, description='Scrooge and Ebenezer Scrooge are the same person', description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d'], rank=135, attributes=None),
#  Relationship(id='dad3599e319544c9914ea474ed78da40', short_id='42', source='DICK WILKINS', target='FEZZIWIG', weight=8.0, description='Fezziwig is the employer of Dick Wilkins', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=14, attributes=None),
#  Relationship(id='3f32481292964deb90d5efcb5a6a47d7', short_id='43', source='DICK WILKINS', target='CHRISTMAS EVE PARTY', weight=6.0, description='Dick Wilkins is a guest at the Christmas Eve party', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=15, attributes=None),
#  Relationship(id='7d03862b31a046b9aef3edb97051a48c', short_id='44', source='BELLE', target='SCROOGE', weight=3.0, description="Belle is mentioned as an old friend of Scrooge's by her husband", description_embedding=None, text_unit_ids=['c79e67fc6f74a9afbe79c158000cc71b'], rank=126, attributes=None),
#  Relationship(id='2bf8bfae60f44041ab408ec594ec83b8', short_id='45', source='BELLE', target='THE HUSBAND', weight=10.0, description='The husband and Belle are married', description_embedding=None, text_unit_ids=['c79e67fc6f74a9afbe79c158000cc71b'], rank=5, attributes=None),
#  Relationship(id='399068a990bb4a8ba69c50abc7415313', short_id='46', source='CAROLINE', target="CAROLINE'S HUSBAND", weight=9.0, description='Caroline and her husband are in a relationship and discuss their financial situation together', description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=9, attributes=None),
#  Relationship(id='41df0cb418694bbc850eba6c0ff7acc1', short_id='47', source='CAROLINE', target='HALF-DRUNKEN WOMAN', weight=2.0, description='The half-drunken woman is mentioned in a conversation between Caroline and her husband', description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=7, attributes=None),
#  Relationship(id='1c08d6e34086461aa42a1c544bd3d7b5', short_id='48', source='CAROLINE', target='DEATH', weight=8.0, description="Caroline is relieved by the man's death as it alleviates her debt", description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=9, attributes=None),
#  Relationship(id='4db158f4f9c54f9598a515a3d3a0ec5e', short_id='49', source='CAROLINE', target='THE MAN', weight=9.0, description="The man's death has a direct impact on Caroline's financial situation", description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=7, attributes=None),
#  Relationship(id='00b1ff2d90bf428ba03987884cef56f4', short_id='50', source='MRS. CRATCHIT', target='BOB CRATCHIT', weight=49.0, description="Bob Cratchit and Mrs. Cratchit are husband and wife, both part of the same family, the Cratchits. They work together, particularly in preparing the Christmas meal. Mrs. Cratchit is identified as Bob Cratchit's wife.", description_embedding=None, text_unit_ids=['1bdf253855a115bcf51faa63d7b07e82', '29793cee69d4eefd5fea8a5f2f27b521', '5d70b47bf7167b7586f47fcc4355a746', 'b4dec8fbe9f2a2c6a79d09c9484d15ae', 'd6583840046247f428a9f02738842a7c', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=36, attributes=None),
#  Relationship(id='547c0472f05a4c0cb381e3f513eb606e', short_id='51', source='MRS. CRATCHIT', target='BELINDA CRATCHIT', weight=10.0, description='Belinda Cratchit is the daughter of Mrs. Cratchit', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=17, attributes=None),
#  Relationship(id='25c2910bc533492a8e8c38beeeb578c5', short_id='52', source='MRS. CRATCHIT', target='TINY TIM', weight=48.0, description="Mrs. Cratchit and Tiny Tim are part of the same family, known as the Cratchits. They work together to prepare the Christmas meal. Mrs. Cratchit is Tiny Tim's mother, and Tiny Tim is her son.", description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d', '1bdf253855a115bcf51faa63d7b07e82', '5d70b47bf7167b7586f47fcc4355a746', 'b4dec8fbe9f2a2c6a79d09c9484d15ae', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=23, attributes=None),
#  Relationship(id='4c79f843731f43dca49d96e3ee048b4a', short_id='53', source='MRS. CRATCHIT', target='MARTHA', weight=18.0, description='Martha is the daughter of Mrs. Cratchit. They are part of the same family and work together to prepare the Christmas meal.', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746', 'b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=19, attributes=None),
#  Relationship(id='050334a272a047b989e287c026533fb0', short_id='54', source='MRS. CRATCHIT', target='CHRISTMAS DAY', weight=5.0, description='The story of Mrs. Cratchit takes place on Christmas Day', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=21, attributes=None),
#  Relationship(id='2be9804fc04b4b6f88ce08c4949d30a9', short_id='55', source='MRS. CRATCHIT', target='MASTER PETER', weight=8.0, description='Mrs. Cratchit and Master Peter are part of the same family and work together to prepare the Christmas meal', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746'], rank=18, attributes=None),
#  Relationship(id='c2cc41e7fe26455bb4e3a5cc85c2803e', short_id='56', source='MRS. CRATCHIT', target='MISS BELINDA', weight=8.0, description='Mrs. Cratchit and Miss Belinda are part of the same family and work together to prepare the Christmas meal', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746'], rank=16, attributes=None),
#  Relationship(id='f879beb2ad6a4d589b3b5c837ba9fcad', short_id='57', source='MRS. CRATCHIT', target='THE TWO YOUNG CRATCHITS', weight=8.0, description='Mrs. Cratchit and the two young Cratchits are part of the same family and work together to prepare the Christmas meal', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746'], rank=16, attributes=None),
#  Relationship(id='8a8f8a6e52d84de0a744f25a86812104', short_id='58', source='MRS. CRATCHIT', target='CHRISTMAS MEAL', weight=9.0, description='Mrs. Cratchit is responsible for the preparation of the Christmas meal', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746'], rank=21, attributes=None),
#  Relationship(id='6d036c2276714c2fbcf71763af217140', short_id='59', source='MRS. CRATCHIT', target='SCROOGE', weight=7.0, description="Mrs. Cratchit and Scrooge have an indirect connection through Bob Cratchit, who is Scrooge's employee and Mrs. Cratchit's husband. However, their relationship is marked by negativity as Mrs. Cratchit has expressed disdain for Scrooge.", description_embedding=None, text_unit_ids=['1bdf253855a115bcf51faa63d7b07e82', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=137, attributes=None),
#  Relationship(id='4cb57bb434374823aaae0c8c80467e98', short_id='60', source='MRS. CRATCHIT', target='PETER', weight=20.0, description='Mrs. Cratchit is the mother of Peter, who is her son.', description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=21, attributes=None),
#  Relationship(id='7f5fed3cb7644cb1bbdb368bc60db2be', short_id='61', source='MRS. CRATCHIT', target='THE GHOST', weight=3.0, description="The Ghost shows Scrooge a scene from Mrs. Cratchit's house.", description_embedding=None, text_unit_ids=['f40e4b274b5e1a25afbff9ecb733e1f4'], rank=27, attributes=None),
#  Relationship(id='e440ea1af916453c8b4392b919357452', short_id='62', source='MRS. CRATCHIT', target='BOB', weight=10.0, description="Bob is Mrs. Cratchit's husband", description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d'], rank=18, attributes=None),
#  Relationship(id='bd8580b4c0d84b11ac071bd87f5a6167', short_id='63', source='BELINDA CRATCHIT', target='BOB CRATCHIT', weight=20.0, description='Belinda Cratchit is the daughter of Bob Cratchit.', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae', 'd6583840046247f428a9f02738842a7c'], rank=25, attributes=None),
#  Relationship(id='ced9a7d9baeb4e3ba110cf10b2cabeb4', short_id='64', source='BELINDA CRATCHIT', target='CHRISTMAS DAY', weight=5.0, description='The story of Belinda Cratchit takes place on Christmas Day', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=10, attributes=None),
#  Relationship(id='f04f995f4ce54013a018d5cf7fd5e6bb', short_id='65', source='MARTHA CRATCHIT', target='BOB CRATCHIT', weight=10.0, description='Martha Cratchit is a daughter of Bob Cratchit', description_embedding=None, text_unit_ids=['d6583840046247f428a9f02738842a7c'], rank=23, attributes=None),
#  Relationship(id='f444bcc99b984801b609a29333ffe590', short_id='66', source='MRS. DILBER', target='WOMAN', weight=6.0, description='Mrs. Dilber and the woman have a conversation in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=9, attributes=None),
#  Relationship(id='67afcbc0e52b4c1ebf66e3e0513a4dc0', short_id='67', source='MRS. DILBER', target='SECOND WOMAN', weight=6.0, description='Mrs. Dilber and the second woman have a conversation in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=7, attributes=None),
#  Relationship(id='31984d28e72f46e0bc8af9682e60950d', short_id='68', source='MRS. DILBER', target='MAN IN FADED BLACK', weight=1.0, description='Mrs. Dilber and the man in faded black have a conversation in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=7, attributes=None),
#  Relationship(id='a44e72e2971346cd8c1d04b372110cbb', short_id='69', source='MRS. DILBER', target='OLD JOE', weight=7.0, description='Old Joe and Mrs. Dilber are interacting in a transaction where Mrs. Dilber is selling items to Old Joe', description_embedding=None, text_unit_ids=['bc606176c752984da6d202275ee8c7a6'], rank=12, attributes=None),
#  Relationship(id='05238f2d694241e599197d417ba072bb', short_id='70', source='MRS. DILBER', target='SCROOGE', weight=3.0, description="Scrooge is observing Mrs. Dilber's actions with disgust", description_embedding=None, text_unit_ids=['bc606176c752984da6d202275ee8c7a6'], rank=128, attributes=None),
#  Relationship(id='662b384e80e74ea6a6b5c5bbb1a9785a', short_id='71', source='FAN', target='SCROOGE', weight=8.0, description="Fan is Scrooge's younger sister who comes to bring him home for Christmas", description_embedding=None, text_unit_ids=['ce95e4fc6ee410973c040fc628dce155'], rank=126, attributes=None),
#  Relationship(id='cdde5f3667c5405aaabd201c24a32a5e', short_id='72', source='FAN', target='MASTER SCROOGE', weight=8.0, description="Fan is Master Scrooge's younger sister who comes to bring him home for Christmas", description_embedding=None, text_unit_ids=['ce95e4fc6ee410973c040fc628dce155'], rank=7, attributes=None),
#  Relationship(id='7943536f667640b79b7aec77eca9748a', short_id='73', source='MRS. FEZZIWIG', target='FEZZIWIG', weight=25.0, description='Fezziwig and Mrs. Fezziwig are a married couple, as indicated by their shared surname and their frequent appearances together. They are often mentioned in the context of a dance, suggesting they enjoy participating in this activity together. In fact, they have been seen dancing together at a domestic ball, further confirming their close relationship and shared interests.', description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1', '260fb94666cbdfb08286ce8d8162130d', 'bf29edcb41403e5af43aa101072f4fdf'], rank=15, attributes=None),
#  Relationship(id='ba4face3e02a47c58a203896e3791ea6', short_id='74', source='MRS. FEZZIWIG', target='CHRISTMAS EVE PARTY', weight=1.0, description='Mrs. Fezziwig is a guest at the Christmas Eve party', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=16, attributes=None),
#  Relationship(id='0f5582bc437746ca81d7ce385837e752', short_id='75', source='MRS. FEZZIWIG', target='DOMESTIC BALL', weight=8.0, description='Mrs. Fezziwig is the hostess of the domestic ball', description_embedding=None, text_unit_ids=['bf29edcb41403e5af43aa101072f4fdf'], rank=6, attributes=None),
#  Relationship(id='61abf241245747e2a6e53a9a69e75086', short_id='76', source='BOB CRATCHIT', target='SCROOGE', weight=34.0, description="Bob Cratchit is a clerk who works for Scrooge at the counting-house. Scrooge, who is Bob Cratchit's employer, frequently interacts with him at the office. In a generous act, Scrooge buys a turkey for Bob Cratchit and also promises to raise his salary and assist his family.", description_embedding=None, text_unit_ids=['04e5c071e4ee5496d5380662e1339f45', '29793cee69d4eefd5fea8a5f2f27b521', '2b5ecb7fba1301d1f3d307e194a6c435', '6c362d3f8d01c76d84443dcabf3f322a', '7064df4af064aeb556e5bab52e896414', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=145, attributes=None),
#  Relationship(id='11f39f6528a744f9b2f5e08ab9f4d54f', short_id='77', source='BOB CRATCHIT', target='COUNTING-HOUSE', weight=9.0, description='Bob Cratchit is a clerk at the counting-house', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=24, attributes=None),
#  Relationship(id='0ebeb2b6bff440fa98045272b2a7e697', short_id='78', source='BOB CRATCHIT', target='CORNHILL', weight=3.0, description='Bob Cratchit goes sliding on Cornhill on Christmas Eve', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=23, attributes=None),
#  Relationship(id='274bd46eefe04274b2f8215029b21b58', short_id='79', source='BOB CRATCHIT', target='CAMDEN TOWN', weight=3.0, description="Bob Cratchit goes to Camden Town to play at blind man's-buff on Christmas Eve", description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=23, attributes=None),
#  Relationship(id='fa9ac85d3b624101a56a9171e41a7d8f', short_id='80', source='BOB CRATCHIT', target='CHRISTMAS EVE', weight=1.0, description='Bob Cratchit celebrates Christmas Eve', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=25, attributes=None),
#  Relationship(id='148c80c297b841cea7f54b1d3ba6de91', short_id='81', source='BOB CRATCHIT', target='SPIRIT', weight=11.0, description="The Spirit bestows blessings upon Bob Cratchit's dwelling, which is also referred to as his house.", description_embedding=None, text_unit_ids=['29793cee69d4eefd5fea8a5f2f27b521', 'b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=27, attributes=None),
#  Relationship(id='d209665873124a3e9b38c83317f741f8', short_id='82', source='BOB CRATCHIT', target='TINY TIM', weight=31.0, description='Bob Cratchit and Tiny Tim are members of the same family, known as the Cratchits. Bob Cratchit is the father of Tiny Tim, and correspondingly, Tiny Tim is the son of Bob Cratchit.', description_embedding=None, text_unit_ids=['1bdf253855a115bcf51faa63d7b07e82', '5d70b47bf7167b7586f47fcc4355a746', 'b4dec8fbe9f2a2c6a79d09c9484d15ae', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=31, attributes=None),
#  Relationship(id='8d469b3d60584762b5e5f00f87487645', short_id='83', source='BOB CRATCHIT', target='MARTHA', weight=10.0, description='Martha is the daughter of Bob Cratchit', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=27, attributes=None),
#  Relationship(id='7dc6a6fe544c47218748acb98dac0aa1', short_id='84', source='BOB CRATCHIT', target='CHRISTMAS DAY', weight=5.0, description='The story of Bob Cratchit takes place on Christmas Day', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=29, attributes=None),
#  Relationship(id='359c60b6714b4f2dba8101a025bbffa4', short_id='85', source='BOB CRATCHIT', target='CHRISTMAS PRESENT', weight=1.0, description='Bob Cratchit is a significant character in the event of Christmas Present', description_embedding=None, text_unit_ids=['b4dec8fbe9f2a2c6a79d09c9484d15ae'], rank=23, attributes=None),
#  Relationship(id='9c9668470db7494381360f276bbcf388', short_id='86', source='BOB CRATCHIT', target='CHRISTMAS MEAL', weight=7.0, description='Bob Cratchit participates in the Christmas meal with his family', description_embedding=None, text_unit_ids=['5d70b47bf7167b7586f47fcc4355a746'], rank=29, attributes=None),
#  Relationship(id='5029339d9d234602bda023e5ad4cc27b', short_id='87', source='BOB CRATCHIT', target='PETER', weight=14.0, description="Bob Cratchit is Peter's father and has a significant relationship with him. Cratchit has a particular situation in mind for Peter, indicating a deep involvement in his son's life.", description_embedding=None, text_unit_ids=['1bdf253855a115bcf51faa63d7b07e82', 'f40e4b274b5e1a25afbff9ecb733e1f4'], rank=29, attributes=None),
#  Relationship(id='4c3361f6de0f487faef061247ab68946', short_id='88', source='BOB CRATCHIT', target='MASTER PETER', weight=4.0, description='Bob Cratchit has a situation in mind for Master Peter, indicating a relationship', description_embedding=None, text_unit_ids=['1bdf253855a115bcf51faa63d7b07e82'], rank=26, attributes=None),
#  Relationship(id='1c1406a74dc54deba14f5f264659f7ca', short_id='89', source='BOB CRATCHIT', target="MR. SCROOGE'S NEPHEW", weight=11.0, description="Mr. Scrooge's nephew consistently demonstrated kindness towards Bob Cratchit. This kindness was not only shown through his general demeanor but also through his offer of assistance to Bob Cratchit.", description_embedding=None, text_unit_ids=['f40e4b274b5e1a25afbff9ecb733e1f4'], rank=25, attributes=None),
#  Relationship(id='b19c19053d724308ba4c216ce7784dd9', short_id='90', source='BOB CRATCHIT', target='THE GHOST', weight=3.0, description="The Ghost shows Scrooge a scene from Bob Cratchit's house.", description_embedding=None, text_unit_ids=['f40e4b274b5e1a25afbff9ecb733e1f4'], rank=35, attributes=None),
#  Relationship(id='de58262aad1a4cbe98eb4d09e1f7a48d', short_id='91', source='BOB CRATCHIT', target='OFFICE', weight=1.0, description='Bob Cratchit works at the office and interacts with Scrooge there', description_embedding=None, text_unit_ids=['04e5c071e4ee5496d5380662e1339f45'], rank=24, attributes=None),
#  Relationship(id='bf83449528234457b997f4d6756ee957', short_id='92', source='FEZZIWIG', target='SCROOGE', weight=1.0, description='Fezziwig is a character in the story who Scrooge was apprenticed to', description_embedding=None, text_unit_ids=['ce95e4fc6ee410973c040fc628dce155'], rank=134, attributes=None),
#  Relationship(id='15ebf63c7046436483a0ca2094dd8291', short_id='93', source='FEZZIWIG', target='MASTER SCROOGE', weight=1.0, description='Fezziwig is a character in the story who Master Scrooge was apprenticed to', description_embedding=None, text_unit_ids=['ce95e4fc6ee410973c040fc628dce155'], rank=15, attributes=None),
#  Relationship(id='a40f6c7942c0493e8e1839699f256804', short_id='94', source='FEZZIWIG', target='CHRISTMAS EVE PARTY', weight=9.0, description='Fezziwig is the host of the Christmas Eve party', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=23, attributes=None),
#  Relationship(id='ff8d33fe608b42a6bbcd8fa8a93c5059', short_id='95', source='FEZZIWIG', target='THE THREE MISS FEZZIWIGS', weight=10.0, description='Fezziwig is the father of the three Miss Fezziwigs', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=13, attributes=None),
#  Relationship(id='708de9b09aa047d88207a133e22a4d27', short_id='96', source='FEZZIWIG', target='THE FIDDLER', weight=7.0, description='Fezziwig is the employer of the fiddler for the Christmas Eve party', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=13, attributes=None),
#  Relationship(id='ec584124db9943aaa9b53980e21cb37c', short_id='97', source='FEZZIWIG', target='THE HOUSEMAID', weight=8.0, description='Fezziwig is the employer of the housemaid', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=14, attributes=None),
#  Relationship(id='f06b67ecf4154c95be82a942de0c32a1', short_id='98', source='FEZZIWIG', target='THE COOK', weight=8.0, description='Fezziwig is the employer of the cook', description_embedding=None, text_unit_ids=['260fb94666cbdfb08286ce8d8162130d'], rank=14, attributes=None),
#  Relationship(id='fcfb0788b50542c0a3c0e6894d33dda6', short_id='99', source='FEZZIWIG', target='DOMESTIC BALL', weight=8.0, description='Fezziwig is the host of the domestic ball', description_embedding=None, text_unit_ids=['bf29edcb41403e5af43aa101072f4fdf'], rank=13, attributes=None),
#  Relationship(id='7e15bcf26eee414289be20ff13434bea', short_id='100', source='SCROOGE', target='MARLEY', weight=41.0, description="Scrooge and Marley were business partners in life, with Scrooge also serving as the executor of Marley's estate after his death. Their past relationship was significant, as Marley is often associated with Scrooge's past. After Marley's death, Scrooge has experienced visions of Marley's face on the tiles around his fireplace and heard a chain dragging, which he associates with ghosts in haunted houses. This suggests that Marley's influence continues to impact Scrooge even after his passing.", description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74', '10730234d6ccc7cee08f3cfc58d8a9a1', '7064df4af064aeb556e5bab52e896414', '759315fa84c14e81f84fc71c73746184', '77ae3762a0b062ca5350ea54a05450ae', 'e8d4072836ac08145edc2fa8c15ea2c2'], rank=125, attributes=None),
#  Relationship(id='8b8abfd8da2340b6a1fb4253419c81c8', short_id='101', source='SCROOGE', target='SCRATCH', weight=3.0, description='Scratch is likely a nickname or alias for Scrooge, as indicated by the conversation between two characters', description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1'], rank=124, attributes=None),
#  Relationship(id='8e7b10cd2540402c99a3dc5cbb07b61b', short_id='102', source='SCROOGE', target='THE CLERGYMAN', weight=2.0, description="The clergyman signed the register of Marley's burial, indicating a professional relationship with Scrooge", description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1'], rank=124, attributes=None),
#  Relationship(id='3b183b6002c54888af6712e4daaa2fe3', short_id='103', source='SCROOGE', target='THE CLERK', weight=10.0, description="Scrooge is the employer of the clerk at the counting-house, indicating a professional relationship between the two. The clerk also signed the register of Marley's burial, further demonstrating their professional connection.", description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1', '7064df4af064aeb556e5bab52e896414'], rank=125, attributes=None),
#  Relationship(id='82ffa2ba82964352b71f9eef693a5d62', short_id='104', source='SCROOGE', target='THE UNDERTAKER', weight=2.0, description="The undertaker signed the register of Marley's burial, indicating a professional relationship with Scrooge", description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1'], rank=124, attributes=None),
#  Relationship(id='a0d5844ea436452cac765c27db8e86ed', short_id='105', source='SCROOGE', target='THE CHIEF MOURNER', weight=2.0, description="The chief mourner signed the register of Marley's burial, indicating a personal or professional relationship with Scrooge", description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1'], rank=124, attributes=None),
#  Relationship(id='47aa79ed2d5c4bbba126f9d115acf905', short_id='106', source='SCROOGE', target='SCROOGE AND MARLEY', weight=10.0, description='Scrooge is a part of the firm Scrooge and Marley', description_embedding=None, text_unit_ids=['10730234d6ccc7cee08f3cfc58d8a9a1'], rank=125, attributes=None),
#  Relationship(id='e1cff2a7aec64a7b90c8d90a6ad6e0fe', short_id='107', source='SCROOGE', target="SCROOGE'S NEPHEW", weight=23.0, description="Scrooge and Scrooge's nephew are relatives. Despite Scrooge's ill will towards his nephew and his family, the nephew harbors no anger towards him. Instead, he feels sorry for Scrooge. Scrooge's nephew consistently tries to bring Christmas cheer to his uncle and engage him in Christmas festivities, despite his uncle's initial resistance.", description_embedding=None, text_unit_ids=['4cf4deeb7f61acb7b7db4ce0e57fb1e6', '980594a50d68db06e6ca257bdb9ae95e', 'bc5fde5d1e00a3ecc1e548c8d24f1c1f'], rank=127, attributes=None),
#  Relationship(id='f49e640cff9746d0a0bc348acc6ed12b', short_id='108', source='SCROOGE', target="SCROOGE'S COUNTING-HOUSE", weight=9.0, description='Scrooge owns and works in his counting-house', description_embedding=None, text_unit_ids=['980594a50d68db06e6ca257bdb9ae95e'], rank=124, attributes=None),
#  Relationship(id='2959223763ce4a8f8713bed4444afb0d', short_id='109', source='SCROOGE', target="SCROOGE'S CLERK", weight=9.0, description="Scrooge's clerk works for Scrooge in his counting-house", description_embedding=None, text_unit_ids=['980594a50d68db06e6ca257bdb9ae95e'], rank=124, attributes=None),
#  Relationship(id='e3762833f4094197b62132870ca5c68a', short_id='110', source='SCROOGE', target='THE CITY', weight=1.0, description='Scrooge lives and works in the city', description_embedding=None, text_unit_ids=['980594a50d68db06e6ca257bdb9ae95e'], rank=124, attributes=None),
#  Relationship(id='3dc12ba290824592b809481bf0b21903', short_id='111', source='SCROOGE', target='CHRISTMAS', weight=40.0, description='Scrooge has a complex and evolving relationship with Christmas. Initially, he is known for his strong dislike of the holiday, even going as far as to consider it a humbug. This negative attitude towards Christmas becomes a point of contention between him and his nephew. However, his relationship with the holiday is complicated by his interactions with the Ghosts of Christmas Past and Present. These spirits show him scenes from his past and present Christmases, leading to feelings of regret, particularly when he recalls not giving something to a boy singing a Christmas carol. Despite his initial disdain, there are indications in the text that Scrooge eventually celebrates Christmas.', description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74', '206c2f9fd249659c7a897d323459cb6f', '4cf4deeb7f61acb7b7db4ce0e57fb1e6', '61a042016835080f3d334560b13b0e35', '980594a50d68db06e6ca257bdb9ae95e', 'ce95e4fc6ee410973c040fc628dce155'], rank=132, attributes=None),
#  Relationship(id='a40b5cdd5ed84072a1b4fcf320cfa206', short_id='112', source='SCROOGE', target='NEPHEW', weight=7.0, description='Scrooge is the uncle of the nephew, who is trying to convince him to celebrate Christmas', description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74'], rank=125, attributes=None),
#  Relationship(id='f872580ff75a4a4e99f69bff5d03b143', short_id='113', source='SCROOGE', target='CLERK', weight=8.0, description="Scrooge is the employer of the clerk, who he threatens to fire for applauding the nephew's speech", description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74'], rank=125, attributes=None),
#  Relationship(id='9e4184f850a4494596a452942189f487', short_id='114', source='SCROOGE', target='PORTLY GENTLEMEN', weight=4.0, description="The portly gentlemen visit Scrooge's office for a business matter", description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74'], rank=124, attributes=None),
#  Relationship(id='f8b67c70b90a4151a69dcf187788c9bb', short_id='115', source='SCROOGE', target='BEDLAM', weight=1.0, description='Scrooge mentions he will retire to Bedlam, indicating his frustration with the Christmas cheer around him', description_embedding=None, text_unit_ids=['080d8e696ff38c653ca90fa086415e74'], rank=124, attributes=None),
#  Relationship(id='e3704f8b08f0493190229fee006f7741', short_id='116', source='SCROOGE', target='THE GENTLEMAN', weight=3.0, description='Scrooge and the gentleman have a conversation about charity and the poor, but they have opposing views.', description_embedding=None, text_unit_ids=['0e2b719e4c97d0d8bfeb2a53f7638eb6'], rank=124, attributes=None),
#  Relationship(id='6c2369ca2d7b403986f6b928a0f7a738', short_id='117', source='SCROOGE', target='UNION WORKHOUSES', weight=5.0, description='Scrooge supports the Union workhouses and believes they are useful for the poor.', description_embedding=None, text_unit_ids=['0e2b719e4c97d0d8bfeb2a53f7638eb6'], rank=124, attributes=None),
#  Relationship(id='4cf265122ecb4c89b81112ac8ec829f9', short_id='118', source='SCROOGE', target='THE TREADMILL AND THE POOR LAW', weight=5.0, description='Scrooge supports The Treadmill and the Poor Law and believes they are useful for the poor.', description_embedding=None, text_unit_ids=['0e2b719e4c97d0d8bfeb2a53f7638eb6'], rank=124, attributes=None),
#  Relationship(id='2b434cd7f96d4e8b8c119e87cff8c365', short_id='119', source='SCROOGE', target='THE ANCIENT TOWER OF A CHURCH', weight=2.0, description='The ancient tower of a church is a location that is visible to Scrooge.', description_embedding=None, text_unit_ids=['0e2b719e4c97d0d8bfeb2a53f7638eb6'], rank=124, attributes=None),
#  Relationship(id='e6215e4777a842a2b64ebf6f6377b5be', short_id='120', source='SCROOGE', target='COUNTING-HOUSE', weight=9.0, description='Scrooge works at the counting-house', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=125, attributes=None),
#  Relationship(id='de8c9489ecc74ad68544523fe83ba823', short_id='121', source='SCROOGE', target='CITY OF LONDON', weight=9.0, description='Scrooge lives and works in the City of London', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=124, attributes=None),
#  Relationship(id='8068b436339e4c59a1a8071599e55330', short_id='122', source='SCROOGE', target='CHRISTMAS EVE', weight=4.0, description='Scrooge shows his disdain for Christmas Eve', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=126, attributes=None),
#  Relationship(id='83cd0a0fc0e64c9d8b800b8ec5023bb1', short_id='123', source='SCROOGE', target='THE GENIUS OF THE WEATHER', weight=2.0, description="The Genius of the Weather is described as sitting on the threshold of Scrooge's house", description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=124, attributes=None),
#  Relationship(id='9d242732e0ae4e3780acf2ab47bc04cc', short_id='124', source='SCROOGE', target='THE CORPORATION', weight=2.0, description='Scrooge is said to have as little fancy about the Corporation as any man in the City of London', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=124, attributes=None),
#  Relationship(id='2dba18277b704ea98f54b1888f04b4fc', short_id='125', source='SCROOGE', target='ALDERMEN', weight=2.0, description='Scrooge is said to have as little fancy about the Aldermen as any man in the City of London', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=124, attributes=None),
#  Relationship(id='dfe498e51d2446b6987fd4d8cdd7d1b6', short_id='126', source='SCROOGE', target='LIVERY', weight=2.0, description='Scrooge is said to have as little fancy about the Livery as any man in the City of London', description_embedding=None, text_unit_ids=['7064df4af064aeb556e5bab52e896414'], rank=124, attributes=None),
#  Relationship(id='05d05211c21a4cbe82a928233931a894', short_id='127', source='SCROOGE', target="SCROOGE'S HOUSE", weight=10.0, description='Scrooge is the resident of the house where the story takes place.', description_embedding=None, text_unit_ids=['759315fa84c14e81f84fc71c73746184'], rank=125, attributes=None),
#  Relationship(id='e8fdaa281d164764b6fdf065b70b93f1', short_id='128', source='SCROOGE', target='DUTCH TILES', weight=1.0, description="Scrooge sees a vision of Marley's face on the Dutch tiles around his fireplace.", description_embedding=None, text_unit_ids=['759315fa84c14e81f84fc71c73746184'], rank=129, attributes=None),
#  Relationship(id='c34125638cdf48bc8aebf1f7748d85fd', short_id='129', source='SCROOGE', target="WINE-MERCHANT'S CELLARS", weight=6.0, description="Scrooge hears a chain dragging in the wine-merchant's cellars, which he associates with ghosts in haunted houses.", description_embedding=None, text_unit_ids=['759315fa84c14e81f84fc71c73746184'], rank=124, attributes=None),
#  Relationship(id='ac968c1639f14657a9382ca498f3bc96', short_id='130', source='SCROOGE', target="MARLEY'S GHOST", weight=10.0, description="Scrooge is visited by Marley's Ghost, the apparition of his former partner. The ghost's visit causes Scrooge to question if he is dreaming, as he is bothered by the unexpected and unsettling presence. Marley's Ghost comes with a warning about Scrooge's fate, adding to the intensity of the encounter.", description_embedding=None, text_unit_ids=['4ffd9df98742c035b3e15bb24c3edb12', '8435b078474636a989a8c22f5493e1b6', 'e8d4072836ac08145edc2fa8c15ea2c2'], rank=125, attributes=None),
#  Relationship(id='5ba4a13ad1eb42aeb6359d3641d7e7d7', short_id='131', source='SCROOGE', target='THE CELLAR', weight=5.0, description="Scrooge hears the ghost's chains coming from the cellar", description_embedding=None, text_unit_ids=['e8d4072836ac08145edc2fa8c15ea2c2'], rank=124, attributes=None),
# ...
#  Relationship(id='3858c61b2aee4760bd76906a92f88701', short_id='271', source='BOB', target='PETER', weight=10.0, description="Bob is Peter's father", description_embedding=None, text_unit_ids=['19f8fd68a8dbc1bba7058e13ce3a2e3d'], rank=11, attributes=None),
#  Relationship(id='0edf7833d2934f82839f3d40bba363f9', short_id='272', source='THE MOOR', target='MINERS', weight=3.0, description='Miners live and work in the moor visited by Scrooge and the Spirit', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=3, attributes=None),
#  Relationship(id='1c80c4fa2e114d16941746b9c9153881', short_id='273', source='THE HUT', target='OLD MAN', weight=3.0, description='The old man is present in the hut visited by Scrooge and the Spirit, singing a Christmas song', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=6, attributes=None),
#  Relationship(id='b3e8b08383884f06b863aa5f42c101f9', short_id='274', source='THE HUT', target='OLD WOMAN', weight=3.0, description='The old woman is present in the hut visited by Scrooge and the Spirit', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=5, attributes=None),
#  Relationship(id='563459bc27874953b0f1fe143266cedb', short_id='275', source='THE HUT', target='CHILDREN', weight=3.0, description='Children are present in the hut visited by Scrooge and the Spirit', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=5, attributes=None),
#  Relationship(id='0ad3eac1a11d40c39aa4c6e94a1a70aa', short_id='276', source='THE LIGHTHOUSE', target='TWO MEN', weight=3.0, description='Two men are in the lighthouse visited by Scrooge and the Spirit, watching the light and celebrating Christmas', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=3, attributes=None),
#  Relationship(id='4a7eaada0e51418985ddcaf3759cc2a3', short_id='277', source='THE SHIP', target='MEN ON BOARD', weight=1.0, description='The men on board are on the ship visited by Scrooge and the Spirit, celebrating Christmas', description_embedding=None, text_unit_ids=['999c9887098d1a25dc3b42a8da7ddc8c'], rank=3, attributes=None),
#  Relationship(id='cd8c5cd312cb468d9bdd772b7ffb889c', short_id='278', source='OLD MAN', target='SHOP', weight=9.0, description='The old man runs the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=7, attributes=None),
#  Relationship(id='d4ae19d6ee024a8880f28f636ef773ac', short_id='279', source="SCROOGE'S NIECE", target='TOPPER', weight=1.0, description="Topper is present at the dinner hosted by Scrooge's niece and her husband. He has his eye on one of Scrooge's niece's sisters.", description_embedding=None, text_unit_ids=['bc5fde5d1e00a3ecc1e548c8d24f1c1f'], rank=10, attributes=None),
#  Relationship(id='074056385c694c559f669e4a4e3c92d4', short_id='280', source="SCROOGE'S NIECE", target="SCROOGE'S NIECE'S SISTERS", weight=9.0, description="Scrooge's niece is the sister of Scrooge's niece's sisters. They are all present at the same dinner.", description_embedding=None, text_unit_ids=['bc5fde5d1e00a3ecc1e548c8d24f1c1f'], rank=8, attributes=None),
#  Relationship(id='e7249aec3b504225abffb80912590c07', short_id='281', source="SCROOGE'S NIECE", target='FORFEITS', weight=1.0, description="Scrooge's niece participates in the game of forfeits during the Christmas festivities", description_embedding=None, text_unit_ids=['4cf4deeb7f61acb7b7db4ce0e57fb1e6'], rank=7, attributes=None),
#  Relationship(id='9debb85834174766b9b70cc3fbc36c34', short_id='282', source='TOPPER', target="SCROOGE'S NIECE'S SISTER", weight=1.0, description="Topper has his eye on one of Scrooge's niece's sisters, indicating a potential romantic interest.", description_embedding=None, text_unit_ids=['bc5fde5d1e00a3ecc1e548c8d24f1c1f'], rank=5, attributes=None),
#  Relationship(id='636aa3304c00466e90dfbe341f45c66e', short_id='283', source='TOPPER', target='THE PLUMP SISTER', weight=1.0, description="Topper chases the plump sister during the game of blind man's-buff", description_embedding=None, text_unit_ids=['4cf4deeb7f61acb7b7db4ce0e57fb1e6'], rank=9, attributes=None),
#  Relationship(id='00c1934f933a460799bf8cd75e0a2d73', short_id='284', source='TOPPER', target="BLIND MAN'S-BUFF PARTY", weight=8.0, description="Topper participates in the blind man's-buff party during the Christmas festivities", description_embedding=None, text_unit_ids=['4cf4deeb7f61acb7b7db4ce0e57fb1e6'], rank=5, attributes=None),
#  Relationship(id='250d21ffa81843498f04143e721b6fa9', short_id='285', source='THE PLUMP SISTER', target='YES AND NO', weight=7.0, description='The plump sister is playing the game Yes and No with the others', description_embedding=None, text_unit_ids=['61a042016835080f3d334560b13b0e35'], rank=8, attributes=None),
#  Relationship(id='7268e5d6171c4a46803e15330b9751e8', short_id='286', source='PHANTOM', target='DEATH', weight=7.0, description="The Phantom is showing Scrooge the event of the man's death", description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=6, attributes=None),
#  Relationship(id='980c713bd85341c1870d075098ad487a', short_id='287', source='BUSINESS MEN', target="'CHANGE", weight=1.0, description="The business men are located at the 'Change in the city", description_embedding=None, text_unit_ids=['ebc403dd3df39bacc3443ef4afb7edfd'], rank=4, attributes=None),
#  Relationship(id='e5af7fd45dd943fcadf5275e09f80bf3', short_id='288', source='SHOP', target='WOMAN', weight=5.0, description='The woman enters the shop with a heavy bundle', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=9, attributes=None),
#  Relationship(id='ae91505f57b3402a9f0417c33e5176f1', short_id='289', source='SHOP', target='SECOND WOMAN', weight=5.0, description='The second woman enters the shop with a heavy bundle', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=7, attributes=None),
#  Relationship(id='0d24628dcb4b4c2fb74c60be70a3257e', short_id='290', source='SHOP', target='MAN IN FADED BLACK', weight=5.0, description='The man in faded black enters the shop after the two women', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=7, attributes=None),
#  Relationship(id='321014e53c0e44e9a9260598fd16522c', short_id='291', source='WOMAN', target='OLD JOE', weight=7.0, description='Old Joe and the woman are interacting in a transaction where the woman is selling items to Old Joe', description_embedding=None, text_unit_ids=['bc606176c752984da6d202275ee8c7a6'], rank=11, attributes=None),
#  Relationship(id='4b0e68d6d31d42e4bfae5c4024859bd1', short_id='292', source='OLD JOE', target='PARLOUR', weight=6.0, description='Old Joe invites the others into the parlour', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=8, attributes=None),
#  Relationship(id='49c40241d4ba43c08452cd7ee35351d5', short_id='293', source='OLD JOE', target='CHARWOMAN', weight=5.0, description='The charwoman is known to Old Joe and is present in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=10, attributes=None),
#  Relationship(id='a8726a454643436d9d9958e369ef0d87', short_id='294', source='OLD JOE', target='LAUNDRESS', weight=5.0, description='The laundress is known to Old Joe and is present in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=10, attributes=None),
#  Relationship(id='3c17ae9bace144ce851d4bdca24250cb', short_id='295', source='OLD JOE', target="UNDERTAKER'S MAN", weight=5.0, description="The undertaker's man is known to Old Joe and is present in the shop", description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=10, attributes=None),
#  Relationship(id='caac467f30174b738d135244789ac3d1', short_id='296', source='LAUNDRESS', target='CHARWOMAN', weight=6.0, description='The charwoman and the laundress know each other and are present in the shop', description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=6, attributes=None),
#  Relationship(id='6b2a02e5e3c24d1dab15ae9dc51ab6cb', short_id='297', source='LAUNDRESS', target="UNDERTAKER'S MAN", weight=1.0, description="The laundress and the undertaker's man know each other and are present in the shop", description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=6, attributes=None),
#  Relationship(id='9537798187714726b1bb50d55fba58c1', short_id='298', source="UNDERTAKER'S MAN", target='CHARWOMAN', weight=6.0, description="The charwoman and the undertaker's man know each other and are present in the shop", description_embedding=None, text_unit_ids=['1cb66ea16e5e4f2816f0e188d3acc792'], rank=6, attributes=None),
#  Relationship(id='5a26dc879bcd4478968d003a94de944c', short_id='299', source="CAROLINE'S HUSBAND", target='HALF-DRUNKEN WOMAN', weight=1.0, description='The half-drunken woman is mentioned in a conversation between Caroline and her husband', description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=6, attributes=None),
#  Relationship(id='3d0c7e2423f74c209bcee4e4556c139c', short_id='300', source="CAROLINE'S HUSBAND", target='DEATH', weight=8.0, description="Caroline's husband brings the news of the man's death", description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=8, attributes=None),
#  Relationship(id='efef7084e33a4a998bca4d4affd74880', short_id='301', source="CAROLINE'S HUSBAND", target='THE MAN', weight=1.0, description="The man's death has a direct impact on the financial situation of Caroline's husband", description_embedding=None, text_unit_ids=['cd8a47ace09b9cee1e8b27b0689f2822'], rank=6, attributes=None),
#  Relationship(id='3ada800ef6ca4a26b4d82a93bba6a23f', short_id='302', source="SCROOGE AND MARLEY'S", target='THE PORTLY GENTLEMAN', weight=1.0, description="The Portly Gentleman walked into Scrooge and Marley's counting-house", description_embedding=None, text_unit_ids=['6c362d3f8d01c76d84443dcabf3f322a'], rank=4, attributes=None),
#  Relationship(id='e8b95e628964481e991109fad505c2e9', short_id='303', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='PROJECT GUTENBERG™', weight=1.0, description='The owner of the Project Gutenberg™ trademark donates royalties to the Project Gutenberg Literary Archive Foundation. The Foundation also manages the Project Gutenberg™ trademark.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=13, attributes=None),
#  Relationship(id='3e90d1e689584a14bf780187cd300111', short_id='304', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='RIGHT OF REPLACEMENT OR REFUND', weight=5.0, description='The Project Gutenberg Literary Archive Foundation provides a Right of Replacement or Refund policy for Project Gutenberg™ electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=10, attributes=None),
#  Relationship(id='f3a008c997034ed6861c986eb8ffae38', short_id='305', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='LIMITED WARRANTY, DISCLAIMER OF DAMAGES', weight=5.0, description='The Project Gutenberg Literary Archive Foundation provides a Limited Warranty, Disclaimer of Damages policy for Project Gutenberg™ electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=10, attributes=None),
#  Relationship(id='ff71d2e82a5d411f967cab5f7816b042', short_id='306', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='INDEMNITY', weight=1.0, description='The Project Gutenberg Literary Archive Foundation provides an Indemnity policy for Project Gutenberg™ electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=10, attributes=None),
#  Relationship(id='0d514e86a99d416e9e9c10a3d24bed60', short_id='307', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='INTERNAL REVENUE SERVICE', weight=7.0, description='The Project Gutenberg Literary Archive Foundation has been granted tax exempt status by the Internal Revenue Service', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=10, attributes=None),
#  Relationship(id='5dc6cb4e9cd44262a533fcf119bd2d9d', short_id='308', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='MISSISSIPPI', weight=6.0, description='The Project Gutenberg Literary Archive Foundation is organized under the laws of the state of Mississippi', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=10, attributes=None),
#  Relationship(id='a2168909a4e1423db67f12e83fe8d4ae', short_id='309', source='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', target='SALT LAKE CITY', weight=5.0, description='The business office of the Project Gutenberg Literary Archive Foundation is located in Salt Lake City', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=10, attributes=None),
#  Relationship(id='ec8f83f5ca494b06923378a7e334cfe6', short_id='310', source='PROJECT GUTENBERG™', target='U.S. COPYRIGHT LAW', weight=5.0, description='Project Gutenberg volunteers and employees consider U.S. copyright law when creating the Project Gutenberg™ collection.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=6, attributes=None),
#  Relationship(id='906a91287a63471fb17beda5b113e43e', short_id='311', source='PROJECT GUTENBERG™', target='RIGHT OF REPLACEMENT OR REFUND', weight=8.0, description='Project Gutenberg™ provides a Right of Replacement or Refund policy for its electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=7, attributes=None),
#  Relationship(id='dc0fb1285d264d23a8b8daf3f05acd1b', short_id='312', source='PROJECT GUTENBERG™', target='LIMITED WARRANTY, DISCLAIMER OF DAMAGES', weight=8.0, description='Project Gutenberg™ has a Limited Warranty, Disclaimer of Damages policy for its electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=7, attributes=None),
#  Relationship(id='e5446a8a991640f1bfb33a18489be572', short_id='313', source='PROJECT GUTENBERG™', target='INDEMNITY', weight=8.0, description='Project Gutenberg™ has an Indemnity policy for its electronic works.', description_embedding=None, text_unit_ids=['0ddc17ea5e566006c000b4013f2181a5'], rank=7, attributes=None),
#  Relationship(id='a7b558f7b329426dade7b8cd6d471da0', short_id='314', source='INTERNAL REVENUE SERVICE', target='FOUNDATION', weight=7.0, description='The Foundation has been granted tax exempt status by the Internal Revenue Service', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=7, attributes=None),
#  Relationship(id='a27982d1672a40fa9d27e61af39c9119', short_id='315', source='MISSISSIPPI', target='FOUNDATION', weight=6.0, description='The Foundation is organized under the laws of the state of Mississippi', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=7, attributes=None),
#  Relationship(id='a60835b9d9eb45d3a6d0fbecd1176718', short_id='316', source='SALT LAKE CITY', target='FOUNDATION', weight=5.0, description='The business office of the Foundation is located in Salt Lake City', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=7, attributes=None),
#  Relationship(id='f6f1a2438b5543efb7b8dbc64d99b581', short_id='317', source='U.S.', target='FOUNDATION', weight=1.0, description='The Foundation operates in the U.S.', description_embedding=None, text_unit_ids=['cd4234ed6caba8f15d09a2e3ee604b2a'], rank=6, attributes=None)]

# %% [markdown]
# ---
# ## 7.3. Visualización de nodos y relaciones

# %% [markdown]
# <div style="text-align: justify;">
#
# `yfiles-jupyter-graphs` es una extensión de visualización de grafos que proporciona representaciones interactivas y personalizables para datos estructurados de nodos y relaciones.
#
# En este caso, la utilizamos para ofrecer una visualización interactiva del grafo de conocimiento, pasando listas de nodos y relaciones convertidas a partir de los archivos parquet proporcionados. Los requisitos para los datos de entrada son un atributo `id` para los nodos y propiedades `start`/`end` para las relaciones, que correspondan a los identificadores de los nodos. Se pueden agregar atributos adicionales en el campo `properties` de cada diccionario de nodo o relación.
#
# </div>

# %%
# %pip install yfiles_jupyter_graphs --quiet
from yfiles_jupyter_graphs import GraphWidget


# converts the entities dataframe to a list of dicts for yfiles-jupyter-graphs (mirar celda de abajo)
def convert_entities_to_dicts(df):
    """Convert the entities dataframe to a list of dicts for yfiles-jupyter-graphs."""
    nodes_dict = {}
    for _, row in df.iterrows():
        # Create a dictionary for each row and collect unique nodes
        node_id = row["title"]
        if node_id not in nodes_dict:
            nodes_dict[node_id] = {
                "id": node_id,
                "properties": row.to_dict(),
            }
    return list(nodes_dict.values())


# converts the relationships dataframe to a list of dicts for yfiles-jupyter-graphs
def convert_relationships_to_dicts(df):
    """Convert the relationships dataframe to a list of dicts for yfiles-jupyter-graphs."""
    relationships = []
    for _, row in df.iterrows():
        # Create a dictionary for each row
        relationships.append({
            "start": row["source"],
            "end": row["target"],
            "properties": row.to_dict(),
        })
    return relationships


w = GraphWidget()
w.directed = True
### Los nodos del grafo son las entidades
w.nodes = convert_entities_to_dicts(entity_df)
### Los ejes del grafo son las relaciones
w.edges = convert_relationships_to_dicts(relationship_df)
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
### Función para convertir entidades a diccionarios
entity_dict = convert_entities_to_dicts(entity_df)
entity_dict
# Out:
# [{'id': 'PROJECT GUTENBERG',
#   'properties': {'id': '4f370d7f0d734f92b6118d88e79d886a',
#    'human_readable_id': 0,
#    'title': 'PROJECT GUTENBERG',
#    'community': 8,
#    'level': 0,
#    'degree': 7,
#    'x': -1.9309667348861694,
#    'y': 17.19828987121582}},
#  {'id': 'UNITED STATES',
#   'properties': {'id': '8e5be5b1e63343b8a2f0af6baba70337',
#    'human_readable_id': 1,
#    'title': 'UNITED STATES',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': 19.66257667541504,
#    'y': 8.599832534790039}},
#  {'id': 'A CHRISTMAS CAROL',
#   'properties': {'id': '73b0e0a551dc454690bad3d6756912be',
#    'human_readable_id': 2,
#    'title': 'A CHRISTMAS CAROL',
#    'community': 0,
#    'level': 0,
#    'degree': 8,
#    'x': -11.45168685913086,
#    'y': 2.6954503059387207}},
#  {'id': 'CHARLES DICKENS',
#   'properties': {'id': 'cf70df771d6c464e93b7ff99d2ea8142',
#    'human_readable_id': 3,
#    'title': 'CHARLES DICKENS',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -12.506287574768066,
#    'y': 1.6406795978546143}},
#  {'id': 'ARTHUR RACKHAM',
#   'properties': {'id': '3dfdd81803b74b3a8d3244af70df4f83',
#    'human_readable_id': 4,
#    'title': 'ARTHUR RACKHAM',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -11.712614059448242,
#    'y': 2.4345991611480713}},
#  {'id': 'PHILADELPHIA',
#   'properties': {'id': 'e478fddb40f044169a81153ee5f8bb3b',
#    'human_readable_id': 5,
#    'title': 'PHILADELPHIA',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'NEW YORK',
#   'properties': {'id': '4531def00cd0409a88e0ad3ca51bfd37',
#    'human_readable_id': 6,
#    'title': 'NEW YORK',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'J. B. LIPPINCOTT COMPANY',
#   'properties': {'id': '05a8b2da0f4d469f8e3ef8b9305ec577',
#    'human_readable_id': 7,
#    'title': 'J. B. LIPPINCOTT COMPANY',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -11.862039566040039,
#    'y': 2.2851402759552}},
#  {'id': 'SUZANNE SHELL',
#   'properties': {'id': '6a99fcd063fa4975978c2891b9b6a4d0',
#    'human_readable_id': 8,
#    'title': 'SUZANNE SHELL',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -11.992227554321289,
#    'y': 2.1550939083099365}},
#  {'id': 'JANET BLENKINSHIP',
#   'properties': {'id': '3582a02e66254a76b79d23799edd6fd5',
#    'human_readable_id': 9,
#    'title': 'JANET BLENKINSHIP',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -12.271769523620605,
#    'y': 1.8753448724746704}},
#  {'id': 'ONLINE DISTRIBUTED PROOFREADING TEAM',
#   'properties': {'id': '728d49a565b04cbdb630e64ef05ee631',
#    'human_readable_id': 10,
#    'title': 'ONLINE DISTRIBUTED PROOFREADING TEAM',
#    'community': 0,
#    'level': 0,
#    'degree': 1,
#    'x': -12.12186050415039,
#    'y': 2.0254018306732178}},
#  {'id': 'PETER CRATCHIT',
#   'properties': {'id': 'a9ebcb82b5694ebf90e11747729afde1',
#    'human_readable_id': 11,
#    'title': 'PETER CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 3,
#    'x': 25.88594627380371,
#    'y': 18.922399520874023}},
#  {'id': 'TIM CRATCHIT',
#   'properties': {'id': '9208f851f93148b8aa4f5760351fe935',
#    'human_readable_id': 12,
#    'title': 'TIM CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 1,
#    'x': 17.33121681213379,
#    'y': 7.915502071380615}},
#  {'id': 'MR. FEZZIWIG',
#   'properties': {'id': '79c9743b91c34addb4078147b4481c0b',
#    'human_readable_id': 13,
#    'title': 'MR. FEZZIWIG',
#    'community': 5,
#    'level': 0,
#    'degree': 1,
#    'x': 9.595601081848145,
#    'y': -5.341401100158691}},
#  {'id': 'FRED',
#   'properties': {'id': 'ce62fb5eacf74c18a8d6b7417a028b47',
#    'human_readable_id': 14,
#    'title': 'FRED',
#    'community': 5,
#    'level': 0,
#    'degree': 7,
#    'x': 12.277932167053223,
#    'y': 3.846339225769043}},
#  {'id': 'GHOST OF CHRISTMAS PAST',
#   'properties': {'id': 'fdee948a65da4ee5b6a3e25793dfab52',
#    'human_readable_id': 15,
#    'title': 'GHOST OF CHRISTMAS PAST',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.049392700195312,
#    'y': 5.3211822509765625}},
#  {'id': 'GHOST OF CHRISTMAS PRESENT',
#   'properties': {'id': '267d767526244db6bdbabfd305b64665',
#    'human_readable_id': 16,
#    'title': 'GHOST OF CHRISTMAS PRESENT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.48997688293457,
#    'y': 5.7156782150268555}},
#  {'id': 'GHOST OF CHRISTMAS YET TO COME',
#   'properties': {'id': '0c4eabfc3e684d2f8ede442fbdacdb7e',
#    'human_readable_id': 17,
#    'title': 'GHOST OF CHRISTMAS YET TO COME',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.442445755004883,
#    'y': 3.604656219482422}},
#  {'id': 'GHOST OF JACOB MARLEY',
#   'properties': {'id': '6041ce29e51e4ee3888db60fa054e349',
#    'human_readable_id': 18,
#    'title': 'GHOST OF JACOB MARLEY',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 11.453722953796387,
#    'y': 4.780170917510986}},
#  {'id': 'JOE',
#   'properties': {'id': '87845a23037848d9b58e0be1539a1ab3',
#    'human_readable_id': 19,
#    'title': 'JOE',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'EBENEZER SCROOGE',
#   'properties': {'id': 'c1e8f6a1790a42cba70228fa79dbf313',
#    'human_readable_id': 20,
#    'title': 'EBENEZER SCROOGE',
#    'community': 5,
#    'level': 0,
#    'degree': 12,
#    'x': 10.559802055358887,
#    'y': 6.358273983001709}},
#  {'id': 'MR. TOPPER',
#   'properties': {'id': '952b08ea7e8d48bd8ccc79ad78f3835c',
#    'human_readable_id': 21,
#    'title': 'MR. TOPPER',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'DICK WILKINS',
#   'properties': {'id': '76d55ff1d0b94c24be81664f63c5fd16',
#    'human_readable_id': 22,
#    'title': 'DICK WILKINS',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 9.966763496398926,
#    'y': 7.258736610412598}},
#  {'id': 'BELLE',
#   'properties': {'id': '586193437d6d4bc2b156e5d8f073d825',
#    'human_readable_id': 23,
#    'title': 'BELLE',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 10.852193832397461,
#    'y': 5.78255033493042}},
#  {'id': 'CAROLINE',
#   'properties': {'id': '558b3c526384498786816333a727b9b6',
#    'human_readable_id': 24,
#    'title': 'CAROLINE',
#    'community': 6,
#    'level': 0,
#    'degree': 5,
#    'x': 1.1250886917114258,
#    'y': 15.281535148620605}},
#  {'id': 'MRS. CRATCHIT',
#   'properties': {'id': '7a5df0bc0a71469dab1e1c922bafc911',
#    'human_readable_id': 25,
#    'title': 'MRS. CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 14,
#    'x': 25.11330223083496,
#    'y': 20.655609130859375}},
#  {'id': 'BELINDA CRATCHIT',
#   'properties': {'id': 'b6b645896dc545a5920fc2c4a00357b9',
#    'human_readable_id': 26,
#    'title': 'BELINDA CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 3,
#    'x': 25.51490592956543,
#    'y': 19.097583770751953}},
#  {'id': 'MARTHA CRATCHIT',
#   'properties': {'id': '072fbc692fe34e069bea21d95e2b4121',
#    'human_readable_id': 27,
#    'title': 'MARTHA CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 1,
#    'x': 17.10604476928711,
#    'y': 8.30604362487793}},
#  {'id': 'MRS. DILBER',
#   'properties': {'id': '31e3b8674621489cb3bd0689a4630f60',
#    'human_readable_id': 28,
#    'title': 'MRS. DILBER',
#    'community': 4,
#    'level': 0,
#    'degree': 5,
#    'x': 2.521592617034912,
#    'y': 0.32656019926071167}},
#  {'id': 'FAN',
#   'properties': {'id': '4bc5ea10dc1342c497eac5a7aef14f7a',
#    'human_readable_id': 29,
#    'title': 'FAN',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 11.22622013092041,
#    'y': 5.155585765838623}},
#  {'id': 'MRS. FEZZIWIG',
#   'properties': {'id': '7f32030293ab434eb8c5730ed22c41c8',
#    'human_readable_id': 30,
#    'title': 'MRS. FEZZIWIG',
#    'community': 5,
#    'level': 0,
#    'degree': 4,
#    'x': 8.0104398727417,
#    'y': 9.256012916564941}},
#  {'id': 'BOB CRATCHIT',
#   'properties': {'id': '256c91e05ad44aff89255d345553a6ec',
#    'human_readable_id': 31,
#    'title': 'BOB CRATCHIT',
#    'community': 2,
#    'level': 0,
#    'degree': 22,
#    'x': 24.54867172241211,
#    'y': 19.846851348876953}},
#  {'id': 'FEZZIWIG',
#   'properties': {'id': 'd43a4bf0218041a6a0d39fa269891322',
#    'human_readable_id': 32,
#    'title': 'FEZZIWIG',
#    'community': 5,
#    'level': 0,
#    'degree': 11,
#    'x': 7.65570068359375,
#    'y': 8.879321098327637}},
#  {'id': 'SCROOGE',
#   'properties': {'id': 'b7fde61247a54514a9482ae2a9b4efae',
#    'human_readable_id': 33,
#    'title': 'SCROOGE',
#    'community': 1,
#    'level': 0,
#    'degree': 123,
#    'x': 15.027237892150879,
#    'y': 5.929666996002197}},
#  {'id': 'MARLEY',
#   'properties': {'id': '07983dc4ae694ee6beade2959a611354',
#    'human_readable_id': 34,
#    'title': 'MARLEY',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.420114517211914,
#    'y': 5.367868423461914}},
#  {'id': "ST. PAUL'S CHURCHYARD",
#   'properties': {'id': '27d3bbc17fb6423b933d0263b178ec1a',
#    'human_readable_id': 35,
#    'title': "ST. PAUL'S CHURCHYARD",
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': "HAMLET'S FATHER",
#   'properties': {'id': 'bd6d54a7a8d94de1bded3c5807a933ad',
#    'human_readable_id': 36,
#    'title': "HAMLET'S FATHER",
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'THE CLERGYMAN',
#   'properties': {'id': 'd9f4a9704b20480db8b8c4e3899a3751',
#    'human_readable_id': 37,
#    'title': 'THE CLERGYMAN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.873067855834961,
#    'y': -5.909343719482422}},
#  {'id': 'THE CLERK',
#   'properties': {'id': 'e9829f782df6461691c81a1b206ef95a',
#    'human_readable_id': 38,
#    'title': 'THE CLERK',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.863858222961426,
#    'y': 3.423569440841675}},
#  {'id': 'THE UNDERTAKER',
#   'properties': {'id': '5c6faac584694fc094a9552e25452149',
#    'human_readable_id': 39,
#    'title': 'THE UNDERTAKER',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.728715896606445,
#    'y': -2.8387269973754883}},
#  {'id': 'THE CHIEF MOURNER',
#   'properties': {'id': 'a576fece771e4165b738d532bce5b66a',
#    'human_readable_id': 40,
#    'title': 'THE CHIEF MOURNER',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.604519844055176,
#    'y': -4.777060508728027}},
#  {'id': 'SCROOGE AND MARLEY',
#   'properties': {'id': 'd99b325cde304d31bcdb16ba4cd3abbf',
#    'human_readable_id': 41,
#    'title': 'SCROOGE AND MARLEY',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 16.868074417114258,
#    'y': 3.184539556503296}},
#  {'id': 'SCRATCH',
#   'properties': {'id': '1fbdeede6a0449fe8b295ed5cfba6cd3',
#    'human_readable_id': 42,
#    'title': 'SCRATCH',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.169861793518066,
#    'y': -4.049539566040039}},
#  {'id': "SCROOGE'S NEPHEW",
#   'properties': {'id': '5b932f4d5c544b648d35af136acfd1af',
#    'human_readable_id': 43,
#    'title': "SCROOGE'S NEPHEW",
#    'community': 1,
#    'level': 0,
#    'degree': 4,
#    'x': 14.070408821105957,
#    'y': 5.735685348510742}},
#  {'id': "SCROOGE'S COUNTING-HOUSE",
#   'properties': {'id': '555a6f653f454ff4bb07e48ae79a540d',
#    'human_readable_id': 44,
#    'title': "SCROOGE'S COUNTING-HOUSE",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.693353652954102,
#    'y': 0.7423296570777893}},
#  {'id': "SCROOGE'S CLERK",
#   'properties': {'id': '7f2701241d404a9699b1c0587d07c03e',
#    'human_readable_id': 45,
#    'title': "SCROOGE'S CLERK",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.96157169342041,
#    'y': -0.12289582937955856}},
#  {'id': 'THE CITY',
#   'properties': {'id': 'a736c92e282d41aaaa1e390030317dd3',
#    'human_readable_id': 46,
#    'title': 'THE CITY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.12144947052002,
#    'y': -4.531960487365723}},
#  {'id': 'CHRISTMAS',
#   'properties': {'id': '570173a4496b4b46a5e81f5ee799733f',
#    'human_readable_id': 47,
#    'title': 'CHRISTMAS',
#    'community': 1,
#    'level': 0,
#    'degree': 9,
#    'x': 14.475743293762207,
#    'y': 5.774542808532715}},
#  {'id': 'NEPHEW',
#   'properties': {'id': 'c03c1461548c4e20a594dd399578cb73',
#    'human_readable_id': 48,
#    'title': 'NEPHEW',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 16.454675674438477,
#    'y': 4.867836952209473}},
#  {'id': 'CLERK',
#   'properties': {'id': '6d509d0e429848779faa5d7b308aa638',
#    'human_readable_id': 49,
#    'title': 'CLERK',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 14.702800750732422,
#    'y': 2.055657148361206}},
#  {'id': 'PORTLY GENTLEMEN',
#   'properties': {'id': '25da083f02e8473ab00632d2c39b72ca',
#    'human_readable_id': 50,
#    'title': 'PORTLY GENTLEMEN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.040874481201172,
#    'y': -4.977717876434326}},
#  {'id': 'BEDLAM',
#   'properties': {'id': '2ee5c5ca9ecf461da9706e2f023b4653',
#    'human_readable_id': 51,
#    'title': 'BEDLAM',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 7.934118747711182,
#    'y': -4.810592174530029}},
#  {'id': 'THE GENTLEMAN',
#   'properties': {'id': 'ccd466f13dcf4b699a30e95ed549178d',
#    'human_readable_id': 52,
#    'title': 'THE GENTLEMAN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.686022758483887,
#    'y': -4.546360969543457}},
#  {'id': 'UNION WORKHOUSES',
#   'properties': {'id': '520d4398eb9a456bb82b964def6e7af6',
#    'human_readable_id': 53,
#    'title': 'UNION WORKHOUSES',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.448444366455078,
#    'y': -4.084162712097168}},
#  {'id': 'THE TREADMILL AND THE POOR LAW',
#   'properties': {'id': 'df1c0f45b5ef434c95bcc99a88a8c0c4',
#    'human_readable_id': 54,
#    'title': 'THE TREADMILL AND THE POOR LAW',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.075346946716309,
#    'y': -6.264317512512207}},
#  {'id': 'THE LORD MAYOR',
#   'properties': {'id': '96872eee0cdd417ba0c16984cf437362',
#    'human_readable_id': 55,
#    'title': 'THE LORD MAYOR',
#    'community': -1,
#    'level': 0,
#    'degree': 2,
#    'x': None,
#    'y': None}},
#  {'id': 'MANSION HOUSE',
#   'properties': {'id': 'dfcefe8a9d384ca4895e4c468528e286',
#    'human_readable_id': 56,
#    'title': 'MANSION HOUSE',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'ST. DUNSTAN',
#   'properties': {'id': '9f06306c9a944ed2a56e18141480af61',
#    'human_readable_id': 57,
#    'title': 'ST. DUNSTAN',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'THE MAIN STREET',
#   'properties': {'id': 'd13d0b9e2a4448d1a0f8c1df7a303dd8',
#    'human_readable_id': 58,
#    'title': 'THE MAIN STREET',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'THE LITTLE TAILOR',
#   'properties': {'id': 'c5490070637e48e596a688dc7262a166',
#    'human_readable_id': 59,
#    'title': 'THE LITTLE TAILOR',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'THE ANCIENT TOWER OF A CHURCH',
#   'properties': {'id': 'db2fae4591c34aa1bf38e07a3b3636a3',
#    'human_readable_id': 60,
#    'title': 'THE ANCIENT TOWER OF A CHURCH',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.565102577209473,
#    'y': -5.111757755279541}},
#  {'id': 'COUNTING-HOUSE',
#   'properties': {'id': '8a076b3c20334e3998624d9899b44eb5',
#    'human_readable_id': 61,
#    'title': 'COUNTING-HOUSE',
#    'community': 2,
#    'level': 0,
#    'degree': 2,
#    'x': 16.78400421142578,
#    'y': 7.480377674102783}},
#  {'id': 'CORNHILL',
#   'properties': {'id': '1fb0c03a02a849b2931d7576b5b2ab8e',
#    'human_readable_id': 62,
#    'title': 'CORNHILL',
#    'community': 2,
#    'level': 0,
#    'degree': 1,
#    'x': 14.745950698852539,
#    'y': -3.540342092514038}},
#  {'id': 'CAMDEN TOWN',
#   'properties': {'id': '06b6de89a4284c0da7635db0fc2a5d4a',
#    'human_readable_id': 63,
#    'title': 'CAMDEN TOWN',
#    'community': 2,
#    'level': 0,
#    'degree': 1,
#    'x': 15.2899808883667,
#    'y': -3.491262912750244}},
#  {'id': 'CITY OF LONDON',
#   'properties': {'id': '2eadd613ec7443d998bd5142c1dafb18',
#    'human_readable_id': 64,
#    'title': 'CITY OF LONDON',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.25412654876709,
#    'y': 2.2463715076446533}},
#  {'id': 'CHRISTMAS EVE',
#   'properties': {'id': 'bc566ac0a7fa4c88a8d1976175607eb3',
#    'human_readable_id': 65,
#    'title': 'CHRISTMAS EVE',
#    'community': 1,
#    'level': 0,
#    'degree': 3,
#    'x': 16.920753479003906,
#    'y': -1.7012546062469482}},
#  {'id': 'THE GENIUS OF THE WEATHER',
#   'properties': {'id': '4ce8c636f57c411cae6e6978559a64b8',
#    'human_readable_id': 66,
#    'title': 'THE GENIUS OF THE WEATHER',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.297033309936523,
#    'y': -3.807237148284912}},
#  {'id': 'THE CORPORATION',
#   'properties': {'id': 'fedf3c73a3274d3db77d65c5398a8508',
#    'human_readable_id': 67,
#    'title': 'THE CORPORATION',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 10.352509498596191,
#    'y': -4.813623428344727}},
#  {'id': 'ALDERMEN',
#   'properties': {'id': 'e822a860386e4bc1adf865c5051038d3',
#    'human_readable_id': 68,
#    'title': 'ALDERMEN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.682656288146973,
#    'y': -4.508584499359131}},
#  {'id': 'LIVERY',
#   'properties': {'id': '4a8c445a21d3462a9a818d5acc948ef5',
#    'human_readable_id': 69,
#    'title': 'LIVERY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.010140419006348,
#    'y': -2.8661117553710938}},
#  {'id': "SCROOGE'S HOUSE",
#   'properties': {'id': 'f236a5f31fe74694ab1f435dba471a37',
#    'human_readable_id': 70,
#    'title': "SCROOGE'S HOUSE",
#    'community': 7,
#    'level': 0,
#    'degree': 2,
#    'x': 13.536642074584961,
#    'y': 1.4787628650665283}},
#  {'id': 'DUTCH TILES',
#   'properties': {'id': '1078111b7734457c9001dadf95fe01f0',
#    'human_readable_id': 71,
#    'title': 'DUTCH TILES',
#    'community': 7,
#    'level': 0,
#    'degree': 6,
#    'x': 10.961118698120117,
#    'y': 1.1388051509857178}},
#  {'id': 'DUTCH MERCHANT',
#   'properties': {'id': 'a5a7bb04b2524d62a85f241d02bff5a9',
#    'human_readable_id': 72,
#    'title': 'DUTCH MERCHANT',
#    'community': 7,
#    'level': 0,
#    'degree': 2,
#    'x': 11.075071334838867,
#    'y': 1.48386812210083}},
#  {'id': 'QUEENS OF SHEBA',
#   'properties': {'id': '5befb2637c17466699226a5c602e9069',
#    'human_readable_id': 73,
#    'title': 'QUEENS OF SHEBA',
#    'community': 7,
#    'level': 0,
#    'degree': 1,
#    'x': 11.667282104492188,
#    'y': 1.185642123222351}},
#  {'id': 'ABRAHAMS',
#   'properties': {'id': 'ac51fc86788d4094ae1d5b566d38ad81',
#    'human_readable_id': 74,
#    'title': 'ABRAHAMS',
#    'community': 7,
#    'level': 0,
#    'degree': 1,
#    'x': 11.586414337158203,
#    'y': 1.8112640380859375}},
#  {'id': 'BELSHAZZARS',
#   'properties': {'id': 'b094598505c541a79ead808acf183c24',
#    'human_readable_id': 75,
#    'title': 'BELSHAZZARS',
#    'community': 7,
#    'level': 0,
#    'degree': 1,
#    'x': 11.243551254272461,
#    'y': 1.5210307836532593}},
#  {'id': 'APOSTLES',
#   'properties': {'id': 'c372fdfff70e4c46b6ac4907cf78c900',
#    'human_readable_id': 76,
#    'title': 'APOSTLES',
#    'community': 7,
#    'level': 0,
#    'degree': 1,
#    'x': 12.337688446044922,
#    'y': 1.493733286857605}},
#  {'id': "WINE-MERCHANT'S CELLARS",
#   'properties': {'id': 'f92c5df1ba1a497e820ce681bcc06675',
#    'human_readable_id': 77,
#    'title': "WINE-MERCHANT'S CELLARS",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.996545791625977,
#    'y': -5.545589447021484}},
#  {'id': "MARLEY'S GHOST",
#   'properties': {'id': 'c097a581e9ee46948a4f2eff89009b8f',
#    'human_readable_id': 78,
#    'title': "MARLEY'S GHOST",
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.50637435913086,
#    'y': 2.656684398651123}},
#  {'id': 'THE FIREPLACE',
#   'properties': {'id': '4b01a514e88d4db09a8e1621d1771192',
#    'human_readable_id': 79,
#    'title': 'THE FIREPLACE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.83580493927002,
#    'y': -2.282989263534546}},
#  {'id': 'THE CELLAR',
#   'properties': {'id': '5da6b379f6284b25be225e26a762aaba',
#    'human_readable_id': 80,
#    'title': 'THE CELLAR',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.179302215576172,
#    'y': -0.06460414081811905}},
#  {'id': 'JACOB MARLEY',
#   'properties': {'id': '2c2f502d1ad44fa7966bf1ee46d11b47',
#    'human_readable_id': 81,
#    'title': 'JACOB MARLEY',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 12.447646141052246,
#    'y': 3.079550266265869}},
#  {'id': 'THE GHOST',
#   'properties': {'id': 'bd932f7fe3764026b5cc799068856763',
#    'human_readable_id': 82,
#    'title': 'THE GHOST',
#    'community': 1,
#    'level': 0,
#    'degree': 13,
#    'x': 15.867765426635742,
#    'y': 6.1099371910095215}},
#  {'id': 'THREE SPIRITS',
#   'properties': {'id': 'e0d2a6a97f13446e854f7fe23596812a',
#    'human_readable_id': 83,
#    'title': 'THREE SPIRITS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.966876029968262,
#    'y': -0.8587977290153503}},
#  {'id': 'PHANTOMS',
#   'properties': {'id': 'dc304fcbaadf4249887139c0a1c1c4fe',
#    'human_readable_id': 84,
#    'title': 'PHANTOMS',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.487274169921875,
#    'y': -6.082265377044678}},
#  {'id': 'INVISIBLE WORLD',
#   'properties': {'id': 'c22dbf4d427146e899c96cafd572d0cc',
#    'human_readable_id': 85,
#    'title': 'INVISIBLE WORLD',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.093988418579102,
#    'y': -5.8462018966674805}},
#  {'id': 'THE STRANGE FIGURE',
#   'properties': {'id': '574900558d71499691573da37dbf34e4',
#    'human_readable_id': 86,
#    'title': 'THE STRANGE FIGURE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 9.899505615234375,
#    'y': -3.596071720123291}},
#  {'id': 'CITY',
#   'properties': {'id': '7c589a1034d94dd8b6f694a1efd4f1b6',
#    'human_readable_id': 87,
#    'title': 'CITY',
#    'community': 1,
#    'level': 0,
#    'degree': 3,
#    'x': 15.631719589233398,
#    'y': 4.8055830001831055}},
#  {'id': 'OPEN COUNTRY ROAD',
#   'properties': {'id': 'e3654fbec18041179cc938e41ab7cd78',
#    'human_readable_id': 88,
#    'title': 'OPEN COUNTRY ROAD',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.801730155944824,
#    'y': -6.189794540405273}},
#  {'id': 'MARKET-TOWN',
#   'properties': {'id': '97e9671e7d214fb1b9933372f9e39a49',
#    'human_readable_id': 89,
#    'title': 'MARKET-TOWN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 7.457309722900391,
#    'y': -4.5430474281311035}},
#  {'id': 'BOYS',
#   'properties': {'id': 'a3572195248743568b6ce14394394b97',
#    'human_readable_id': 90,
#    'title': 'BOYS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 17.647544860839844,
#    'y': -3.112647771835327}},
#  {'id': 'FARMERS',
#   'properties': {'id': '7c32805ea0eb462c9eb4b5468cb8f402',
#    'human_readable_id': 91,
#    'title': 'FARMERS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 9.532421112060547,
#    'y': -4.074025630950928}},
#  {'id': 'WINTER DAY',
#   'properties': {'id': '00aea98437c042d6b606e7f8d402822e',
#    'human_readable_id': 92,
#    'title': 'WINTER DAY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 17.794002532958984,
#    'y': -3.476076602935791}},
#  {'id': 'GHOST',
#   'properties': {'id': '7f63082186b34dff845eae842dfa8cd8',
#    'human_readable_id': 93,
#    'title': 'GHOST',
#    'community': 1,
#    'level': 0,
#    'degree': 4,
#    'x': 14.969809532165527,
#    'y': 5.2430267333984375}},
#  {'id': 'ALI BABA',
#   'properties': {'id': '79b6449fb65d4da8856ed497c564a6a9',
#    'human_readable_id': 94,
#    'title': 'ALI BABA',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.896066665649414,
#    'y': -5.768688201904297}},
#  {'id': 'VALENTINE',
#   'properties': {'id': '711ee727e40545aca473ae9d3f164dc9',
#    'human_readable_id': 95,
#    'title': 'VALENTINE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.405943870544434,
#    'y': -5.872541427612305}},
#  {'id': 'ORSON',
#   'properties': {'id': 'e9b37dc43c9d4d88afccee6224f7182f',
#    'human_readable_id': 96,
#    'title': 'ORSON',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.101188659667969,
#    'y': -4.6802825927734375}},
#  {'id': "SULTAN'S GROOM",
#   'properties': {'id': '0e7f692221864df5a38ce32f157ddd2a',
#    'human_readable_id': 97,
#    'title': "SULTAN'S GROOM",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.869301795959473,
#    'y': -5.739353656768799}},
#  {'id': 'GENII',
#   'properties': {'id': '995e5585d4574d02b5108c38b9e06832',
#    'human_readable_id': 98,
#    'title': 'GENII',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.159170150756836,
#    'y': -5.009078502655029}},
#  {'id': 'PARROT',
#   'properties': {'id': 'c157def39acd4a6aadbbf13f5a2c3a73',
#    'human_readable_id': 99,
#    'title': 'PARROT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.525848388671875,
#    'y': -6.3486151695251465}},
#  {'id': 'ROBIN CRUSOE',
#   'properties': {'id': 'c5655c5a3dea49da8de6775d7fd60bc6',
#    'human_readable_id': 100,
#    'title': 'ROBIN CRUSOE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.289815902709961,
#    'y': -6.241746425628662}},
#  {'id': 'FRIDAY',
#   'properties': {'id': 'e2de0fdf4587443295fe5a3b97d9135d',
#    'human_readable_id': 101,
#    'title': 'FRIDAY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 7.7235307693481445,
#    'y': -4.3722991943359375}},
#  {'id': 'DAMASCUS',
#   'properties': {'id': 'b7465414546748a9934eb8e85ab27587',
#    'human_readable_id': 102,
#    'title': 'DAMASCUS',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'PRINCESS',
#   'properties': {'id': '15b4495354bd45449b85b1264288c721',
#    'human_readable_id': 103,
#    'title': 'PRINCESS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 10.446015357971191,
#    'y': -3.2882444858551025}},
#  {'id': 'SCHOOLMASTER',
#   'properties': {'id': 'cee113b74c4a49f29489ed5127301cf5',
#    'human_readable_id': 104,
#    'title': 'SCHOOLMASTER',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 12.799341201782227,
#    'y': 2.4879891872406006}},
#  {'id': 'MASTER SCROOGE',
#   'properties': {'id': '271b011d2d4c48d6a058a1a7ff605548',
#    'human_readable_id': 105,
#    'title': 'MASTER SCROOGE',
#    'community': 5,
#    'level': 0,
#    'degree': 4,
#    'x': 11.690038681030273,
#    'y': 4.295132160186768}},
#  {'id': 'CHRISTMAS EVE PARTY',
#   'properties': {'id': 'ac2e3b3c40054b84bc026a376297604e',
#    'human_readable_id': 106,
#    'title': 'CHRISTMAS EVE PARTY',
#    'community': 5,
#    'level': 0,
#    'degree': 12,
#    'x': 7.968871116638184,
#    'y': 9.269719123840332}},
#  {'id': 'THE FIDDLER',
#   'properties': {'id': '935aae12b36448bdab54b23483542ed6',
#    'human_readable_id': 107,
#    'title': 'THE FIDDLER',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 9.346867561340332,
#    'y': 8.228256225585938}},
#  {'id': 'THE HOUSEMAID',
#   'properties': {'id': '71365c925c5c4bc1b059a1b1ddea2f81',
#    'human_readable_id': 108,
#    'title': 'THE HOUSEMAID',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 9.176044464111328,
#    'y': 9.432074546813965}},
#  {'id': 'THE COOK',
#   'properties': {'id': '9cb193afc5e5423a8f9298f423e790cc',
#    'human_readable_id': 109,
#    'title': 'THE COOK',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 8.638306617736816,
#    'y': 9.016475677490234}},
#  {'id': 'THE BAKER',
#   'properties': {'id': '712ed4a7cb4f40e38803882ac917bdb2',
#    'human_readable_id': 110,
#    'title': 'THE BAKER',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 9.41743278503418,
#    'y': 9.179183959960938}},
#  {'id': 'THE MILKMAN',
#   'properties': {'id': 'a5a87c6ac0d5472da37ac2a44386119e',
#    'human_readable_id': 111,
#    'title': 'THE MILKMAN',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 9.391019821166992,
#    'y': 8.612661361694336}},
#  {'id': 'THE BOY FROM OVER THE WAY',
#   'properties': {'id': '2581bc141fa7487aa132200456957105',
#    'human_readable_id': 112,
#    'title': 'THE BOY FROM OVER THE WAY',
#    'community': 5,
#    'level': 0,
#    'degree': 1,
#    'x': 9.782614707946777,
#    'y': 8.065317153930664}},
#  {'id': 'THE GIRL FROM NEXT DOOR BUT ONE',
#   'properties': {'id': '99bb9034ca064140a0bbcaaa7a405151',
#    'human_readable_id': 113,
#    'title': 'THE GIRL FROM NEXT DOOR BUT ONE',
#    'community': 5,
#    'level': 0,
#    'degree': 1,
#    'x': 9.972993850708008,
#    'y': -5.26845121383667}},
#  {'id': 'THE THREE MISS FEZZIWIGS',
#   'properties': {'id': '476ea4c9514341998c12d1a26e68f214',
#    'human_readable_id': 114,
#    'title': 'THE THREE MISS FEZZIWIGS',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 8.707990646362305,
#    'y': 8.58990478515625}},
#  {'id': 'DICK',
#   'properties': {'id': '154359c3e0e9432480ccf5db7e2076db',
#    'human_readable_id': 115,
#    'title': 'DICK',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.902276039123535,
#    'y': -5.04029655456543}},
#  {'id': 'FAIR YOUNG GIRL',
#   'properties': {'id': 'c0f067e15fbd407ab6d52e261f2b7487',
#    'human_readable_id': 116,
#    'title': 'FAIR YOUNG GIRL',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 10.981739044189453,
#    'y': -4.059465408325195}},
#  {'id': 'CHRISTMAS PAST',
#   'properties': {'id': '56bf3e638b424cc6acb0e55b8790fe61',
#    'human_readable_id': 117,
#    'title': 'CHRISTMAS PAST',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.582953453063965,
#    'y': 0.07687479257583618}},
#  {'id': 'DOMESTIC BALL',
#   'properties': {'id': '8c96fae6a4b448ac9b8ce3ca99d547d5',
#    'human_readable_id': 118,
#    'title': 'DOMESTIC BALL',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 9.022104263305664,
#    'y': 8.071839332580566}},
#  {'id': 'SPIRIT',
#   'properties': {'id': 'f489885b414f4818873b9175c667a6ca',
#    'human_readable_id': 119,
#    'title': 'SPIRIT',
#    'community': 1,
#    'level': 0,
#    'degree': 5,
#    'x': 16.326093673706055,
#    'y': 6.446509838104248}},
#  {'id': 'MOTHER',
#   'properties': {'id': '88807ce13ab14110bd9234ebb69296ee',
#    'human_readable_id': 120,
#    'title': 'MOTHER',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'DAUGHTER',
#   'properties': {'id': '004f7d801f964160b441c6e7060c2479',
#    'human_readable_id': 121,
#    'title': 'DAUGHTER',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'GIRL',
#   'properties': {'id': '10195ec108f448f192c2b227fdd824d1',
#    'human_readable_id': 122,
#    'title': 'GIRL',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.126976013183594,
#    'y': -0.2730925977230072}},
#  {'id': 'THE SECOND OF THE THREE SPIRITS',
#   'properties': {'id': 'a55585e910d946ceab19bbcf9584d341',
#    'human_readable_id': 123,
#    'title': 'THE SECOND OF THE THREE SPIRITS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.316839218139648,
#    'y': -3.212966203689575}},
#  {'id': 'THE MASTER OF THE HOUSE',
#   'properties': {'id': 'df4bc230438f422682ee570d910724c5',
#    'human_readable_id': 124,
#    'title': 'THE MASTER OF THE HOUSE',
#    'community': -1,
#    'level': 0,
#    'degree': 2,
#    'x': None,
#    'y': None}},
#  {'id': 'THE DAUGHTER',
#   'properties': {'id': '614380a21580450cb223eb65c782c0ba',
#    'human_readable_id': 125,
#    'title': 'THE DAUGHTER',
#    'community': -1,
#    'level': 0,
#    'degree': 2,
#    'x': None,
#    'y': None}},
#  {'id': 'THE MOTHER',
#   'properties': {'id': '697ffe9feda0452a955dd192a02dac8f',
#    'human_readable_id': 126,
#    'title': 'THE MOTHER',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'THE HUSBAND',
#   'properties': {'id': '2ab3aab6d06e40cea139389e7d827e27',
#    'human_readable_id': 127,
#    'title': 'THE HUSBAND',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 11.089232444763184,
#    'y': 5.999684810638428}},
#  {'id': 'FATHER',
#   'properties': {'id': 'd0f3ed3eb4bf4f7bb817e3496c9e33a7',
#    'human_readable_id': 128,
#    'title': 'FATHER',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'GENTLEMEN OF THE FREE-AND-EASY SORT',
#   'properties': {'id': '99a683e3c8fe48f48ba637c55db46d5c',
#    'human_readable_id': 129,
#    'title': 'GENTLEMEN OF THE FREE-AND-EASY SORT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 8.661236763000488,
#    'y': -4.005089282989502}},
#  {'id': 'JOLLY GIANT',
#   'properties': {'id': 'e00ccddeec394b1ca028756c91a28ab5',
#    'human_readable_id': 130,
#    'title': 'JOLLY GIANT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.31413745880127,
#    'y': 1.0040980577468872}},
#  {'id': 'SPIRIT OF CHRISTMAS PRESENT',
#   'properties': {'id': '97b48239f4604560ae52d5755439215b',
#    'human_readable_id': 131,
#    'title': 'SPIRIT OF CHRISTMAS PRESENT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 9.54471206665039,
#    'y': -4.4560723304748535}},
#  {'id': 'GREAT BRITAIN',
#   'properties': {'id': '67c4c53107d9459fb925f03f3ac78f4e',
#    'human_readable_id': 132,
#    'title': 'GREAT BRITAIN',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'CITY STREETS',
#   'properties': {'id': '47086a08782d498399b2935600ab5630',
#    'human_readable_id': 133,
#    'title': 'CITY STREETS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.815813064575195,
#    'y': -3.3582346439361572}},
#  {'id': 'HOUSE-FRONTS',
#   'properties': {'id': '993045638448491c8fcdbe9d59b1ea35',
#    'human_readable_id': 134,
#    'title': 'HOUSE-FRONTS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.779864311218262,
#    'y': -4.624713897705078}},
#  {'id': "POULTERERS' SHOPS",
#   'properties': {'id': '4d22cd5a8f3549db9ba634550d8180ec',
#    'human_readable_id': 135,
#    'title': "POULTERERS' SHOPS",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.677040100097656,
#    'y': -3.6434597969055176}},
#  {'id': "FRUITERERS'",
#   'properties': {'id': '4c4107d39dc24d68b8a715d40bc78bca',
#    'human_readable_id': 136,
#    'title': "FRUITERERS'",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.376446723937988,
#    'y': -4.333854675292969}},
#  {'id': "GROCERS'",
#   'properties': {'id': '026adfbca92540759d2c7a2c8d242baa',
#    'human_readable_id': 137,
#    'title': "GROCERS'",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 8.608844757080078,
#    'y': -3.767653703689575}},
#  {'id': 'HOLLY',
#   'properties': {'id': 'cbe6aa4cd959402189cd9a76d0a71ed2',
#    'human_readable_id': 138,
#    'title': 'HOLLY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.219867706298828,
#    'y': -4.828073978424072}},
#  {'id': 'CHRISTMAS DAY',
#   'properties': {'id': '53c3f1991729403ca847df8bb9c62128',
#    'human_readable_id': 139,
#    'title': 'CHRISTMAS DAY',
#    'community': 2,
#    'level': 0,
#    'degree': 7,
#    'x': 25.687240600585938,
#    'y': 18.56905746459961}},
#  {'id': "BAKERS' SHOPS",
#   'properties': {'id': 'd936f32f716e48e2b592f2b620472ffa',
#    'human_readable_id': 140,
#    'title': "BAKERS' SHOPS",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.472021102905273,
#    'y': -4.652870178222656}},
#  {'id': 'CHURCH AND CHAPEL',
#   'properties': {'id': 'b8571fd02ddb4b2f8420a5b9eb1c416f',
#    'human_readable_id': 141,
#    'title': 'CHURCH AND CHAPEL',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'TOWN',
#   'properties': {'id': '6f90e7d38b604d57bcca2fd8b1bd516f',
#    'human_readable_id': 142,
#    'title': 'TOWN',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.82164192199707,
#    'y': -2.5542173385620117}},
#  {'id': 'PEOPLE',
#   'properties': {'id': '3d110cdf03074c588b57381bce99f673',
#    'human_readable_id': 143,
#    'title': 'PEOPLE',
#    'community': -1,
#    'level': 0,
#    'degree': 1,
#    'x': None,
#    'y': None}},
#  {'id': 'TINY TIM',
#   'properties': {'id': '2bd07ec6e9d94d07bc1f054d7a388da9',
#    'human_readable_id': 144,
#    'title': 'TINY TIM',
#    'community': 2,
#    'level': 0,
#    'degree': 9,
#    'x': 24.91554069519043,
#    'y': 20.249271392822266}},
#  {'id': 'MARTHA',
#   'properties': {'id': '4e75c7bf4903499fa4ec6e9f4583fac8',
#    'human_readable_id': 145,
#    'title': 'MARTHA',
#    'community': 2,
#    'level': 0,
#    'degree': 5,
#    'x': 25.438400268554688,
#    'y': 19.742536544799805}},
#  {'id': 'CHRISTMAS PRESENT',
#   'properties': {'id': '4a0515486e9549d2afcc5eac40352e40',
#    'human_readable_id': 146,
#    'title': 'CHRISTMAS PRESENT',
#    'community': 2,
#    'level': 0,
#    'degree': 1,
#    'x': 10.123246192932129,
#    'y': -3.0675506591796875}},
#  {'id': 'MASTER PETER',
#   'properties': {'id': '62e4eee2405d4f35a8661b3cc97d5089',
#    'human_readable_id': 147,
#    'title': 'MASTER PETER',
#    'community': 2,
#    'level': 0,
#    'degree': 4,
#    'x': 25.806427001953125,
#    'y': 19.84444236755371}},
#  {'id': 'MISS BELINDA',
#   'properties': {'id': '48510eb732a947c98dfa4133aee8706e',
#    'human_readable_id': 148,
#    'title': 'MISS BELINDA',
#    'community': 2,
#    'level': 0,
#    'degree': 2,
#    'x': 26.124645233154297,
#    'y': 18.825645446777344}},
#  {'id': 'THE TWO YOUNG CRATCHITS',
#   'properties': {'id': '43fb97b0f2924029a9e1fd420b97e081',
#    'human_readable_id': 149,
#    'title': 'THE TWO YOUNG CRATCHITS',
#    'community': 2,
#    'level': 0,
#    'degree': 2,
#    'x': 17.550888061523438,
#    'y': 8.51101016998291}},
#  {'id': 'CHRISTMAS MEAL',
#   'properties': {'id': 'e10066894c9140e893dc2300f6624fd1',
#    'human_readable_id': 150,
#    'title': 'CHRISTMAS MEAL',
#    'community': 2,
#    'level': 0,
#    'degree': 7,
#    'x': 25.581693649291992,
#    'y': 20.433324813842773}},
#  {'id': 'BOB',
#   'properties': {'id': '3eade1997a6f45a0ac99dcfacad1592d',
#    'human_readable_id': 151,
#    'title': 'BOB',
#    'community': 2,
#    'level': 0,
#    'degree': 4,
#    'x': 25.14583969116211,
#    'y': 18.977588653564453}},
#  {'id': 'PETER',
#   'properties': {'id': 'c008362d78374b47b44f4bebe1cbfe0a',
#    'human_readable_id': 152,
#    'title': 'PETER',
#    'community': 2,
#    'level': 0,
#    'degree': 7,
#    'x': 24.966257095336914,
#    'y': 19.56655502319336}},
#  {'id': 'THE CRATCHITS',
#   'properties': {'id': '3b94d799fc4f408986fee654e57f3b8d',
#    'human_readable_id': 153,
#    'title': 'THE CRATCHITS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 10.25185775756836,
#    'y': -4.401368618011475}},
#  {'id': 'THE BLAZE',
#   'properties': {'id': '34462806a6b648a4a05213d8b7ad5a39',
#    'human_readable_id': 154,
#    'title': 'THE BLAZE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 13.779058456420898,
#    'y': -5.31087589263916}},
#  {'id': 'THE LAMPLIGHTER',
#   'properties': {'id': '55e3a006011d4b14a7062294f98e4977',
#    'human_readable_id': 155,
#    'title': 'THE LAMPLIGHTER',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.971956253051758,
#    'y': -3.0872387886047363}},
#  {'id': 'THE SPIRIT',
#   'properties': {'id': '9df2d220303a4171b208a2f5779226b3',
#    'human_readable_id': 156,
#    'title': 'THE SPIRIT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 17.27297019958496,
#    'y': -3.89047908782959}},
#  {'id': 'THE MOOR',
#   'properties': {'id': '7ac103a0c6a9467ab7e31e0b484cb555',
#    'human_readable_id': 157,
#    'title': 'THE MOOR',
#    'community': 10,
#    'level': 0,
#    'degree': 2,
#    'x': 11.744510650634766,
#    'y': -1.1981186866760254}},
#  {'id': 'THE HUT',
#   'properties': {'id': '92536143892c4b47945d649c2cb0aedd',
#    'human_readable_id': 158,
#    'title': 'THE HUT',
#    'community': 4,
#    'level': 0,
#    'degree': 4,
#    'x': 4.185364246368408,
#    'y': -1.0135899782180786}},
#  {'id': 'THE LIGHTHOUSE',
#   'properties': {'id': '0f4210898ea444f9b5d45d0ff4b5cce5',
#    'human_readable_id': 159,
#    'title': 'THE LIGHTHOUSE',
#    'community': 11,
#    'level': 0,
#    'degree': 2,
#    'x': 12.40570068359375,
#    'y': -2.010584831237793}},
#  {'id': 'THE SHIP',
#   'properties': {'id': '8ffd46a4202346459336e9c4b7e4c10f',
#    'human_readable_id': 160,
#    'title': 'THE SHIP',
#    'community': 9,
#    'level': 0,
#    'degree': 2,
#    'x': 11.894918441772461,
#    'y': -1.6052814722061157}},
#  {'id': 'OLD MAN',
#   'properties': {'id': '4fde7a56185b407287e52cc57c23e67d',
#    'human_readable_id': 161,
#    'title': 'OLD MAN',
#    'community': 4,
#    'level': 0,
#    'degree': 2,
#    'x': 3.944267511367798,
#    'y': -0.6968801617622375}},
#  {'id': 'OLD WOMAN',
#   'properties': {'id': 'd20270db61844a6480559bc79103ab73',
#    'human_readable_id': 162,
#    'title': 'OLD WOMAN',
#    'community': 4,
#    'level': 0,
#    'degree': 1,
#    'x': 4.959849834442139,
#    'y': -0.8119771480560303}},
#  {'id': 'CHILDREN',
#   'properties': {'id': '70978f7128794ab89b2d6ba139758e38',
#    'human_readable_id': 163,
#    'title': 'CHILDREN',
#    'community': 4,
#    'level': 0,
#    'degree': 1,
#    'x': 4.7351813316345215,
#    'y': -0.9556490778923035}},
#  {'id': 'TWO MEN',
#   'properties': {'id': '5adeb2fd7463496787f670d5344b1a83',
#    'human_readable_id': 164,
#    'title': 'TWO MEN',
#    'community': 11,
#    'level': 0,
#    'degree': 1,
#    'x': 12.463319778442383,
#    'y': -1.1774860620498657}},
#  {'id': 'MEN ON BOARD',
#   'properties': {'id': '5933eaea758b4fd3811b78af1ce83052',
#    'human_readable_id': 165,
#    'title': 'MEN ON BOARD',
#    'community': 9,
#    'level': 0,
#    'degree': 1,
#    'x': 12.102048873901367,
#    'y': -1.8525304794311523}},
#  {'id': 'MINERS',
#   'properties': {'id': 'bc2474d410ae4bab8339cd255fc8a183',
#    'human_readable_id': 166,
#    'title': 'MINERS',
#    'community': 10,
#    'level': 0,
#    'degree': 1,
#    'x': 11.489625930786133,
#    'y': -1.1034069061279297}},
#  {'id': "SCROOGE'S NIECE",
#   'properties': {'id': '0afded79d65f41879975a196592e401e',
#    'human_readable_id': 167,
#    'title': "SCROOGE'S NIECE",
#    'community': 1,
#    'level': 0,
#    'degree': 6,
#    'x': 13.890140533447266,
#    'y': 5.517326831817627}},
#  {'id': 'TOPPER',
#   'properties': {'id': '37ad1587196d4cbb84f76516a0a3086b',
#    'human_readable_id': 168,
#    'title': 'TOPPER',
#    'community': 3,
#    'level': 0,
#    'degree': 4,
#    'x': 13.491955757141113,
#    'y': 4.529442310333252}},
#  {'id': "SCROOGE'S NIECE'S SISTERS",
#   'properties': {'id': '39885a80a1f04d2589fd43fa41452af3',
#    'human_readable_id': 169,
#    'title': "SCROOGE'S NIECE'S SISTERS",
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 13.82397747039795,
#    'y': 5.235133171081543}},
#  {'id': "SCROOGE'S NIECE'S SISTER",
#   'properties': {'id': '470c76df99de4087b5dc8c64e07fe121',
#    'human_readable_id': 170,
#    'title': "SCROOGE'S NIECE'S SISTER",
#    'community': 3,
#    'level': 0,
#    'degree': 1,
#    'x': 12.825333595275879,
#    'y': -1.8118109703063965}},
#  {'id': 'THE PLUMP SISTER',
#   'properties': {'id': '486318cf9b1f4a6db9f5d9f44d0b8e92',
#    'human_readable_id': 171,
#    'title': 'THE PLUMP SISTER',
#    'community': 5,
#    'level': 0,
#    'degree': 5,
#    'x': 12.934557914733887,
#    'y': 3.5707626342773438}},
#  {'id': "BLIND MAN'S-BUFF PARTY",
#   'properties': {'id': 'e04fc15dcb884c4d9b29df42619cb091',
#    'human_readable_id': 172,
#    'title': "BLIND MAN'S-BUFF PARTY",
#    'community': 3,
#    'level': 0,
#    'degree': 1,
#    'x': 13.253833770751953,
#    'y': 4.307192325592041}},
#  {'id': 'FORFEITS',
#   'properties': {'id': '3885e10ac31c4aada2234e4e2716559a',
#    'human_readable_id': 173,
#    'title': 'FORFEITS',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.984796524047852,
#    'y': -3.4573354721069336}},
#  {'id': 'UNCLE SCROOGE',
#   'properties': {'id': 'b98f7da9e5b345fcbac37f3d2ed726d4',
#    'human_readable_id': 174,
#    'title': 'UNCLE SCROOGE',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 13.304788589477539,
#    'y': 2.8068504333496094}},
#  {'id': 'LONDON',
#   'properties': {'id': 'a5bee48729364eef94dc043c682429a8',
#    'human_readable_id': 175,
#    'title': 'LONDON',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'TWELFTH-NIGHT PARTY',
#   'properties': {'id': 'b341012ab7b64a7091df7f713976c2fb',
#    'human_readable_id': 176,
#    'title': 'TWELFTH-NIGHT PARTY',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.400224685668945,
#    'y': -0.7167580723762512}},
#  {'id': 'MULLED WINE',
#   'properties': {'id': '3a28550abba74ef8b1aa05d9bc0ce10a',
#    'human_readable_id': 177,
#    'title': 'MULLED WINE',
#    'community': 5,
#    'level': 0,
#    'degree': 2,
#    'x': 12.993958473205566,
#    'y': 2.9438319206237793}},
#  {'id': 'CHRISTMAS HOLIDAYS',
#   'properties': {'id': 'c84df7e888ab4ad29d2708007be5dd70',
#    'human_readable_id': 178,
#    'title': 'CHRISTMAS HOLIDAYS',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 16.606185913085938,
#    'y': 6.194141387939453}},
#  {'id': 'MIDNIGHT',
#   'properties': {'id': 'f675eb0bc3554c7f8ad1c33d7ff28ced',
#    'human_readable_id': 179,
#    'title': 'MIDNIGHT',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 16.966772079467773,
#    'y': 5.708287239074707}},
#  {'id': 'YES AND NO',
#   'properties': {'id': '508b5c929a8147cd8e7ad855c42d2d8b',
#    'human_readable_id': 180,
#    'title': 'YES AND NO',
#    'community': 5,
#    'level': 0,
#    'degree': 3,
#    'x': 13.407939910888672,
#    'y': 3.3755908012390137}},
#  {'id': 'IGNORANCE',
#   'properties': {'id': '47aac66515904a1a92afc42e4063848d',
#    'human_readable_id': 181,
#    'title': 'IGNORANCE',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 17.264936447143555,
#    'y': -2.2560904026031494}},
#  {'id': 'WANT',
#   'properties': {'id': '08c825231e1c472e97e252b7fc52c753',
#    'human_readable_id': 182,
#    'title': 'WANT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 16.154056549072266,
#    'y': -3.3816518783569336}},
#  {'id': 'PHANTOM',
#   'properties': {'id': '80a01b1a903a469f9ba407d446709608',
#    'human_readable_id': 183,
#    'title': 'PHANTOM',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 15.524317741394043,
#    'y': 4.2147908210754395}},
#  {'id': 'BUSINESS MEN',
#   'properties': {'id': 'af878082ebbf453aaac6caa7463348a6',
#    'human_readable_id': 184,
#    'title': 'BUSINESS MEN',
#    'community': 1,
#    'level': 0,
#    'degree': 3,
#    'x': 16.592788696289062,
#    'y': 3.2830393314361572}},
#  {'id': 'MAN WITH A MONSTROUS CHIN',
#   'properties': {'id': 'bf75cac4650344729eb11a51fa4786b3',
#    'human_readable_id': 185,
#    'title': 'MAN WITH A MONSTROUS CHIN',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'MAN WITH A PENDULOUS EXCRESCENCE ON HIS NOSE',
#   'properties': {'id': '109f1f26b8c4445c870dc493ac14103f',
#    'human_readable_id': 186,
#    'title': 'MAN WITH A PENDULOUS EXCRESCENCE ON HIS NOSE',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': 'TWO PERSONS MEETING',
#   'properties': {'id': 'b16019e4f3f449bd9219fa31dbbdb977',
#    'human_readable_id': 187,
#    'title': 'TWO PERSONS MEETING',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 12.335051536560059,
#    'y': -5.539237976074219}},
#  {'id': 'JACOB',
#   'properties': {'id': '874d920d39464b7a9dd3ea6f9eee4711',
#    'human_readable_id': 188,
#    'title': 'JACOB',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 11.679855346679688,
#    'y': -3.4860031604766846}},
#  {'id': "'CHANGE",
#   'properties': {'id': 'aea296544129403cb2263fde85b5cb43',
#    'human_readable_id': 189,
#    'title': "'CHANGE",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 8.852375984191895,
#    'y': -4.710215091705322}},
#  {'id': 'SHOP',
#   'properties': {'id': '75ab4558f5194554a8834f5f4304ebad',
#    'human_readable_id': 190,
#    'title': 'SHOP',
#    'community': 4,
#    'level': 0,
#    'degree': 5,
#    'x': 3.869774580001831,
#    'y': -0.19700117409229279}},
#  {'id': 'WOMAN',
#   'properties': {'id': 'f493c3021464426c937467b846fdcbce',
#    'human_readable_id': 191,
#    'title': 'WOMAN',
#    'community': 4,
#    'level': 0,
#    'degree': 4,
#    'x': 2.8660457134246826,
#    'y': 0.2825413644313812}},
#  {'id': 'SECOND WOMAN',
#   'properties': {'id': '11403f795c244cac83ab919e7e00dc6d',
#    'human_readable_id': 192,
#    'title': 'SECOND WOMAN',
#    'community': 4,
#    'level': 0,
#    'degree': 2,
#    'x': 3.3423986434936523,
#    'y': 0.03131604194641113}},
#  {'id': 'MAN IN FADED BLACK',
#   'properties': {'id': '38b30e2fe917450989de4104327fae0d',
#    'human_readable_id': 193,
#    'title': 'MAN IN FADED BLACK',
#    'community': 4,
#    'level': 0,
#    'degree': 2,
#    'x': 4.4230499267578125,
#    'y': -0.5153181552886963}},
#  {'id': 'OLD JOE',
#   'properties': {'id': 'dd038db7190f4fe9a2abb9aadf45808b',
#    'human_readable_id': 194,
#    'title': 'OLD JOE',
#    'community': 4,
#    'level': 0,
#    'degree': 7,
#    'x': 2.063711404800415,
#    'y': -0.24053682386875153}},
#  {'id': 'PARLOUR',
#   'properties': {'id': '655d7b2eb89948b5b7b4853ebd881665',
#    'human_readable_id': 195,
#    'title': 'PARLOUR',
#    'community': 4,
#    'level': 0,
#    'degree': 1,
#    'x': 2.7754385471343994,
#    'y': 0.5830840468406677}},
#  {'id': 'LAUNDRESS',
#   'properties': {'id': 'cce4c8578e3b4ca7ac6cb03c33dc9813',
#    'human_readable_id': 196,
#    'title': 'LAUNDRESS',
#    'community': 4,
#    'level': 0,
#    'degree': 3,
#    'x': 1.587613582611084,
#    'y': -0.09810532629489899}},
#  {'id': "UNDERTAKER'S MAN",
#   'properties': {'id': 'fc4e0665f6374672a2fe1951bdd3f829',
#    'human_readable_id': 197,
#    'title': "UNDERTAKER'S MAN",
#    'community': 4,
#    'level': 0,
#    'degree': 3,
#    'x': 1.4627156257629395,
#    'y': -0.4950934052467346}},
#  {'id': 'CHARWOMAN',
#   'properties': {'id': '656dc4d549a74b7492232de73df31802',
#    'human_readable_id': 198,
#    'title': 'CHARWOMAN',
#    'community': 4,
#    'level': 0,
#    'degree': 3,
#    'x': 1.4150996208190918,
#    'y': -0.07730633020401001}},
#  {'id': "CAROLINE'S HUSBAND",
#   'properties': {'id': 'e7394767c46c4cf187ebb144ada00564',
#    'human_readable_id': 199,
#    'title': "CAROLINE'S HUSBAND",
#    'community': 6,
#    'level': 0,
#    'degree': 4,
#    'x': 1.4233381748199463,
#    'y': 14.984020233154297}},
#  {'id': 'HALF-DRUNKEN WOMAN',
#   'properties': {'id': 'fb5c3f8f24e54e329fac12208336ffe6',
#    'human_readable_id': 200,
#    'title': 'HALF-DRUNKEN WOMAN',
#    'community': 6,
#    'level': 0,
#    'degree': 2,
#    'x': 1.5006544589996338,
#    'y': 14.907233238220215}},
#  {'id': 'THE MAN',
#   'properties': {'id': 'f8ee38bcb37f4b92be9db2fc6cfaff6e',
#    'human_readable_id': 201,
#    'title': 'THE MAN',
#    'community': 6,
#    'level': 0,
#    'degree': 2,
#    'x': 1.3018600940704346,
#    'y': 15.10883903503418}},
#  {'id': 'DEATH',
#   'properties': {'id': '01505a7c5e3e4b1c978016e6a2020f27',
#    'human_readable_id': 202,
#    'title': 'DEATH',
#    'community': 6,
#    'level': 0,
#    'degree': 4,
#    'x': 0.9467031955718994,
#    'y': 15.46237564086914}},
#  {'id': "MR. SCROOGE'S NEPHEW",
#   'properties': {'id': '317de596b79c401cb6a73e5073a6b6ed',
#    'human_readable_id': 203,
#    'title': "MR. SCROOGE'S NEPHEW",
#    'community': 2,
#    'level': 0,
#    'degree': 3,
#    'x': 16.908906936645508,
#    'y': 7.624209403991699}},
#  {'id': 'CHURCHYARD',
#   'properties': {'id': 'c0d4ef2502bb4d428241a2f34c99752d',
#    'human_readable_id': 204,
#    'title': 'CHURCHYARD',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 9.480002403259277,
#    'y': -5.019212245941162}},
#  {'id': 'BOY IN SUNDAY CLOTHES',
#   'properties': {'id': 'ffcb75801b0a4885aa444c93fb0680cd',
#    'human_readable_id': 205,
#    'title': 'BOY IN SUNDAY CLOTHES',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 10.824423789978027,
#    'y': -3.45099139213562}},
#  {'id': 'JOE MILLER',
#   'properties': {'id': 'becaebd5ae8e4c0981e67f34539b0d3c',
#    'human_readable_id': 206,
#    'title': 'JOE MILLER',
#    'community': -1,
#    'level': 0,
#    'degree': 0,
#    'x': None,
#    'y': None}},
#  {'id': "THE POULTERER'S",
#   'properties': {'id': 'db870c9e44834159a707535acb201bc6',
#    'human_readable_id': 207,
#    'title': "THE POULTERER'S",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.552112579345703,
#    'y': -0.5194995403289795}},
#  {'id': 'THE GHOST OF CHRISTMAS PRESENT',
#   'properties': {'id': '72fd931167ee4c2b9cc367cfeccfd786',
#    'human_readable_id': 208,
#    'title': 'THE GHOST OF CHRISTMAS PRESENT',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 14.933066368103027,
#    'y': 0.5427278280258179}},
#  {'id': "SCROOGE AND MARLEY'S",
#   'properties': {'id': '9efdb8d321d5445e9dfea1fa29a1b173',
#    'human_readable_id': 209,
#    'title': "SCROOGE AND MARLEY'S",
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 14.647850036621094,
#    'y': 1.2878434658050537}},
#  {'id': 'THE PORTLY GENTLEMAN',
#   'properties': {'id': 'c4e8ca318c6046a58ed833be1aa86732',
#    'human_readable_id': 210,
#    'title': 'THE PORTLY GENTLEMAN',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 16.623620986938477,
#    'y': 2.7949020862579346}},
#  {'id': 'THE BOY',
#   'properties': {'id': 'ea84881a96d644c5884e6675ee1ff591',
#    'human_readable_id': 211,
#    'title': 'THE BOY',
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 8.075386047363281,
#    'y': -3.995177745819092}},
#  {'id': 'OFFICE',
#   'properties': {'id': '3ce8510deb354206b7dbcbd0f7b0d8b8',
#    'human_readable_id': 212,
#    'title': 'OFFICE',
#    'community': 1,
#    'level': 0,
#    'degree': 2,
#    'x': 14.349294662475586,
#    'y': 1.019740104675293}},
#  {'id': "NEPHEW'S HOUSE",
#   'properties': {'id': '1351e738a2d84f7cbf27734dd86ec10b',
#    'human_readable_id': 213,
#    'title': "NEPHEW'S HOUSE",
#    'community': 1,
#    'level': 0,
#    'degree': 1,
#    'x': 15.178711891174316,
#    'y': 1.6861146688461304}},
#  {'id': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'properties': {'id': 'cdc960b51aee454aac0468b8568d3ae0',
#    'human_readable_id': 214,
#    'title': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'community': 8,
#    'level': 0,
#    'degree': 8,
#    'x': -2.4301159381866455,
#    'y': 17.593013763427734}},
#  {'id': 'WWW.GUTENBERG.ORG',
#   'properties': {'id': 'd27215aa34204d8794c8a5ea7fb9459f',
#    'human_readable_id': 215,
#    'title': 'WWW.GUTENBERG.ORG',
#    'community': 8,
#    'level': 0,
#    'degree': 1,
#    'x': 19.36341094970703,
#    'y': 8.2623929977417}},
#  {'id': 'PROJECT GUTENBERG™',
#   'properties': {'id': 'fc18d39cb306425f97dbc98e67477b71',
#    'human_readable_id': 216,
#    'title': 'PROJECT GUTENBERG™',
#    'community': 8,
#    'level': 0,
#    'degree': 5,
#    'x': -17.540855407714844,
#    'y': -16.454866409301758}},
#  {'id': 'RIGHT OF REPLACEMENT OR REFUND',
#   'properties': {'id': '86bd766291de4dfb8438ac505c327a8c',
#    'human_readable_id': 217,
#    'title': 'RIGHT OF REPLACEMENT OR REFUND',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -18.338850021362305,
#    'y': -17.250797271728516}},
#  {'id': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#   'properties': {'id': '7d8eb17010dc4eb49da67cc8e357e171',
#    'human_readable_id': 218,
#    'title': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -18.0080623626709,
#    'y': -16.909927368164062}},
#  {'id': 'INDEMNITY',
#   'properties': {'id': '756ba1081f75405dbb6e6ad482e3e417',
#    'human_readable_id': 219,
#    'title': 'INDEMNITY',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -17.838300704956055,
#    'y': -16.75006675720215}},
#  {'id': 'U.S. COPYRIGHT LAW',
#   'properties': {'id': '831c8b2a06cf403bbcdf7fbad7e55f2c',
#    'human_readable_id': 220,
#    'title': 'U.S. COPYRIGHT LAW',
#    'community': 8,
#    'level': 0,
#    'degree': 1,
#    'x': -18.015913009643555,
#    'y': -16.927223205566406}},
#  {'id': 'INTERNAL REVENUE SERVICE',
#   'properties': {'id': 'ab5f859905df47deb7dce3fad43e3a84',
#    'human_readable_id': 221,
#    'title': 'INTERNAL REVENUE SERVICE',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -1.695879340171814,
#    'y': 17.257104873657227}},
#  {'id': 'MISSISSIPPI',
#   'properties': {'id': '51786a53a4e94b53b7c01ce9d74bb9c3',
#    'human_readable_id': 222,
#    'title': 'MISSISSIPPI',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -1.4560695886611938,
#    'y': 17.618587493896484}},
#  {'id': 'SALT LAKE CITY',
#   'properties': {'id': '5856cc0228fa4101962730baf7d15892',
#    'human_readable_id': 223,
#    'title': 'SALT LAKE CITY',
#    'community': 8,
#    'level': 0,
#    'degree': 2,
#    'x': -1.264572262763977,
#    'y': 17.853330612182617}},
#  {'id': 'MICHAEL S. HART',
#   'properties': {'id': '76f71716f34c4221b6842fdc33f7b8ab',
#    'human_readable_id': 224,
#    'title': 'MICHAEL S. HART',
#    'community': 8,
#    'level': 0,
#    'degree': 1,
#    'x': 19.87111473083496,
#    'y': 8.777139663696289}},
#  {'id': 'PROFESSOR MICHAEL S. HART',
#   'properties': {'id': '55979c145edf48e7877b3991b1e9f12c',
#    'human_readable_id': 225,
#    'title': 'PROFESSOR MICHAEL S. HART',
#    'community': 8,
#    'level': 0,
#    'degree': 1,
#    'x': -1.1370015144348145,
#    'y': 17.173871994018555}},
#  {'id': 'U.S.',
#   'properties': {'id': 'daf6294d55eb45ee82a26407b59c8caf',
#    'human_readable_id': 226,
#    'title': 'U.S.',
#    'community': 8,
#    'level': 0,
#    'degree': 1,
#    'x': 19.56641387939453,
#    'y': 8.43437385559082}},
#  {'id': 'FOUNDATION',
#   'properties': {'id': '75ad3bb83f21431696e5e61883149e30',
#    'human_readable_id': 227,
#    'title': 'FOUNDATION',
#    'community': 8,
#    'level': 0,
#    'degree': 5,
#    'x': -2.2613887786865234,
#    'y': 17.48116683959961}}]

# %%
# Hacemos lo propio con las relaciones
relationships_dict = convert_relationships_to_dicts(relationship_df)
relationships_dict
# Out:
# [{'start': 'PROJECT GUTENBERG',
#   'end': 'A CHRISTMAS CAROL',
#   'properties': {'id': '27f628f3ac9e44cfb4fba4efb6104d88',
#    'human_readable_id': 0,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'A CHRISTMAS CAROL',
#    'description': 'Project Gutenberg released the eBook version of A Christmas Carol',
#    'weight': 1.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'UNITED STATES',
#   'properties': {'id': '40c306c8012c4f499359a608dcb020e7',
#    'human_readable_id': 1,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'UNITED STATES',
#    'description': 'Project Gutenberg, a collection of individual works, is predominantly composed of materials that are in the public domain in the United States. This means that the works within Project Gutenberg are not protected by copyright law in the United States.',
#    'weight': 2.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['2b5ecb7fba1301d1f3d307e194a6c435',
#           'aa8d2310a206001404282ddb3fd645aa'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'properties': {'id': '74294f1a9ee947d8879a245e1c19d5e8',
#    'human_readable_id': 2,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'description': 'The Project Gutenberg Literary Archive Foundation, which owns a compilation copyright in the collection of Project Gutenberg electronic works, was created to provide a secure and permanent future for Project Gutenberg.',
#    'weight': 19.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['aa8d2310a206001404282ddb3fd645aa',
#           'cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'WWW.GUTENBERG.ORG',
#   'properties': {'id': 'e74897d5b27a48cdbc346676663a269a',
#    'human_readable_id': 3,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'WWW.GUTENBERG.ORG',
#    'description': "Project Gutenberg's works are posted and can be accessed on www.gutenberg.org.",
#    'weight': 1.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['aa8d2310a206001404282ddb3fd645aa'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'MICHAEL S. HART',
#   'properties': {'id': '348a412fd97a40aea938af6e5f34d0d9',
#    'human_readable_id': 4,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'MICHAEL S. HART',
#    'description': 'Michael S. Hart was the originator of the Project Gutenberg concept',
#    'weight': 1.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'FOUNDATION',
#   'properties': {'id': 'b4503b731f2c4225adb0ce4483a9186d',
#    'human_readable_id': 5,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'FOUNDATION',
#    'description': 'The Foundation was created to provide a secure and permanent future for Project Gutenberg',
#    'weight': 9.0,
#    'combined_degree': 12,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG',
#   'end': 'PROFESSOR MICHAEL S. HART',
#   'properties': {'id': '4928c7ad1165494292a39b0eed069dc4',
#    'human_readable_id': 6,
#    'source': 'PROJECT GUTENBERG',
#    'target': 'PROFESSOR MICHAEL S. HART',
#    'description': 'Professor Michael S. Hart was the originator of the Project Gutenberg concept',
#    'weight': 8.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'UNITED STATES',
#   'end': 'SCROOGE',
#   'properties': {'id': 'ac347464a74f478b89a18d997307ce00',
#    'human_readable_id': 7,
#    'source': 'UNITED STATES',
#    'target': 'SCROOGE',
#    'description': "Scrooge's financial dealings are compared to a United States security",
#    'weight': 1.0,
#    'combined_degree': 125,
#    'text_unit_ids': array(['8435b078474636a989a8c22f5493e1b6'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'CHARLES DICKENS',
#   'properties': {'id': '2a238fb19702455ea908bc7f6cb646ba',
#    'human_readable_id': 8,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'CHARLES DICKENS',
#    'description': 'Charles Dickens is the author of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'ARTHUR RACKHAM',
#   'properties': {'id': '7ce4b0c4ced84a5cbfb5d689b76dd463',
#    'human_readable_id': 9,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'ARTHUR RACKHAM',
#    'description': 'Arthur Rackham is the illustrator of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'J. B. LIPPINCOTT COMPANY',
#   'properties': {'id': '6b62957820284e01b5dddab42da62c14',
#    'human_readable_id': 10,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'J. B. LIPPINCOTT COMPANY',
#    'description': 'J. B. Lippincott Company is the original publisher of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'SUZANNE SHELL',
#   'properties': {'id': 'f04cb909b8264316956780a5aff3e7ab',
#    'human_readable_id': 11,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'SUZANNE SHELL',
#    'description': 'Suzanne Shell is a producer of the eBook version of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'JANET BLENKINSHIP',
#   'properties': {'id': '520e5b61d354470da4057726eb3c2e55',
#    'human_readable_id': 12,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'JANET BLENKINSHIP',
#    'description': 'Janet Blenkinship is a producer of the eBook version of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'ONLINE DISTRIBUTED PROOFREADING TEAM',
#   'properties': {'id': 'c1e5881730ca4132a03d6ca9be155fbd',
#    'human_readable_id': 13,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'ONLINE DISTRIBUTED PROOFREADING TEAM',
#    'description': 'The Online Distributed Proofreading Team helped produce the eBook version of A Christmas Carol',
#    'weight': 10.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'A CHRISTMAS CAROL',
#   'end': 'SCROOGE',
#   'properties': {'id': 'ad0b90d08e2f48d8856e0cc5ce720a53',
#    'human_readable_id': 14,
#    'source': 'A CHRISTMAS CAROL',
#    'target': 'SCROOGE',
#    'description': 'Scrooge is the main character in A Christmas Carol who changes his ways',
#    'weight': 1.0,
#    'combined_degree': 131,
#    'text_unit_ids': array(['2b5ecb7fba1301d1f3d307e194a6c435'], dtype=object)}},
#  {'start': 'PETER CRATCHIT',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': '86eecbc0e64d44d8a9f161e6c7d9e528',
#    'human_readable_id': 15,
#    'source': 'PETER CRATCHIT',
#    'target': 'BOB CRATCHIT',
#    'description': 'Peter Cratchit is the son of Bob Cratchit.',
#    'weight': 20.0,
#    'combined_degree': 25,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae',
#           'd6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'PETER CRATCHIT',
#   'end': 'MRS. CRATCHIT',
#   'properties': {'id': 'baabb058259b4ea983f6258f459de0f2',
#    'human_readable_id': 16,
#    'source': 'PETER CRATCHIT',
#    'target': 'MRS. CRATCHIT',
#    'description': 'Peter Cratchit is the son of Mrs. Cratchit',
#    'weight': 10.0,
#    'combined_degree': 17,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'PETER CRATCHIT',
#   'end': 'CHRISTMAS DAY',
#   'properties': {'id': 'f900b22bd4904e8896d26ca35a42f5c9',
#    'human_readable_id': 17,
#    'source': 'PETER CRATCHIT',
#    'target': 'CHRISTMAS DAY',
#    'description': 'The story of Peter Cratchit takes place on Christmas Day',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'TIM CRATCHIT',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': '7661c462c78b48be9f9d9f6a4b94147e',
#    'human_readable_id': 18,
#    'source': 'TIM CRATCHIT',
#    'target': 'BOB CRATCHIT',
#    'description': 'Tim Cratchit is the youngest son of Bob Cratchit',
#    'weight': 10.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'MR. FEZZIWIG',
#   'end': 'MRS. FEZZIWIG',
#   'properties': {'id': 'c115f823d8cb4060a09352bd9d912bae',
#    'human_readable_id': 19,
#    'source': 'MR. FEZZIWIG',
#    'target': 'MRS. FEZZIWIG',
#    'description': 'Mrs. Fezziwig is the wife of Mr. Fezziwig',
#    'weight': 1.0,
#    'combined_degree': 5,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'EBENEZER SCROOGE',
#   'properties': {'id': 'cc2cdab573904a9cb0efb55df3d93eef',
#    'human_readable_id': 20,
#    'source': 'FRED',
#    'target': 'EBENEZER SCROOGE',
#    'description': "Fred is Scrooge's nephew",
#    'weight': 10.0,
#    'combined_degree': 19,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'SCROOGE',
#   'properties': {'id': 'bbd1bb9e7bca472e80b37960694a882f',
#    'human_readable_id': 21,
#    'source': 'FRED',
#    'target': 'SCROOGE',
#    'description': "Scrooge is Fred's uncle, a relationship confirmed by Scrooge's own statement. They share a close bond, often spending time together. This includes visiting for dinner and engaging in playful activities such as games.",
#    'weight': 16.0,
#    'combined_degree': 130,
#    'text_unit_ids': array(['04e5c071e4ee5496d5380662e1339f45',
#           '10730234d6ccc7cee08f3cfc58d8a9a1',
#           '61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'UNCLE SCROOGE',
#   'properties': {'id': '14579249ca8e4359a66c730891e864ef',
#    'human_readable_id': 22,
#    'source': 'FRED',
#    'target': 'UNCLE SCROOGE',
#    'description': 'Fred refers to Scrooge as Uncle Scrooge',
#    'weight': 5.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'THE PLUMP SISTER',
#   'properties': {'id': 'e4a8196deda141668299e353a285df68',
#    'human_readable_id': 23,
#    'source': 'FRED',
#    'target': 'THE PLUMP SISTER',
#    'description': 'Fred is playing a game with the plump sister',
#    'weight': 6.0,
#    'combined_degree': 12,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'CHRISTMAS',
#   'properties': {'id': '4bd2822388b34ec8ba9e30a341d15366',
#    'human_readable_id': 24,
#    'source': 'FRED',
#    'target': 'CHRISTMAS',
#    'description': 'Fred is celebrating Christmas in the text',
#    'weight': 4.0,
#    'combined_degree': 16,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'YES AND NO',
#   'properties': {'id': 'd2ec050a506c476b97f2d85692a1bb69',
#    'human_readable_id': 25,
#    'source': 'FRED',
#    'target': 'YES AND NO',
#    'description': 'Fred is playing the game Yes and No with the others',
#    'weight': 7.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'FRED',
#   'end': 'MULLED WINE',
#   'properties': {'id': '07db3cf4430d44dcb25c2bea515b3806',
#    'human_readable_id': 26,
#    'source': 'FRED',
#    'target': 'MULLED WINE',
#    'description': 'Fred proposes a toast to Uncle Scrooge with the mulled wine',
#    'weight': 6.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'GHOST OF CHRISTMAS PAST',
#   'end': 'SCROOGE',
#   'properties': {'id': '059f09b2659a4f729fd754c41750d5d3',
#    'human_readable_id': 27,
#    'source': 'GHOST OF CHRISTMAS PAST',
#    'target': 'SCROOGE',
#    'description': "The Ghost of Christmas Past visits Scrooge, showing him scenes from his past Christmases. This spectral entity's purpose is to provide Scrooge with a glimpse into his own history, allowing him to reflect on his past actions and decisions.",
#    'weight': 19.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['3763b08136628f77304cb4eb1136ea48',
#           '4cf4deeb7f61acb7b7db4ce0e57fb1e6'], dtype=object)}},
#  {'start': 'GHOST OF CHRISTMAS PRESENT',
#   'end': 'SCROOGE',
#   'properties': {'id': '7d2d86bc935649748c39ddb4941e4be2',
#    'human_readable_id': 28,
#    'source': 'GHOST OF CHRISTMAS PRESENT',
#    'target': 'SCROOGE',
#    'description': 'The Ghost of Christmas Present visits Scrooge to provide him with a glimpse into the present Christmas. This spectral entity guides Scrooge through scenes from his current life, specifically focusing on events occurring during the current Christmas season.',
#    'weight': 27.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['0f9b4e5a7cfc0c3c89a8898a45383588',
#           '4cf4deeb7f61acb7b7db4ce0e57fb1e6',
#           '77ae3762a0b062ca5350ea54a05450ae'], dtype=object)}},
#  {'start': 'GHOST OF CHRISTMAS YET TO COME',
#   'end': 'SCROOGE',
#   'properties': {'id': 'c4f45971c22c472e8375f4f6d3c05799',
#    'human_readable_id': 29,
#    'source': 'GHOST OF CHRISTMAS YET TO COME',
#    'target': 'SCROOGE',
#    'description': "The Ghost of Christmas Yet to Come, also known as the Spirit, is a spectral entity that plays a significant role in Scrooge's life. This ghost is responsible for showing Scrooge visions of the future, providing him with a glimpse into what lies ahead.",
#    'weight': 18.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['19f8fd68a8dbc1bba7058e13ce3a2e3d',
#           '98f3970b31dfa1d7391cdaa453d6ade7'], dtype=object)}},
#  {'start': 'GHOST OF JACOB MARLEY',
#   'end': 'EBENEZER SCROOGE',
#   'properties': {'id': 'a71e256151f64f588f6d0b073a531c5b',
#    'human_readable_id': 30,
#    'source': 'GHOST OF JACOB MARLEY',
#    'target': 'EBENEZER SCROOGE',
#    'description': "The Ghost of Jacob Marley is a spectre of Scrooge's former partner in business",
#    'weight': 10.0,
#    'combined_degree': 14,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'GHOST OF JACOB MARLEY',
#   'end': 'SCROOGE',
#   'properties': {'id': 'bdb536fca4424dee8e8fa28c6103a165',
#    'human_readable_id': 31,
#    'source': 'GHOST OF JACOB MARLEY',
#    'target': 'SCROOGE',
#    'description': 'The ghost of Jacob Marley visits Scrooge',
#    'weight': 10.0,
#    'combined_degree': 125,
#    'text_unit_ids': array(['0f9b4e5a7cfc0c3c89a8898a45383588'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': '5690b7ae4b5c4ad9b8a403eb458de263',
#    'human_readable_id': 32,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'BOB CRATCHIT',
#    'description': 'Bob Cratchit is a clerk to Ebenezer Scrooge',
#    'weight': 10.0,
#    'combined_degree': 34,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'DICK WILKINS',
#   'properties': {'id': '3528c2ba352847be9b9b06c1756bb7a1',
#    'human_readable_id': 33,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'DICK WILKINS',
#    'description': "Ebenezer Scrooge and Dick Wilkins are fellow apprentices. They work together under the same employer, Fezziwig. Dick Wilkins is specifically identified as a fellow apprentice of Scrooge's, indicating a close working relationship between the two.",
#    'weight': 17.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d',
#           'd6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'BELLE',
#   'properties': {'id': 'fcf4d46f529e4e47a3a4af65761fd197',
#    'human_readable_id': 34,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'BELLE',
#    'description': "Belle is an old sweetheart of Scrooge's",
#    'weight': 10.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'CAROLINE',
#   'properties': {'id': '293333ff826345d4829269755c461c6c',
#    'human_readable_id': 35,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'CAROLINE',
#    'description': "Caroline is the wife of one of Scrooge's debtors",
#    'weight': 10.0,
#    'combined_degree': 17,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'FAN',
#   'properties': {'id': '9114fce3a9e945aa8e7ded44b868d392',
#    'human_readable_id': 36,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'FAN',
#    'description': 'Fan is the sister of Scrooge',
#    'weight': 10.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'JACOB MARLEY',
#   'properties': {'id': '0f7af7b7a6ed4c94ae7c272e2e339fb2',
#    'human_readable_id': 37,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'JACOB MARLEY',
#    'description': 'Jacob Marley visits Ebenezer Scrooge to warn him about his life choices',
#    'weight': 8.0,
#    'combined_degree': 14,
#    'text_unit_ids': array(['e3bef9514042131cf477476725497416'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'THE GHOST',
#   'properties': {'id': '2929c3e4ebe948e0b35110aea982a439',
#    'human_readable_id': 38,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'THE GHOST',
#    'description': 'The Ghost, who is Jacob Marley, visits Ebenezer Scrooge to warn him about his life choices',
#    'weight': 1.0,
#    'combined_degree': 25,
#    'text_unit_ids': array(['e3bef9514042131cf477476725497416'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'FEZZIWIG',
#   'properties': {'id': '70e29d3722244902aa91d5dc91935dd1',
#    'human_readable_id': 39,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'FEZZIWIG',
#    'description': 'Fezziwig is the employer of Ebenezer Scrooge',
#    'weight': 8.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'CHRISTMAS EVE PARTY',
#   'properties': {'id': 'b3a2be1c9a61439985448661a2c2bdbb',
#    'human_readable_id': 40,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'CHRISTMAS EVE PARTY',
#    'description': 'Ebenezer Scrooge is a guest at the Christmas Eve party',
#    'weight': 6.0,
#    'combined_degree': 24,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'EBENEZER SCROOGE',
#   'end': 'SCROOGE',
#   'properties': {'id': '6b862dff33d94d6cb19e1d0cfd98e44b',
#    'human_readable_id': 41,
#    'source': 'EBENEZER SCROOGE',
#    'target': 'SCROOGE',
#    'description': 'Scrooge and Ebenezer Scrooge are the same person',
#    'weight': 1.0,
#    'combined_degree': 135,
#    'text_unit_ids': array(['19f8fd68a8dbc1bba7058e13ce3a2e3d'], dtype=object)}},
#  {'start': 'DICK WILKINS',
#   'end': 'FEZZIWIG',
#   'properties': {'id': 'dad3599e319544c9914ea474ed78da40',
#    'human_readable_id': 42,
#    'source': 'DICK WILKINS',
#    'target': 'FEZZIWIG',
#    'description': 'Fezziwig is the employer of Dick Wilkins',
#    'weight': 8.0,
#    'combined_degree': 14,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'DICK WILKINS',
#   'end': 'CHRISTMAS EVE PARTY',
#   'properties': {'id': '3f32481292964deb90d5efcb5a6a47d7',
#    'human_readable_id': 43,
#    'source': 'DICK WILKINS',
#    'target': 'CHRISTMAS EVE PARTY',
#    'description': 'Dick Wilkins is a guest at the Christmas Eve party',
#    'weight': 6.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'BELLE',
#   'end': 'SCROOGE',
#   'properties': {'id': '7d03862b31a046b9aef3edb97051a48c',
#    'human_readable_id': 44,
#    'source': 'BELLE',
#    'target': 'SCROOGE',
#    'description': "Belle is mentioned as an old friend of Scrooge's by her husband",
#    'weight': 3.0,
#    'combined_degree': 126,
#    'text_unit_ids': array(['c79e67fc6f74a9afbe79c158000cc71b'], dtype=object)}},
#  {'start': 'BELLE',
#   'end': 'THE HUSBAND',
#   'properties': {'id': '2bf8bfae60f44041ab408ec594ec83b8',
#    'human_readable_id': 45,
#    'source': 'BELLE',
#    'target': 'THE HUSBAND',
#    'description': 'The husband and Belle are married',
#    'weight': 10.0,
#    'combined_degree': 5,
#    'text_unit_ids': array(['c79e67fc6f74a9afbe79c158000cc71b'], dtype=object)}},
#  {'start': 'CAROLINE',
#   'end': "CAROLINE'S HUSBAND",
#   'properties': {'id': '399068a990bb4a8ba69c50abc7415313',
#    'human_readable_id': 46,
#    'source': 'CAROLINE',
#    'target': "CAROLINE'S HUSBAND",
#    'description': 'Caroline and her husband are in a relationship and discuss their financial situation together',
#    'weight': 9.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': 'CAROLINE',
#   'end': 'HALF-DRUNKEN WOMAN',
#   'properties': {'id': '41df0cb418694bbc850eba6c0ff7acc1',
#    'human_readable_id': 47,
#    'source': 'CAROLINE',
#    'target': 'HALF-DRUNKEN WOMAN',
#    'description': 'The half-drunken woman is mentioned in a conversation between Caroline and her husband',
#    'weight': 2.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': 'CAROLINE',
#   'end': 'DEATH',
#   'properties': {'id': '1c08d6e34086461aa42a1c544bd3d7b5',
#    'human_readable_id': 48,
#    'source': 'CAROLINE',
#    'target': 'DEATH',
#    'description': "Caroline is relieved by the man's death as it alleviates her debt",
#    'weight': 8.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': 'CAROLINE',
#   'end': 'THE MAN',
#   'properties': {'id': '4db158f4f9c54f9598a515a3d3a0ec5e',
#    'human_readable_id': 49,
#    'source': 'CAROLINE',
#    'target': 'THE MAN',
#    'description': "The man's death has a direct impact on Caroline's financial situation",
#    'weight': 9.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': '00b1ff2d90bf428ba03987884cef56f4',
#    'human_readable_id': 50,
#    'source': 'MRS. CRATCHIT',
#    'target': 'BOB CRATCHIT',
#    'description': "Bob Cratchit and Mrs. Cratchit are husband and wife, both part of the same family, the Cratchits. They work together, particularly in preparing the Christmas meal. Mrs. Cratchit is identified as Bob Cratchit's wife.",
#    'weight': 49.0,
#    'combined_degree': 36,
#    'text_unit_ids': array(['1bdf253855a115bcf51faa63d7b07e82',
#           '29793cee69d4eefd5fea8a5f2f27b521',
#           '5d70b47bf7167b7586f47fcc4355a746',
#           'b4dec8fbe9f2a2c6a79d09c9484d15ae',
#           'd6583840046247f428a9f02738842a7c',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'BELINDA CRATCHIT',
#   'properties': {'id': '547c0472f05a4c0cb381e3f513eb606e',
#    'human_readable_id': 51,
#    'source': 'MRS. CRATCHIT',
#    'target': 'BELINDA CRATCHIT',
#    'description': 'Belinda Cratchit is the daughter of Mrs. Cratchit',
#    'weight': 10.0,
#    'combined_degree': 17,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'TINY TIM',
#   'properties': {'id': '25c2910bc533492a8e8c38beeeb578c5',
#    'human_readable_id': 52,
#    'source': 'MRS. CRATCHIT',
#    'target': 'TINY TIM',
#    'description': "Mrs. Cratchit and Tiny Tim are part of the same family, known as the Cratchits. They work together to prepare the Christmas meal. Mrs. Cratchit is Tiny Tim's mother, and Tiny Tim is her son.",
#    'weight': 48.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['19f8fd68a8dbc1bba7058e13ce3a2e3d',
#           '1bdf253855a115bcf51faa63d7b07e82',
#           '5d70b47bf7167b7586f47fcc4355a746',
#           'b4dec8fbe9f2a2c6a79d09c9484d15ae',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'MARTHA',
#   'properties': {'id': '4c79f843731f43dca49d96e3ee048b4a',
#    'human_readable_id': 53,
#    'source': 'MRS. CRATCHIT',
#    'target': 'MARTHA',
#    'description': 'Martha is the daughter of Mrs. Cratchit. They are part of the same family and work together to prepare the Christmas meal.',
#    'weight': 18.0,
#    'combined_degree': 19,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746',
#           'b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'CHRISTMAS DAY',
#   'properties': {'id': '050334a272a047b989e287c026533fb0',
#    'human_readable_id': 54,
#    'source': 'MRS. CRATCHIT',
#    'target': 'CHRISTMAS DAY',
#    'description': 'The story of Mrs. Cratchit takes place on Christmas Day',
#    'weight': 5.0,
#    'combined_degree': 21,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'MASTER PETER',
#   'properties': {'id': '2be9804fc04b4b6f88ce08c4949d30a9',
#    'human_readable_id': 55,
#    'source': 'MRS. CRATCHIT',
#    'target': 'MASTER PETER',
#    'description': 'Mrs. Cratchit and Master Peter are part of the same family and work together to prepare the Christmas meal',
#    'weight': 8.0,
#    'combined_degree': 18,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'MISS BELINDA',
#   'properties': {'id': 'c2cc41e7fe26455bb4e3a5cc85c2803e',
#    'human_readable_id': 56,
#    'source': 'MRS. CRATCHIT',
#    'target': 'MISS BELINDA',
#    'description': 'Mrs. Cratchit and Miss Belinda are part of the same family and work together to prepare the Christmas meal',
#    'weight': 8.0,
#    'combined_degree': 16,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'THE TWO YOUNG CRATCHITS',
#   'properties': {'id': 'f879beb2ad6a4d589b3b5c837ba9fcad',
#    'human_readable_id': 57,
#    'source': 'MRS. CRATCHIT',
#    'target': 'THE TWO YOUNG CRATCHITS',
#    'description': 'Mrs. Cratchit and the two young Cratchits are part of the same family and work together to prepare the Christmas meal',
#    'weight': 8.0,
#    'combined_degree': 16,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'CHRISTMAS MEAL',
#   'properties': {'id': '8a8f8a6e52d84de0a744f25a86812104',
#    'human_readable_id': 58,
#    'source': 'MRS. CRATCHIT',
#    'target': 'CHRISTMAS MEAL',
#    'description': 'Mrs. Cratchit is responsible for the preparation of the Christmas meal',
#    'weight': 9.0,
#    'combined_degree': 21,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'SCROOGE',
#   'properties': {'id': '6d036c2276714c2fbcf71763af217140',
#    'human_readable_id': 59,
#    'source': 'MRS. CRATCHIT',
#    'target': 'SCROOGE',
#    'description': "Mrs. Cratchit and Scrooge have an indirect connection through Bob Cratchit, who is Scrooge's employee and Mrs. Cratchit's husband. However, their relationship is marked by negativity as Mrs. Cratchit has expressed disdain for Scrooge.",
#    'weight': 7.0,
#    'combined_degree': 137,
#    'text_unit_ids': array(['1bdf253855a115bcf51faa63d7b07e82',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'PETER',
#   'properties': {'id': '4cb57bb434374823aaae0c8c80467e98',
#    'human_readable_id': 60,
#    'source': 'MRS. CRATCHIT',
#    'target': 'PETER',
#    'description': 'Mrs. Cratchit is the mother of Peter, who is her son.',
#    'weight': 20.0,
#    'combined_degree': 21,
#    'text_unit_ids': array(['19f8fd68a8dbc1bba7058e13ce3a2e3d',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'THE GHOST',
#   'properties': {'id': '7f5fed3cb7644cb1bbdb368bc60db2be',
#    'human_readable_id': 61,
#    'source': 'MRS. CRATCHIT',
#    'target': 'THE GHOST',
#    'description': "The Ghost shows Scrooge a scene from Mrs. Cratchit's house.",
#    'weight': 3.0,
#    'combined_degree': 27,
#    'text_unit_ids': array(['f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'MRS. CRATCHIT',
#   'end': 'BOB',
#   'properties': {'id': 'e440ea1af916453c8b4392b919357452',
#    'human_readable_id': 62,
#    'source': 'MRS. CRATCHIT',
#    'target': 'BOB',
#    'description': "Bob is Mrs. Cratchit's husband",
#    'weight': 10.0,
#    'combined_degree': 18,
#    'text_unit_ids': array(['19f8fd68a8dbc1bba7058e13ce3a2e3d'], dtype=object)}},
#  {'start': 'BELINDA CRATCHIT',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': 'bd8580b4c0d84b11ac071bd87f5a6167',
#    'human_readable_id': 63,
#    'source': 'BELINDA CRATCHIT',
#    'target': 'BOB CRATCHIT',
#    'description': 'Belinda Cratchit is the daughter of Bob Cratchit.',
#    'weight': 20.0,
#    'combined_degree': 25,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae',
#           'd6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'BELINDA CRATCHIT',
#   'end': 'CHRISTMAS DAY',
#   'properties': {'id': 'ced9a7d9baeb4e3ba110cf10b2cabeb4',
#    'human_readable_id': 64,
#    'source': 'BELINDA CRATCHIT',
#    'target': 'CHRISTMAS DAY',
#    'description': 'The story of Belinda Cratchit takes place on Christmas Day',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'MARTHA CRATCHIT',
#   'end': 'BOB CRATCHIT',
#   'properties': {'id': 'f04f995f4ce54013a018d5cf7fd5e6bb',
#    'human_readable_id': 65,
#    'source': 'MARTHA CRATCHIT',
#    'target': 'BOB CRATCHIT',
#    'description': 'Martha Cratchit is a daughter of Bob Cratchit',
#    'weight': 10.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['d6583840046247f428a9f02738842a7c'], dtype=object)}},
#  {'start': 'MRS. DILBER',
#   'end': 'WOMAN',
#   'properties': {'id': 'f444bcc99b984801b609a29333ffe590',
#    'human_readable_id': 66,
#    'source': 'MRS. DILBER',
#    'target': 'WOMAN',
#    'description': 'Mrs. Dilber and the woman have a conversation in the shop',
#    'weight': 6.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'MRS. DILBER',
#   'end': 'SECOND WOMAN',
#   'properties': {'id': '67afcbc0e52b4c1ebf66e3e0513a4dc0',
#    'human_readable_id': 67,
#    'source': 'MRS. DILBER',
#    'target': 'SECOND WOMAN',
#    'description': 'Mrs. Dilber and the second woman have a conversation in the shop',
#    'weight': 6.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'MRS. DILBER',
#   'end': 'MAN IN FADED BLACK',
#   'properties': {'id': '31984d28e72f46e0bc8af9682e60950d',
#    'human_readable_id': 68,
#    'source': 'MRS. DILBER',
#    'target': 'MAN IN FADED BLACK',
#    'description': 'Mrs. Dilber and the man in faded black have a conversation in the shop',
#    'weight': 1.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'MRS. DILBER',
#   'end': 'OLD JOE',
#   'properties': {'id': 'a44e72e2971346cd8c1d04b372110cbb',
#    'human_readable_id': 69,
#    'source': 'MRS. DILBER',
#    'target': 'OLD JOE',
#    'description': 'Old Joe and Mrs. Dilber are interacting in a transaction where Mrs. Dilber is selling items to Old Joe',
#    'weight': 7.0,
#    'combined_degree': 12,
#    'text_unit_ids': array(['bc606176c752984da6d202275ee8c7a6'], dtype=object)}},
#  {'start': 'MRS. DILBER',
#   'end': 'SCROOGE',
#   'properties': {'id': '05238f2d694241e599197d417ba072bb',
#    'human_readable_id': 70,
#    'source': 'MRS. DILBER',
#    'target': 'SCROOGE',
#    'description': "Scrooge is observing Mrs. Dilber's actions with disgust",
#    'weight': 3.0,
#    'combined_degree': 128,
#    'text_unit_ids': array(['bc606176c752984da6d202275ee8c7a6'], dtype=object)}},
#  {'start': 'FAN',
#   'end': 'SCROOGE',
#   'properties': {'id': '662b384e80e74ea6a6b5c5bbb1a9785a',
#    'human_readable_id': 71,
#    'source': 'FAN',
#    'target': 'SCROOGE',
#    'description': "Fan is Scrooge's younger sister who comes to bring him home for Christmas",
#    'weight': 8.0,
#    'combined_degree': 126,
#    'text_unit_ids': array(['ce95e4fc6ee410973c040fc628dce155'], dtype=object)}},
#  {'start': 'FAN',
#   'end': 'MASTER SCROOGE',
#   'properties': {'id': 'cdde5f3667c5405aaabd201c24a32a5e',
#    'human_readable_id': 72,
#    'source': 'FAN',
#    'target': 'MASTER SCROOGE',
#    'description': "Fan is Master Scrooge's younger sister who comes to bring him home for Christmas",
#    'weight': 8.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['ce95e4fc6ee410973c040fc628dce155'], dtype=object)}},
#  {'start': 'MRS. FEZZIWIG',
#   'end': 'FEZZIWIG',
#   'properties': {'id': '7943536f667640b79b7aec77eca9748a',
#    'human_readable_id': 73,
#    'source': 'MRS. FEZZIWIG',
#    'target': 'FEZZIWIG',
#    'description': 'Fezziwig and Mrs. Fezziwig are a married couple, as indicated by their shared surname and their frequent appearances together. They are often mentioned in the context of a dance, suggesting they enjoy participating in this activity together. In fact, they have been seen dancing together at a domestic ball, further confirming their close relationship and shared interests.',
#    'weight': 25.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['10730234d6ccc7cee08f3cfc58d8a9a1',
#           '260fb94666cbdfb08286ce8d8162130d',
#           'bf29edcb41403e5af43aa101072f4fdf'], dtype=object)}},
#  {'start': 'MRS. FEZZIWIG',
#   'end': 'CHRISTMAS EVE PARTY',
#   'properties': {'id': 'ba4face3e02a47c58a203896e3791ea6',
#    'human_readable_id': 74,
#    'source': 'MRS. FEZZIWIG',
#    'target': 'CHRISTMAS EVE PARTY',
#    'description': 'Mrs. Fezziwig is a guest at the Christmas Eve party',
#    'weight': 1.0,
#    'combined_degree': 16,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'MRS. FEZZIWIG',
#   'end': 'DOMESTIC BALL',
#   'properties': {'id': '0f5582bc437746ca81d7ce385837e752',
#    'human_readable_id': 75,
#    'source': 'MRS. FEZZIWIG',
#    'target': 'DOMESTIC BALL',
#    'description': 'Mrs. Fezziwig is the hostess of the domestic ball',
#    'weight': 8.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['bf29edcb41403e5af43aa101072f4fdf'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'SCROOGE',
#   'properties': {'id': '61abf241245747e2a6e53a9a69e75086',
#    'human_readable_id': 76,
#    'source': 'BOB CRATCHIT',
#    'target': 'SCROOGE',
#    'description': "Bob Cratchit is a clerk who works for Scrooge at the counting-house. Scrooge, who is Bob Cratchit's employer, frequently interacts with him at the office. In a generous act, Scrooge buys a turkey for Bob Cratchit and also promises to raise his salary and assist his family.",
#    'weight': 34.0,
#    'combined_degree': 145,
#    'text_unit_ids': array(['04e5c071e4ee5496d5380662e1339f45',
#           '29793cee69d4eefd5fea8a5f2f27b521',
#           '2b5ecb7fba1301d1f3d307e194a6c435',
#           '6c362d3f8d01c76d84443dcabf3f322a',
#           '7064df4af064aeb556e5bab52e896414',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'COUNTING-HOUSE',
#   'properties': {'id': '11f39f6528a744f9b2f5e08ab9f4d54f',
#    'human_readable_id': 77,
#    'source': 'BOB CRATCHIT',
#    'target': 'COUNTING-HOUSE',
#    'description': 'Bob Cratchit is a clerk at the counting-house',
#    'weight': 9.0,
#    'combined_degree': 24,
#    'text_unit_ids': array(['7064df4af064aeb556e5bab52e896414'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CORNHILL',
#   'properties': {'id': '0ebeb2b6bff440fa98045272b2a7e697',
#    'human_readable_id': 78,
#    'source': 'BOB CRATCHIT',
#    'target': 'CORNHILL',
#    'description': 'Bob Cratchit goes sliding on Cornhill on Christmas Eve',
#    'weight': 3.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['7064df4af064aeb556e5bab52e896414'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CAMDEN TOWN',
#   'properties': {'id': '274bd46eefe04274b2f8215029b21b58',
#    'human_readable_id': 79,
#    'source': 'BOB CRATCHIT',
#    'target': 'CAMDEN TOWN',
#    'description': "Bob Cratchit goes to Camden Town to play at blind man's-buff on Christmas Eve",
#    'weight': 3.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['7064df4af064aeb556e5bab52e896414'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CHRISTMAS EVE',
#   'properties': {'id': 'fa9ac85d3b624101a56a9171e41a7d8f',
#    'human_readable_id': 80,
#    'source': 'BOB CRATCHIT',
#    'target': 'CHRISTMAS EVE',
#    'description': 'Bob Cratchit celebrates Christmas Eve',
#    'weight': 1.0,
#    'combined_degree': 25,
#    'text_unit_ids': array(['7064df4af064aeb556e5bab52e896414'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'SPIRIT',
#   'properties': {'id': '148c80c297b841cea7f54b1d3ba6de91',
#    'human_readable_id': 81,
#    'source': 'BOB CRATCHIT',
#    'target': 'SPIRIT',
#    'description': "The Spirit bestows blessings upon Bob Cratchit's dwelling, which is also referred to as his house.",
#    'weight': 11.0,
#    'combined_degree': 27,
#    'text_unit_ids': array(['29793cee69d4eefd5fea8a5f2f27b521',
#           'b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'TINY TIM',
#   'properties': {'id': 'd209665873124a3e9b38c83317f741f8',
#    'human_readable_id': 82,
#    'source': 'BOB CRATCHIT',
#    'target': 'TINY TIM',
#    'description': 'Bob Cratchit and Tiny Tim are members of the same family, known as the Cratchits. Bob Cratchit is the father of Tiny Tim, and correspondingly, Tiny Tim is the son of Bob Cratchit.',
#    'weight': 31.0,
#    'combined_degree': 31,
#    'text_unit_ids': array(['1bdf253855a115bcf51faa63d7b07e82',
#           '5d70b47bf7167b7586f47fcc4355a746',
#           'b4dec8fbe9f2a2c6a79d09c9484d15ae',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'MARTHA',
#   'properties': {'id': '8d469b3d60584762b5e5f00f87487645',
#    'human_readable_id': 83,
#    'source': 'BOB CRATCHIT',
#    'target': 'MARTHA',
#    'description': 'Martha is the daughter of Bob Cratchit',
#    'weight': 10.0,
#    'combined_degree': 27,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CHRISTMAS DAY',
#   'properties': {'id': '7dc6a6fe544c47218748acb98dac0aa1',
#    'human_readable_id': 84,
#    'source': 'BOB CRATCHIT',
#    'target': 'CHRISTMAS DAY',
#    'description': 'The story of Bob Cratchit takes place on Christmas Day',
#    'weight': 5.0,
#    'combined_degree': 29,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CHRISTMAS PRESENT',
#   'properties': {'id': '359c60b6714b4f2dba8101a025bbffa4',
#    'human_readable_id': 85,
#    'source': 'BOB CRATCHIT',
#    'target': 'CHRISTMAS PRESENT',
#    'description': 'Bob Cratchit is a significant character in the event of Christmas Present',
#    'weight': 1.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['b4dec8fbe9f2a2c6a79d09c9484d15ae'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'CHRISTMAS MEAL',
#   'properties': {'id': '9c9668470db7494381360f276bbcf388',
#    'human_readable_id': 86,
#    'source': 'BOB CRATCHIT',
#    'target': 'CHRISTMAS MEAL',
#    'description': 'Bob Cratchit participates in the Christmas meal with his family',
#    'weight': 7.0,
#    'combined_degree': 29,
#    'text_unit_ids': array(['5d70b47bf7167b7586f47fcc4355a746'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'PETER',
#   'properties': {'id': '5029339d9d234602bda023e5ad4cc27b',
#    'human_readable_id': 87,
#    'source': 'BOB CRATCHIT',
#    'target': 'PETER',
#    'description': "Bob Cratchit is Peter's father and has a significant relationship with him. Cratchit has a particular situation in mind for Peter, indicating a deep involvement in his son's life.",
#    'weight': 14.0,
#    'combined_degree': 29,
#    'text_unit_ids': array(['1bdf253855a115bcf51faa63d7b07e82',
#           'f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'MASTER PETER',
#   'properties': {'id': '4c3361f6de0f487faef061247ab68946',
#    'human_readable_id': 88,
#    'source': 'BOB CRATCHIT',
#    'target': 'MASTER PETER',
#    'description': 'Bob Cratchit has a situation in mind for Master Peter, indicating a relationship',
#    'weight': 4.0,
#    'combined_degree': 26,
#    'text_unit_ids': array(['1bdf253855a115bcf51faa63d7b07e82'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': "MR. SCROOGE'S NEPHEW",
#   'properties': {'id': '1c1406a74dc54deba14f5f264659f7ca',
#    'human_readable_id': 89,
#    'source': 'BOB CRATCHIT',
#    'target': "MR. SCROOGE'S NEPHEW",
#    'description': "Mr. Scrooge's nephew consistently demonstrated kindness towards Bob Cratchit. This kindness was not only shown through his general demeanor but also through his offer of assistance to Bob Cratchit.",
#    'weight': 11.0,
#    'combined_degree': 25,
#    'text_unit_ids': array(['f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'THE GHOST',
#   'properties': {'id': 'b19c19053d724308ba4c216ce7784dd9',
#    'human_readable_id': 90,
#    'source': 'BOB CRATCHIT',
#    'target': 'THE GHOST',
#    'description': "The Ghost shows Scrooge a scene from Bob Cratchit's house.",
#    'weight': 3.0,
#    'combined_degree': 35,
#    'text_unit_ids': array(['f40e4b274b5e1a25afbff9ecb733e1f4'], dtype=object)}},
#  {'start': 'BOB CRATCHIT',
#   'end': 'OFFICE',
#   'properties': {'id': 'de58262aad1a4cbe98eb4d09e1f7a48d',
#    'human_readable_id': 91,
#    'source': 'BOB CRATCHIT',
#    'target': 'OFFICE',
#    'description': 'Bob Cratchit works at the office and interacts with Scrooge there',
#    'weight': 1.0,
#    'combined_degree': 24,
#    'text_unit_ids': array(['04e5c071e4ee5496d5380662e1339f45'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'SCROOGE',
#   'properties': {'id': 'bf83449528234457b997f4d6756ee957',
#    'human_readable_id': 92,
#    'source': 'FEZZIWIG',
#    'target': 'SCROOGE',
#    'description': 'Fezziwig is a character in the story who Scrooge was apprenticed to',
#    'weight': 1.0,
#    'combined_degree': 134,
#    'text_unit_ids': array(['ce95e4fc6ee410973c040fc628dce155'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'MASTER SCROOGE',
#   'properties': {'id': '15ebf63c7046436483a0ca2094dd8291',
#    'human_readable_id': 93,
#    'source': 'FEZZIWIG',
#    'target': 'MASTER SCROOGE',
#    'description': 'Fezziwig is a character in the story who Master Scrooge was apprenticed to',
#    'weight': 1.0,
#    'combined_degree': 15,
#    'text_unit_ids': array(['ce95e4fc6ee410973c040fc628dce155'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'CHRISTMAS EVE PARTY',
#   'properties': {'id': 'a40f6c7942c0493e8e1839699f256804',
#    'human_readable_id': 94,
#    'source': 'FEZZIWIG',
#    'target': 'CHRISTMAS EVE PARTY',
#    'description': 'Fezziwig is the host of the Christmas Eve party',
#    'weight': 9.0,
#    'combined_degree': 23,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'THE THREE MISS FEZZIWIGS',
#   'properties': {'id': 'ff8d33fe608b42a6bbcd8fa8a93c5059',
#    'human_readable_id': 95,
#    'source': 'FEZZIWIG',
#    'target': 'THE THREE MISS FEZZIWIGS',
#    'description': 'Fezziwig is the father of the three Miss Fezziwigs',
#    'weight': 10.0,
#    'combined_degree': 13,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'THE FIDDLER',
#   'properties': {'id': '708de9b09aa047d88207a133e22a4d27',
#    'human_readable_id': 96,
#    'source': 'FEZZIWIG',
#    'target': 'THE FIDDLER',
#    'description': 'Fezziwig is the employer of the fiddler for the Christmas Eve party',
#    'weight': 7.0,
#    'combined_degree': 13,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'THE HOUSEMAID',
#   'properties': {'id': 'ec584124db9943aaa9b53980e21cb37c',
#    'human_readable_id': 97,
#    'source': 'FEZZIWIG',
#    'target': 'THE HOUSEMAID',
#    'description': 'Fezziwig is the employer of the housemaid',
#    'weight': 8.0,
#    'combined_degree': 14,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'THE COOK',
#   'properties': {'id': 'f06b67ecf4154c95be82a942de0c32a1',
#    'human_readable_id': 98,
#    'source': 'FEZZIWIG',
#    'target': 'THE COOK',
#    'description': 'Fezziwig is the employer of the cook',
#    'weight': 8.0,
#    'combined_degree': 14,
#    'text_unit_ids': array(['260fb94666cbdfb08286ce8d8162130d'], dtype=object)}},
#  {'start': 'FEZZIWIG',
#   'end': 'DOMESTIC BALL',
#   'properties': {'id': 'fcfb0788b50542c0a3c0e6894d33dda6',
#    'human_readable_id': 99,
#    'source': 'FEZZIWIG',
#    'target': 'DOMESTIC BALL',
#    'description': 'Fezziwig is the host of the domestic ball',
#    'weight': 8.0,
#    'combined_degree': 13,
#    'text_unit_ids': array(['bf29edcb41403e5af43aa101072f4fdf'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'MARLEY',
#   'properties': {'id': '7e15bcf26eee414289be20ff13434bea',
#    'human_readable_id': 100,
#    'source': 'SCROOGE',
#    'target': 'MARLEY',
#    'description': "Scrooge and Marley were business partners in life, with Scrooge also serving as the executor of Marley's estate after his death. Their past relationship was significant, as Marley is often associated with Scrooge's past. After Marley's death, Scrooge has experienced visions of Marley's face on the tiles around his fireplace and heard a chain dragging, which he associates with ghosts in haunted houses. This suggests that Marley's influence continues to impact Scrooge even after his passing.",
#    'weight': 41.0,
#    'combined_degree': 125,
#    'text_unit_ids': array(['080d8e696ff38c653ca90fa086415e74',
#           '10730234d6ccc7cee08f3cfc58d8a9a1',
#           '7064df4af064aeb556e5bab52e896414',
#           '759315fa84c14e81f84fc71c73746184',
#           '77ae3762a0b062ca5350ea54a05450ae',
#           'e8d4072836ac08145edc2fa8c15ea2c2'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'SCRATCH',
#   'properties': {'id': '8b8abfd8da2340b6a1fb4253419c81c8',
#    'human_readable_id': 101,
#    'source': 'SCROOGE',
#    'target': 'SCRATCH',
#    'description': 'Scratch is likely a nickname or alias for Scrooge, as indicated by the conversation between two characters',
#    'weight': 3.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['10730234d6ccc7cee08f3cfc58d8a9a1'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'THE CLERGYMAN',
#   'properties': {'id': '8e7b10cd2540402c99a3dc5cbb07b61b',
#    'human_readable_id': 102,
#    'source': 'SCROOGE',
#    'target': 'THE CLERGYMAN',
#    'description': "The clergyman signed the register of Marley's burial, indicating a professional relationship with Scrooge",
#    'weight': 2.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['10730234d6ccc7cee08f3cfc58d8a9a1'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'THE CLERK',
#   'properties': {'id': '3b183b6002c54888af6712e4daaa2fe3',
#    'human_readable_id': 103,
#    'source': 'SCROOGE',
#    'target': 'THE CLERK',
#    'description': "Scrooge is the employer of the clerk at the counting-house, indicating a professional relationship between the two. The clerk also signed the register of Marley's burial, further demonstrating their professional connection.",
#    'weight': 10.0,
#    'combined_degree': 125,
#    'text_unit_ids': array(['10730234d6ccc7cee08f3cfc58d8a9a1',
#           '7064df4af064aeb556e5bab52e896414'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'THE UNDERTAKER',
#   'properties': {'id': '82ffa2ba82964352b71f9eef693a5d62',
#    'human_readable_id': 104,
#    'source': 'SCROOGE',
#    'target': 'THE UNDERTAKER',
#    'description': "The undertaker signed the register of Marley's burial, indicating a professional relationship with Scrooge",
#    'weight': 2.0,
#    'combined_degree': 124,
#    'text_unit_ids': array(['10730234d6ccc7cee08f3cfc58d8a9a1'], dtype=object)}},
#  {'start': 'SCROOGE',
#   'end': 'THE CHIEF MOURNER',
#   'properties': {'id': 'a0d5844ea436452cac765c27db8e86ed',
#    'human_readable_id': 105,
# ...
#  {'start': 'TOPPER',
#   'end': "SCROOGE'S NIECE'S SISTER",
#   'properties': {'id': '9debb85834174766b9b70cc3fbc36c34',
#    'human_readable_id': 282,
#    'source': 'TOPPER',
#    'target': "SCROOGE'S NIECE'S SISTER",
#    'description': "Topper has his eye on one of Scrooge's niece's sisters, indicating a potential romantic interest.",
#    'weight': 1.0,
#    'combined_degree': 5,
#    'text_unit_ids': array(['bc5fde5d1e00a3ecc1e548c8d24f1c1f'], dtype=object)}},
#  {'start': 'TOPPER',
#   'end': 'THE PLUMP SISTER',
#   'properties': {'id': '636aa3304c00466e90dfbe341f45c66e',
#    'human_readable_id': 283,
#    'source': 'TOPPER',
#    'target': 'THE PLUMP SISTER',
#    'description': "Topper chases the plump sister during the game of blind man's-buff",
#    'weight': 1.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['4cf4deeb7f61acb7b7db4ce0e57fb1e6'], dtype=object)}},
#  {'start': 'TOPPER',
#   'end': "BLIND MAN'S-BUFF PARTY",
#   'properties': {'id': '00c1934f933a460799bf8cd75e0a2d73',
#    'human_readable_id': 284,
#    'source': 'TOPPER',
#    'target': "BLIND MAN'S-BUFF PARTY",
#    'description': "Topper participates in the blind man's-buff party during the Christmas festivities",
#    'weight': 8.0,
#    'combined_degree': 5,
#    'text_unit_ids': array(['4cf4deeb7f61acb7b7db4ce0e57fb1e6'], dtype=object)}},
#  {'start': 'THE PLUMP SISTER',
#   'end': 'YES AND NO',
#   'properties': {'id': '250d21ffa81843498f04143e721b6fa9',
#    'human_readable_id': 285,
#    'source': 'THE PLUMP SISTER',
#    'target': 'YES AND NO',
#    'description': 'The plump sister is playing the game Yes and No with the others',
#    'weight': 7.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['61a042016835080f3d334560b13b0e35'], dtype=object)}},
#  {'start': 'PHANTOM',
#   'end': 'DEATH',
#   'properties': {'id': '7268e5d6171c4a46803e15330b9751e8',
#    'human_readable_id': 286,
#    'source': 'PHANTOM',
#    'target': 'DEATH',
#    'description': "The Phantom is showing Scrooge the event of the man's death",
#    'weight': 7.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': 'BUSINESS MEN',
#   'end': "'CHANGE",
#   'properties': {'id': '980c713bd85341c1870d075098ad487a',
#    'human_readable_id': 287,
#    'source': 'BUSINESS MEN',
#    'target': "'CHANGE",
#    'description': "The business men are located at the 'Change in the city",
#    'weight': 1.0,
#    'combined_degree': 4,
#    'text_unit_ids': array(['ebc403dd3df39bacc3443ef4afb7edfd'], dtype=object)}},
#  {'start': 'SHOP',
#   'end': 'WOMAN',
#   'properties': {'id': 'e5af7fd45dd943fcadf5275e09f80bf3',
#    'human_readable_id': 288,
#    'source': 'SHOP',
#    'target': 'WOMAN',
#    'description': 'The woman enters the shop with a heavy bundle',
#    'weight': 5.0,
#    'combined_degree': 9,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'SHOP',
#   'end': 'SECOND WOMAN',
#   'properties': {'id': 'ae91505f57b3402a9f0417c33e5176f1',
#    'human_readable_id': 289,
#    'source': 'SHOP',
#    'target': 'SECOND WOMAN',
#    'description': 'The second woman enters the shop with a heavy bundle',
#    'weight': 5.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'SHOP',
#   'end': 'MAN IN FADED BLACK',
#   'properties': {'id': '0d24628dcb4b4c2fb74c60be70a3257e',
#    'human_readable_id': 290,
#    'source': 'SHOP',
#    'target': 'MAN IN FADED BLACK',
#    'description': 'The man in faded black enters the shop after the two women',
#    'weight': 5.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'WOMAN',
#   'end': 'OLD JOE',
#   'properties': {'id': '321014e53c0e44e9a9260598fd16522c',
#    'human_readable_id': 291,
#    'source': 'WOMAN',
#    'target': 'OLD JOE',
#    'description': 'Old Joe and the woman are interacting in a transaction where the woman is selling items to Old Joe',
#    'weight': 7.0,
#    'combined_degree': 11,
#    'text_unit_ids': array(['bc606176c752984da6d202275ee8c7a6'], dtype=object)}},
#  {'start': 'OLD JOE',
#   'end': 'PARLOUR',
#   'properties': {'id': '4b0e68d6d31d42e4bfae5c4024859bd1',
#    'human_readable_id': 292,
#    'source': 'OLD JOE',
#    'target': 'PARLOUR',
#    'description': 'Old Joe invites the others into the parlour',
#    'weight': 6.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'OLD JOE',
#   'end': 'CHARWOMAN',
#   'properties': {'id': '49c40241d4ba43c08452cd7ee35351d5',
#    'human_readable_id': 293,
#    'source': 'OLD JOE',
#    'target': 'CHARWOMAN',
#    'description': 'The charwoman is known to Old Joe and is present in the shop',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'OLD JOE',
#   'end': 'LAUNDRESS',
#   'properties': {'id': 'a8726a454643436d9d9958e369ef0d87',
#    'human_readable_id': 294,
#    'source': 'OLD JOE',
#    'target': 'LAUNDRESS',
#    'description': 'The laundress is known to Old Joe and is present in the shop',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'OLD JOE',
#   'end': "UNDERTAKER'S MAN",
#   'properties': {'id': '3c17ae9bace144ce851d4bdca24250cb',
#    'human_readable_id': 295,
#    'source': 'OLD JOE',
#    'target': "UNDERTAKER'S MAN",
#    'description': "The undertaker's man is known to Old Joe and is present in the shop",
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'LAUNDRESS',
#   'end': 'CHARWOMAN',
#   'properties': {'id': 'caac467f30174b738d135244789ac3d1',
#    'human_readable_id': 296,
#    'source': 'LAUNDRESS',
#    'target': 'CHARWOMAN',
#    'description': 'The charwoman and the laundress know each other and are present in the shop',
#    'weight': 6.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': 'LAUNDRESS',
#   'end': "UNDERTAKER'S MAN",
#   'properties': {'id': '6b2a02e5e3c24d1dab15ae9dc51ab6cb',
#    'human_readable_id': 297,
#    'source': 'LAUNDRESS',
#    'target': "UNDERTAKER'S MAN",
#    'description': "The laundress and the undertaker's man know each other and are present in the shop",
#    'weight': 1.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': "UNDERTAKER'S MAN",
#   'end': 'CHARWOMAN',
#   'properties': {'id': '9537798187714726b1bb50d55fba58c1',
#    'human_readable_id': 298,
#    'source': "UNDERTAKER'S MAN",
#    'target': 'CHARWOMAN',
#    'description': "The charwoman and the undertaker's man know each other and are present in the shop",
#    'weight': 6.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['1cb66ea16e5e4f2816f0e188d3acc792'], dtype=object)}},
#  {'start': "CAROLINE'S HUSBAND",
#   'end': 'HALF-DRUNKEN WOMAN',
#   'properties': {'id': '5a26dc879bcd4478968d003a94de944c',
#    'human_readable_id': 299,
#    'source': "CAROLINE'S HUSBAND",
#    'target': 'HALF-DRUNKEN WOMAN',
#    'description': 'The half-drunken woman is mentioned in a conversation between Caroline and her husband',
#    'weight': 1.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': "CAROLINE'S HUSBAND",
#   'end': 'DEATH',
#   'properties': {'id': '3d0c7e2423f74c209bcee4e4556c139c',
#    'human_readable_id': 300,
#    'source': "CAROLINE'S HUSBAND",
#    'target': 'DEATH',
#    'description': "Caroline's husband brings the news of the man's death",
#    'weight': 8.0,
#    'combined_degree': 8,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': "CAROLINE'S HUSBAND",
#   'end': 'THE MAN',
#   'properties': {'id': 'efef7084e33a4a998bca4d4affd74880',
#    'human_readable_id': 301,
#    'source': "CAROLINE'S HUSBAND",
#    'target': 'THE MAN',
#    'description': "The man's death has a direct impact on the financial situation of Caroline's husband",
#    'weight': 1.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['cd8a47ace09b9cee1e8b27b0689f2822'], dtype=object)}},
#  {'start': "SCROOGE AND MARLEY'S",
#   'end': 'THE PORTLY GENTLEMAN',
#   'properties': {'id': '3ada800ef6ca4a26b4d82a93bba6a23f',
#    'human_readable_id': 302,
#    'source': "SCROOGE AND MARLEY'S",
#    'target': 'THE PORTLY GENTLEMAN',
#    'description': "The Portly Gentleman walked into Scrooge and Marley's counting-house",
#    'weight': 1.0,
#    'combined_degree': 4,
#    'text_unit_ids': array(['6c362d3f8d01c76d84443dcabf3f322a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'PROJECT GUTENBERG™',
#   'properties': {'id': 'e8b95e628964481e991109fad505c2e9',
#    'human_readable_id': 303,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'PROJECT GUTENBERG™',
#    'description': 'The owner of the Project Gutenberg™ trademark donates royalties to the Project Gutenberg Literary Archive Foundation. The Foundation also manages the Project Gutenberg™ trademark.',
#    'weight': 1.0,
#    'combined_degree': 13,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'RIGHT OF REPLACEMENT OR REFUND',
#   'properties': {'id': '3e90d1e689584a14bf780187cd300111',
#    'human_readable_id': 304,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'RIGHT OF REPLACEMENT OR REFUND',
#    'description': 'The Project Gutenberg Literary Archive Foundation provides a Right of Replacement or Refund policy for Project Gutenberg™ electronic works.',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#   'properties': {'id': 'f3a008c997034ed6861c986eb8ffae38',
#    'human_readable_id': 305,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#    'description': 'The Project Gutenberg Literary Archive Foundation provides a Limited Warranty, Disclaimer of Damages policy for Project Gutenberg™ electronic works.',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'INDEMNITY',
#   'properties': {'id': 'ff71d2e82a5d411f967cab5f7816b042',
#    'human_readable_id': 306,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'INDEMNITY',
#    'description': 'The Project Gutenberg Literary Archive Foundation provides an Indemnity policy for Project Gutenberg™ electronic works.',
#    'weight': 1.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'INTERNAL REVENUE SERVICE',
#   'properties': {'id': '0d514e86a99d416e9e9c10a3d24bed60',
#    'human_readable_id': 307,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'INTERNAL REVENUE SERVICE',
#    'description': 'The Project Gutenberg Literary Archive Foundation has been granted tax exempt status by the Internal Revenue Service',
#    'weight': 7.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'MISSISSIPPI',
#   'properties': {'id': '5dc6cb4e9cd44262a533fcf119bd2d9d',
#    'human_readable_id': 308,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'MISSISSIPPI',
#    'description': 'The Project Gutenberg Literary Archive Foundation is organized under the laws of the state of Mississippi',
#    'weight': 6.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#   'end': 'SALT LAKE CITY',
#   'properties': {'id': 'a2168909a4e1423db67f12e83fe8d4ae',
#    'human_readable_id': 309,
#    'source': 'PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION',
#    'target': 'SALT LAKE CITY',
#    'description': 'The business office of the Project Gutenberg Literary Archive Foundation is located in Salt Lake City',
#    'weight': 5.0,
#    'combined_degree': 10,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG™',
#   'end': 'U.S. COPYRIGHT LAW',
#   'properties': {'id': 'ec8f83f5ca494b06923378a7e334cfe6',
#    'human_readable_id': 310,
#    'source': 'PROJECT GUTENBERG™',
#    'target': 'U.S. COPYRIGHT LAW',
#    'description': 'Project Gutenberg volunteers and employees consider U.S. copyright law when creating the Project Gutenberg™ collection.',
#    'weight': 5.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG™',
#   'end': 'RIGHT OF REPLACEMENT OR REFUND',
#   'properties': {'id': '906a91287a63471fb17beda5b113e43e',
#    'human_readable_id': 311,
#    'source': 'PROJECT GUTENBERG™',
#    'target': 'RIGHT OF REPLACEMENT OR REFUND',
#    'description': 'Project Gutenberg™ provides a Right of Replacement or Refund policy for its electronic works.',
#    'weight': 8.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG™',
#   'end': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#   'properties': {'id': 'dc0fb1285d264d23a8b8daf3f05acd1b',
#    'human_readable_id': 312,
#    'source': 'PROJECT GUTENBERG™',
#    'target': 'LIMITED WARRANTY, DISCLAIMER OF DAMAGES',
#    'description': 'Project Gutenberg™ has a Limited Warranty, Disclaimer of Damages policy for its electronic works.',
#    'weight': 8.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'PROJECT GUTENBERG™',
#   'end': 'INDEMNITY',
#   'properties': {'id': 'e5446a8a991640f1bfb33a18489be572',
#    'human_readable_id': 313,
#    'source': 'PROJECT GUTENBERG™',
#    'target': 'INDEMNITY',
#    'description': 'Project Gutenberg™ has an Indemnity policy for its electronic works.',
#    'weight': 8.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['0ddc17ea5e566006c000b4013f2181a5'], dtype=object)}},
#  {'start': 'INTERNAL REVENUE SERVICE',
#   'end': 'FOUNDATION',
#   'properties': {'id': 'a7b558f7b329426dade7b8cd6d471da0',
#    'human_readable_id': 314,
#    'source': 'INTERNAL REVENUE SERVICE',
#    'target': 'FOUNDATION',
#    'description': 'The Foundation has been granted tax exempt status by the Internal Revenue Service',
#    'weight': 7.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'MISSISSIPPI',
#   'end': 'FOUNDATION',
#   'properties': {'id': 'a27982d1672a40fa9d27e61af39c9119',
#    'human_readable_id': 315,
#    'source': 'MISSISSIPPI',
#    'target': 'FOUNDATION',
#    'description': 'The Foundation is organized under the laws of the state of Mississippi',
#    'weight': 6.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'SALT LAKE CITY',
#   'end': 'FOUNDATION',
#   'properties': {'id': 'a60835b9d9eb45d3a6d0fbecd1176718',
#    'human_readable_id': 316,
#    'source': 'SALT LAKE CITY',
#    'target': 'FOUNDATION',
#    'description': 'The business office of the Foundation is located in Salt Lake City',
#    'weight': 5.0,
#    'combined_degree': 7,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}},
#  {'start': 'U.S.',
#   'end': 'FOUNDATION',
#   'properties': {'id': 'f6f1a2438b5543efb7b8dbc64d99b581',
#    'human_readable_id': 317,
#    'source': 'U.S.',
#    'target': 'FOUNDATION',
#    'description': 'The Foundation operates in the U.S.',
#    'weight': 1.0,
#    'combined_degree': 6,
#    'text_unit_ids': array(['cd4234ed6caba8f15d09a2e3ee604b2a'], dtype=object)}}]

# %% [markdown]
# <div style="text-align: justify;">
#
# En este siguiente bloque se configura la visualización basada en los datos para representar de forma interactiva el grafo de conocimiento.
#
# Luego, se define una función `community_to_color` que asigna un color a cada comunidad. Para ello, se utiliza una lista predefinida de colores y se selecciona uno en función del valor numérico de la comunidad, garantizando que cada comunidad tenga un color distintivo. En el caso de que el nodo no pertenezca a ninguna comunidad, se asigna el color "lightgray".
#
# A continuación, la función `edge_to_source_community` permite obtener la comunidad del nodo de origen de una arista. Esta función busca en la lista de nodos aquel cuyo título coincide con el identificador de inicio de la arista y retorna la comunidad asociada. Esto es útil para que las aristas también reflejen visualmente la pertenencia a una comunidad, basándose en el color del nodo de origen.
#
# Con las funciones definidas, se aplican mapeos para configurar la visualización:
# - `w.node_color_mapping` asigna a cada nodo un color en función de la comunidad a la que pertenece.
# - `w.edge_color_mapping` hace lo propio para las aristas, basándose en la comunidad del nodo de origen.
#
# Finalmente, se comentan líneas adicionales que podrían utilizarse para ajustar el tamaño de los nodos en función de su grado (utilizando un factor de escala) o para definir el grosor de las aristas según algún peso asociado. Estas configuraciones adicionales permiten personalizar aún más la visualización para diferentes casos de uso.
#
# </div>

# %%
# show title on the node
w.node_label_mapping = "NORMAS"


# map community to a color
def community_to_color(community):
    """Map a community to a color."""
    colors = [
        "crimson",
        "darkorange",
        "indigo",
        "cornflowerblue",
        "cyan",
        "teal",
        "green",
    ]
    return (
        colors[int(community) % len(colors)] if community is not None else "lightgray"
    )


def edge_to_source_community(edge):
    """Get the community of the source node of an edge."""
    source_node = next(
        (entry for entry in w.nodes if entry["properties"]["title"] == edge["start"]),
        None,
    )
    source_node_community = source_node["properties"]["community"]
    return source_node_community if source_node_community is not None else None

## Coloreamos en función de la comunidad a la que pertenecen
w.node_color_mapping = lambda node: community_to_color(node["properties"]["community"])
w.edge_color_mapping = lambda edge: community_to_color(edge_to_source_community(edge))
# map size data to a reasonable factor
#w.node_scale_factor_mapping = lambda node: 0.5 + node["properties"]["degree"] * 1.5 / 20
# use weight for edge thickness
#w.edge_thickness_factor_mapping = "weight"

# %% [markdown]
# <div style="text-align: justify;">
#
# El widget ofrece diferentes layouts automáticos que se adaptan a diversos propósitos y estilos de visualización. Entre las opciones disponibles se encuentran `Circular`, `Hierarchic`, `Organic (interactivo o estático)`, `Orthogonal`, `Radial`, `Tree` y `Geo-spatial`. Cada uno de estos diseños organiza los nodos y aristas del grafo de manera distinta, permitiendo resaltar diferentes aspectos estructurales y relacionales de los datos.
#
# En el caso del grafo de conocimiento, este ejemplo utiliza el layout `Circular`. Este diseño distribuye los nodos uniformemente alrededor de un círculo, lo que facilita la identificación de comunidades y patrones de conexión de forma clara y simétrica. Sin embargo, layouts como `Hierarchic` o `Organic` también pueden ser opciones  adecuadas.
#
#
# </div>

# %%
def custom_node_label_mapping(index,node):
    properties = node.get("properties", {})
    return properties.get("title", "no title")

w.node_label_mapping = custom_node_label_mapping

# %% [markdown]
# <div style="color: red; font-weight: bold;">
# AVISO: Para poder visualizar el grafo es necesario ejecutar las celdas, ya que no se guarda una vez cerrado el notebook.
# </div>

# %%
w.set_sidebar(start_with='Data')
display(w)
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
# Use the circular layout for this visualization. For larger graphs, the default organic layout is often preferrable.
w.circular_layout()
display(w)
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %% [markdown]
# ---
# ## 7.4. Consultas sobre GraphRAG

# %% [markdown]
# ### NO EJECUTAR A PARTIR DE AQUÍ
# A partir de este punto del notebook se incluyen celdas destinadas a visualizar el contexto de los resultados obtenidos a partir de las consultas realizadas con GraphRAG. Es importante destacar que estas celdas no deben ejecutarse directamente en este entorno, ya que requieren de un token API de OpenAI para funcionar correctamente. Por razones de seguridad, dicho token no se proporciona en este código.
#
# Si se desea ejecutar estas celdas, se recomienda almacenar el token API en un archivo de entorno (`.env`) ubicado en la carpeta `graphrag`. De esta forma, se puede acceder al token de forma segura sin exponerlo en el código fuente.

# %%
entity_df['type'] = entity_df['community']
entity_embedding_df['type'] = entity_embedding_df['community']


entity_df['description'] = entity_df['title']
entity_embedding_df['description'] = entity_embedding_df['title']

# %%
columns = [col for col in entity_df.columns if col != 'degree'] + ['degree']

# Reorganizar las columnas en ambos DataFrames
entity_df = entity_df[columns]
entity_embedding_df = entity_embedding_df[columns]

# Verificar el nuevo orden de las columnas
print(entity_df.columns)
print(entity_embedding_df.columns)
# Out:
# Index(['id', 'human_readable_id', 'title', 'community', 'level', 'x', 'y',
#        'type', 'description', 'degree'],
#       dtype='object')
# Index(['id', 'human_readable_id', 'title', 'community', 'level', 'x', 'y',
#        'type', 'description', 'degree'],
#       dtype='object')

# %% [markdown]
# En GraphRAG, el "nivel de una comunidad" se refiere a la jerarquía de las comunidades detectadas dentro de un grafo de conocimiento. Las comunidades son grupos de nodos densamente conectados que representan temas o subtemas en los datos.
#
# Cómo se estructuran estos niveles:
#
# - Comunidades de Nivel 0: Representan los temas más amplios del conjunto de datos. Estas comunidades abarcan conceptos generales y proporcionan una visión general del grafo.
#
# - Comunidades de Nivel 1: Muestran temas más detallados dentro de cada comunidad principal. Estas comunidades desglosan los temas amplios en subtemas más específicos, permitiendo un análisis más profundo.

# %%
from graphrag.model.entity import Entity


# La función read_indexer_entities procesa las salidas crudas de la indexación y las transforma en
# una lista de objetos Entity, alineando los datos de nodos y entidades según el modelo de conocimiento.
def read_indexer_entities(final_nodes: pd.DataFrame,
                          final_entities: pd.DataFrame,
                          community_level: int | None) -> list[Entity]:
    # Asignamos los DataFrames de nodos y entidades a variables locales.
    nodes_df = final_nodes
    entities_df = final_entities

    # Si se especifica un nivel de comunidad, filtramos los nodos para conservar solo aquellos
    # cuyo nivel es menor o igual que el nivel indicado.
    if community_level is not None:
        nodes_df = _filter_under_community_level(nodes_df, community_level)

    # Seleccionamos únicamente las columnas relevantes: 'id', 'degree' y 'community'.
    nodes_df = cast("pd.DataFrame", nodes_df[["id", "degree", "community"]])

    # Agrupamos los nodos por 'id' y 'degree', consolidando las comunidades en un conjunto
    # para eliminar duplicados y luego transformamos el conjunto en una lista de strings.
    nodes_df = nodes_df.groupby(["id", "degree"]).agg({"community": set}).reset_index()
    nodes_df["community"] = nodes_df["community"].apply(lambda x: [str(i) for i in x])
    
    # Fusionamos los datos de nodos con los de entidades utilizando el 'id' como clave y eliminamos duplicados.
    final_df = nodes_df.merge(entities_df, on="id", how="inner").drop_duplicates(subset=["id"])

    # Convertimos el DataFrame final en objetos Entity mediante la función read_entities,
    # mapeando las columnas del DataFrame a los atributos correspondientes del modelo.
    return read_entities(
        df=final_df,
        id_col="id",
        title_col="title",
        type_col="type",
        short_id_col="human_readable_id",
        description_col="description",
        community_col="community",
        rank_col="degree_x",
        name_embedding_col=None,
        description_embedding_col="description_embedding",
        text_unit_ids_col="text_unit_ids",
    )


## Esta función nos permite quedarnos con las filas cuyo nivel sea menor o igual que un determinado nivel de comunidad seleccionado
def _filter_under_community_level(
    df: pd.DataFrame, community_level: int
) -> pd.DataFrame:
    return cast(
        "pd.DataFrame",
        df[df.level <= community_level],
    )

# %%
community_level = 2
nodes_df = entity_df
entities_df = entity_embedding_df

if community_level is not None:
    nodes_df = _filter_under_community_level(nodes_df, community_level)

nodes_df.dtypes
# Out:
# id                   object
# human_readable_id     int64
# title                object
# community             int32
# level                 int64
# x                    object
# y                    object
# type                  int32
# description          object
# degree                int64
# dtype: object

# %%
#Nos quedamos solo con las columnas que nos interesan
nodes_df = cast("pd.DataFrame", nodes_df[["id", "degree", "community"]])
nodes_df
# Out:
#                                     id  degree  community
# 0     4f370d7f0d734f92b6118d88e79d886a       7          8
# 1     8e5be5b1e63343b8a2f0af6baba70337       2          8
# 2     73b0e0a551dc454690bad3d6756912be       8          0
# 7     cf70df771d6c464e93b7ff99d2ea8142       1          0
# 12    3dfdd81803b74b3a8d3244af70df4f83       1          0
# ...                                ...     ...        ...
# 1001  9efdb8d321d5445e9dfea1fa29a1b173       2         29
# 1002  c4e8ca318c6046a58ed833be1aa86732       2         29
# 1003  ea84881a96d644c5884e6675ee1ff591       1         29
# 1004  3ce8510deb354206b7dbcbd0f7b0d8b8       2         29
# 1005  1351e738a2d84f7cbf27734dd86ec10b       1         29
#
# [497 rows x 3 columns]

# %%
# A continuación, vamos a consolidar y estructurar la información resultante de la indexación para que se ajuste
# a nuestro modelo de conocimiento. Se fusionan los datos de nodos y entidades, se filtran según un nivel de comunidad
# específico y se agrupan para eliminar redundancias. El resultado es una lista de objetos Entity que encapsulan
# la información esencial, facilitando así el análisis y la representación del grafo de conocimiento.
nodes_df = nodes_df.groupby(["id", "degree"]).agg({"community": set}).reset_index()
nodes_df["community"] = nodes_df["community"].apply(lambda x: [str(i) for i in x])
nodes_df
# Out:
#                                    id  degree    community
# 0    004f7d801f964160b441c6e7060c2479       1         [-1]
# 1    00aea98437c042d6b606e7f8d402822e       1  [1, 12, 29]
# 2    01505a7c5e3e4b1c978016e6a2020f27       4          [6]
# 3    026adfbca92540759d2c7a2c8d242baa       1  [1, 12, 29]
# 4    05a8b2da0f4d469f8e3ef8b9305ec577       1          [0]
# ..                                ...     ...          ...
# 223  fc18d39cb306425f97dbc98e67477b71       5      [8, 28]
# 224  fc4e0665f6374672a2fe1951bdd3f829       3      [18, 4]
# 225  fdee948a65da4ee5b6a3e25793dfab52       1  [1, 12, 29]
# 226  fedf3c73a3274d3db77d65c5398a8508       1  [1, 12, 29]
# 227  ffcb75801b0a4885aa444c93fb0680cd       1  [1, 12, 29]
#
# [228 rows x 3 columns]

# %%
# Este código fusiona (mediante un inner join) el DataFrame de nodos (nodes_df) con el de entidades (entities_df)
# utilizando la columna "id" como clave. Posteriormente, se eliminan los registros duplicados basados en "id",
# de modo que cada entidad aparezca solo una vez en el DataFrame final (final_df).

final_df = nodes_df.merge(entities_df, on="id", how="inner").drop_duplicates(
        subset=["id"]
    )
final_df
# Out:
#                                    id  degree_x  community_x  \
# 0    004f7d801f964160b441c6e7060c2479         1         [-1]
# 1    00aea98437c042d6b606e7f8d402822e         1  [1, 12, 29]
# 6    01505a7c5e3e4b1c978016e6a2020f27         4          [6]
# 7    026adfbca92540759d2c7a2c8d242baa         1  [1, 12, 29]
# 12   05a8b2da0f4d469f8e3ef8b9305ec577         1          [0]
# ..                                ...       ...          ...
# 630  fc18d39cb306425f97dbc98e67477b71         5      [8, 28]
# 632  fc4e0665f6374672a2fe1951bdd3f829         3      [18, 4]
# 634  fdee948a65da4ee5b6a3e25793dfab52         1  [1, 12, 29]
# 639  fedf3c73a3274d3db77d65c5398a8508         1  [1, 12, 29]
# 644  ffcb75801b0a4885aa444c93fb0680cd         1  [1, 12, 29]
#
#      human_readable_id                     title  community_y  level  \
# 0                  121                  DAUGHTER           -1      0
# 1                   92                WINTER DAY            1      0
# 6                  202                     DEATH            6      0
# 7                  137                  GROCERS'            1      0
# 12                   7  J. B. LIPPINCOTT COMPANY            0      0
# ..                 ...                       ...          ...    ...
# 630                216        PROJECT GUTENBERG™            8      0
# 632                197          UNDERTAKER'S MAN            4      0
# 634                 15   GHOST OF CHRISTMAS PAST            1      0
# 639                 67           THE CORPORATION            1      0
# 644                205     BOY IN SUNDAY CLOTHES            1      0
#
#              x          y  type               description  degree_y
# 0         None       None    -1                  DAUGHTER         1
# 1    17.794003  -3.476077     1                WINTER DAY         1
# 6     0.946703  15.462376     6                     DEATH         4
# 7     8.608845  -3.767654     1                  GROCERS'         1
# 12   -11.86204    2.28514     0  J. B. LIPPINCOTT COMPANY         1
# ..         ...        ...   ...                       ...       ...
# 630 -17.540855 -16.454866     8        PROJECT GUTENBERG™         5
# 632   1.462716  -0.495093     4          UNDERTAKER'S MAN         3
# 634  16.049393   5.321182     1   GHOST OF CHRISTMAS PAST         1
# 639  10.352509  -4.813623     1           THE CORPORATION         1
# 644  10.824424  -3.450991     1     BOY IN SUNDAY CLOTHES         1
#
# [228 rows x 12 columns]

# %% [markdown]
# La función `read_entities` que definimos a continuación recibe un DataFrame y mapea cada fila a un objeto de tipo `Entity`, que forma parte de nuestro modelo de conocimiento. Para ello, extrae y convierte los datos de cada columna utilizando funciones auxiliares (como `to_str`, `to_optional_str`, etc.) que aseguran que los valores se transformen al tipo de dato esperado.
#
# Los parámetros de la función (por ejemplo, `id_col`, `title_col`, etc.) indican el nombre de las columnas a utilizar para cada atributo del objeto. En cada iteración del bucle, se crea un objeto `Entity` con:
#
# - **Atributos obligatorios:** como `id`, `short_id` y `title`.
# - **Atributos opcionales:** como `type`, `description`, embeddings (para nombre y descripción), comunidades (`community_ids`), ids de unidades de texto y el rango (`rank`).
# - **Atributos adicionales:** si se proporciona una lista de columnas adicionales a través del parámetro `attributes_cols`.
#
# Finalmente, la función agrega cada objeto `Entity` a una lista y la retorna.

# %%
from graphrag.query.input.loaders.utils import (
    to_optional_dict,
    to_optional_float,
    to_optional_int,
    to_optional_list,
    to_optional_str,
    to_str
)


def read_entities(
    df: pd.DataFrame,
    id_col: str = "id",
    short_id_col: str | None = "human_readable_id",
    title_col: str = "title",
    type_col: str | None = "type",
    description_col: str | None = "description",
    name_embedding_col: str | None = "name_embedding",
    description_embedding_col: str | None = "description_embedding",
    community_col: str | None = "community_ids",
    text_unit_ids_col: str | None = "text_unit_ids",
    rank_col: str | None = "degree",
    attributes_cols: list[str] | None = None,
) -> list[Entity]:
    """Read entities from a dataframe."""
    entities = []
    for idx, row in df.iterrows():
        entity = Entity(
            id=to_str(row, id_col),
            short_id=to_optional_str(row, short_id_col) if short_id_col else str(idx),
            title=to_str(row, title_col),
            type=to_optional_str(row, type_col),
            description=to_optional_str(row, description_col),
            name_embedding=to_optional_list(row, name_embedding_col, item_type=float),
            description_embedding=to_optional_list(
                row, description_embedding_col, item_type=float
            ),
            community_ids=to_optional_list(row, community_col, item_type=str),
            text_unit_ids=to_optional_list(row, text_unit_ids_col),
            rank=to_optional_int(row, rank_col),
            attributes=(
                {col: row.get(col) for col in attributes_cols}
                if attributes_cols
                else None
            ),
        )
        entities.append(entity)
    return entities

# %%
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
entities
# Out:
# [Entity(id='004f7d801f964160b441c6e7060c2479', short_id='121', title='DAUGHTER', type='-1', description='DAUGHTER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='00aea98437c042d6b606e7f8d402822e', short_id='92', title='WINTER DAY', type='1', description='WINTER DAY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='01505a7c5e3e4b1c978016e6a2020f27', short_id='202', title='DEATH', type='6', description='DEATH', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='026adfbca92540759d2c7a2c8d242baa', short_id='137', title="GROCERS'", type='1', description="GROCERS'", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='05a8b2da0f4d469f8e3ef8b9305ec577', short_id='7', title='J. B. LIPPINCOTT COMPANY', type='0', description='J. B. LIPPINCOTT COMPANY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='06b6de89a4284c0da7635db0fc2a5d4a', short_id='63', title='CAMDEN TOWN', type='2', description='CAMDEN TOWN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='072fbc692fe34e069bea21d95e2b4121', short_id='27', title='MARTHA CRATCHIT', type='2', description='MARTHA CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='07983dc4ae694ee6beade2959a611354', short_id='34', title='MARLEY', type='1', description='MARLEY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='08c825231e1c472e97e252b7fc52c753', short_id='182', title='WANT', type='1', description='WANT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='0afded79d65f41879975a196592e401e', short_id='167', title="SCROOGE'S NIECE", type='1', description="SCROOGE'S NIECE", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=6, attributes=None),
#  Entity(id='0c4eabfc3e684d2f8ede442fbdacdb7e', short_id='17', title='GHOST OF CHRISTMAS YET TO COME', type='1', description='GHOST OF CHRISTMAS YET TO COME', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='0e7f692221864df5a38ce32f157ddd2a', short_id='97', title="SULTAN'S GROOM", type='1', description="SULTAN'S GROOM", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='0f4210898ea444f9b5d45d0ff4b5cce5', short_id='159', title='THE LIGHTHOUSE', type='11', description='THE LIGHTHOUSE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='10195ec108f448f192c2b227fdd824d1', short_id='122', title='GIRL', type='1', description='GIRL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='1078111b7734457c9001dadf95fe01f0', short_id='71', title='DUTCH TILES', type='7', description='DUTCH TILES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=6, attributes=None),
#  Entity(id='109f1f26b8c4445c870dc493ac14103f', short_id='186', title='MAN WITH A PENDULOUS EXCRESCENCE ON HIS NOSE', type='-1', description='MAN WITH A PENDULOUS EXCRESCENCE ON HIS NOSE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='11403f795c244cac83ab919e7e00dc6d', short_id='192', title='SECOND WOMAN', type='4', description='SECOND WOMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='1351e738a2d84f7cbf27734dd86ec10b', short_id='213', title="NEPHEW'S HOUSE", type='1', description="NEPHEW'S HOUSE", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='154359c3e0e9432480ccf5db7e2076db', short_id='115', title='DICK', type='1', description='DICK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='15b4495354bd45449b85b1264288c721', short_id='103', title='PRINCESS', type='1', description='PRINCESS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='1fb0c03a02a849b2931d7576b5b2ab8e', short_id='62', title='CORNHILL', type='2', description='CORNHILL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='1fbdeede6a0449fe8b295ed5cfba6cd3', short_id='42', title='SCRATCH', type='1', description='SCRATCH', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='256c91e05ad44aff89255d345553a6ec', short_id='31', title='BOB CRATCHIT', type='2', description='BOB CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=22, attributes=None),
#  Entity(id='2581bc141fa7487aa132200456957105', short_id='112', title='THE BOY FROM OVER THE WAY', type='5', description='THE BOY FROM OVER THE WAY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='25da083f02e8473ab00632d2c39b72ca', short_id='50', title='PORTLY GENTLEMEN', type='1', description='PORTLY GENTLEMEN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='267d767526244db6bdbabfd305b64665', short_id='16', title='GHOST OF CHRISTMAS PRESENT', type='1', description='GHOST OF CHRISTMAS PRESENT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='271b011d2d4c48d6a058a1a7ff605548', short_id='105', title='MASTER SCROOGE', type='5', description='MASTER SCROOGE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='27d3bbc17fb6423b933d0263b178ec1a', short_id='35', title="ST. PAUL'S CHURCHYARD", type='-1', description="ST. PAUL'S CHURCHYARD", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='2ab3aab6d06e40cea139389e7d827e27', short_id='127', title='THE HUSBAND', type='5', description='THE HUSBAND', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='2bd07ec6e9d94d07bc1f054d7a388da9', short_id='144', title='TINY TIM', type='2', description='TINY TIM', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=9, attributes=None),
#  Entity(id='2c2f502d1ad44fa7966bf1ee46d11b47', short_id='81', title='JACOB MARLEY', type='1', description='JACOB MARLEY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='2eadd613ec7443d998bd5142c1dafb18', short_id='64', title='CITY OF LONDON', type='1', description='CITY OF LONDON', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='2ee5c5ca9ecf461da9706e2f023b4653', short_id='51', title='BEDLAM', type='1', description='BEDLAM', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='317de596b79c401cb6a73e5073a6b6ed', short_id='203', title="MR. SCROOGE'S NEPHEW", type='2', description="MR. SCROOGE'S NEPHEW", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='31e3b8674621489cb3bd0689a4630f60', short_id='28', title='MRS. DILBER', type='4', description='MRS. DILBER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='34462806a6b648a4a05213d8b7ad5a39', short_id='154', title='THE BLAZE', type='1', description='THE BLAZE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='3582a02e66254a76b79d23799edd6fd5', short_id='9', title='JANET BLENKINSHIP', type='0', description='JANET BLENKINSHIP', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='37ad1587196d4cbb84f76516a0a3086b', short_id='168', title='TOPPER', type='3', description='TOPPER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='3885e10ac31c4aada2234e4e2716559a', short_id='173', title='FORFEITS', type='1', description='FORFEITS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='38b30e2fe917450989de4104327fae0d', short_id='193', title='MAN IN FADED BLACK', type='4', description='MAN IN FADED BLACK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='39885a80a1f04d2589fd43fa41452af3', short_id='169', title="SCROOGE'S NIECE'S SISTERS", type='1', description="SCROOGE'S NIECE'S SISTERS", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='3a28550abba74ef8b1aa05d9bc0ce10a', short_id='177', title='MULLED WINE', type='5', description='MULLED WINE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='3b94d799fc4f408986fee654e57f3b8d', short_id='153', title='THE CRATCHITS', type='1', description='THE CRATCHITS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='3ce8510deb354206b7dbcbd0f7b0d8b8', short_id='212', title='OFFICE', type='1', description='OFFICE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='3d110cdf03074c588b57381bce99f673', short_id='143', title='PEOPLE', type='-1', description='PEOPLE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='3dfdd81803b74b3a8d3244af70df4f83', short_id='4', title='ARTHUR RACKHAM', type='0', description='ARTHUR RACKHAM', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='3eade1997a6f45a0ac99dcfacad1592d', short_id='151', title='BOB', type='2', description='BOB', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='43fb97b0f2924029a9e1fd420b97e081', short_id='149', title='THE TWO YOUNG CRATCHITS', type='2', description='THE TWO YOUNG CRATCHITS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='4531def00cd0409a88e0ad3ca51bfd37', short_id='6', title='NEW YORK', type='-1', description='NEW YORK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='47086a08782d498399b2935600ab5630', short_id='133', title='CITY STREETS', type='1', description='CITY STREETS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='470c76df99de4087b5dc8c64e07fe121', short_id='170', title="SCROOGE'S NIECE'S SISTER", type='3', description="SCROOGE'S NIECE'S SISTER", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='476ea4c9514341998c12d1a26e68f214', short_id='114', title='THE THREE MISS FEZZIWIGS', type='5', description='THE THREE MISS FEZZIWIGS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='47aac66515904a1a92afc42e4063848d', short_id='181', title='IGNORANCE', type='1', description='IGNORANCE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='48510eb732a947c98dfa4133aee8706e', short_id='148', title='MISS BELINDA', type='2', description='MISS BELINDA', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='486318cf9b1f4a6db9f5d9f44d0b8e92', short_id='171', title='THE PLUMP SISTER', type='5', description='THE PLUMP SISTER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='4a0515486e9549d2afcc5eac40352e40', short_id='146', title='CHRISTMAS PRESENT', type='2', description='CHRISTMAS PRESENT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4a8c445a21d3462a9a818d5acc948ef5', short_id='69', title='LIVERY', type='1', description='LIVERY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4b01a514e88d4db09a8e1621d1771192', short_id='79', title='THE FIREPLACE', type='1', description='THE FIREPLACE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4bc5ea10dc1342c497eac5a7aef14f7a', short_id='29', title='FAN', type='5', description='FAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='4c4107d39dc24d68b8a715d40bc78bca', short_id='136', title="FRUITERERS'", type='1', description="FRUITERERS'", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4ce8c636f57c411cae6e6978559a64b8', short_id='66', title='THE GENIUS OF THE WEATHER', type='1', description='THE GENIUS OF THE WEATHER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4d22cd5a8f3549db9ba634550d8180ec', short_id='135', title="POULTERERS' SHOPS", type='1', description="POULTERERS' SHOPS", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='4e75c7bf4903499fa4ec6e9f4583fac8', short_id='145', title='MARTHA', type='2', description='MARTHA', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='4f370d7f0d734f92b6118d88e79d886a', short_id='0', title='PROJECT GUTENBERG', type='8', description='PROJECT GUTENBERG', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='4fde7a56185b407287e52cc57c23e67d', short_id='161', title='OLD MAN', type='4', description='OLD MAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='508b5c929a8147cd8e7ad855c42d2d8b', short_id='180', title='YES AND NO', type='5', description='YES AND NO', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='51786a53a4e94b53b7c01ce9d74bb9c3', short_id='222', title='MISSISSIPPI', type='8', description='MISSISSIPPI', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='520d4398eb9a456bb82b964def6e7af6', short_id='53', title='UNION WORKHOUSES', type='1', description='UNION WORKHOUSES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='53c3f1991729403ca847df8bb9c62128', short_id='139', title='CHRISTMAS DAY', type='2', description='CHRISTMAS DAY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='555a6f653f454ff4bb07e48ae79a540d', short_id='44', title="SCROOGE'S COUNTING-HOUSE", type='1', description="SCROOGE'S COUNTING-HOUSE", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='558b3c526384498786816333a727b9b6', short_id='24', title='CAROLINE', type='6', description='CAROLINE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='55979c145edf48e7877b3991b1e9f12c', short_id='225', title='PROFESSOR MICHAEL S. HART', type='8', description='PROFESSOR MICHAEL S. HART', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='55e3a006011d4b14a7062294f98e4977', short_id='155', title='THE LAMPLIGHTER', type='1', description='THE LAMPLIGHTER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='56bf3e638b424cc6acb0e55b8790fe61', short_id='117', title='CHRISTMAS PAST', type='1', description='CHRISTMAS PAST', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='570173a4496b4b46a5e81f5ee799733f', short_id='47', title='CHRISTMAS', type='1', description='CHRISTMAS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=9, attributes=None),
#  Entity(id='574900558d71499691573da37dbf34e4', short_id='86', title='THE STRANGE FIGURE', type='1', description='THE STRANGE FIGURE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='5856cc0228fa4101962730baf7d15892', short_id='223', title='SALT LAKE CITY', type='8', description='SALT LAKE CITY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='586193437d6d4bc2b156e5d8f073d825', short_id='23', title='BELLE', type='5', description='BELLE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='5933eaea758b4fd3811b78af1ce83052', short_id='165', title='MEN ON BOARD', type='9', description='MEN ON BOARD', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='5adeb2fd7463496787f670d5344b1a83', short_id='164', title='TWO MEN', type='11', description='TWO MEN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='5b932f4d5c544b648d35af136acfd1af', short_id='43', title="SCROOGE'S NEPHEW", type='1', description="SCROOGE'S NEPHEW", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='5befb2637c17466699226a5c602e9069', short_id='73', title='QUEENS OF SHEBA', type='7', description='QUEENS OF SHEBA', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='5c6faac584694fc094a9552e25452149', short_id='39', title='THE UNDERTAKER', type='1', description='THE UNDERTAKER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='5da6b379f6284b25be225e26a762aaba', short_id='80', title='THE CELLAR', type='1', description='THE CELLAR', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='6041ce29e51e4ee3888db60fa054e349', short_id='18', title='GHOST OF JACOB MARLEY', type='5', description='GHOST OF JACOB MARLEY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='614380a21580450cb223eb65c782c0ba', short_id='125', title='THE DAUGHTER', type='-1', description='THE DAUGHTER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='62e4eee2405d4f35a8661b3cc97d5089', short_id='147', title='MASTER PETER', type='2', description='MASTER PETER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='655d7b2eb89948b5b7b4853ebd881665', short_id='195', title='PARLOUR', type='4', description='PARLOUR', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='656dc4d549a74b7492232de73df31802', short_id='198', title='CHARWOMAN', type='4', description='CHARWOMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='67c4c53107d9459fb925f03f3ac78f4e', short_id='132', title='GREAT BRITAIN', type='-1', description='GREAT BRITAIN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='697ffe9feda0452a955dd192a02dac8f', short_id='126', title='THE MOTHER', type='-1', description='THE MOTHER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='6a99fcd063fa4975978c2891b9b6a4d0', short_id='8', title='SUZANNE SHELL', type='0', description='SUZANNE SHELL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='6d509d0e429848779faa5d7b308aa638', short_id='49', title='CLERK', type='1', description='CLERK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='6f90e7d38b604d57bcca2fd8b1bd516f', short_id='142', title='TOWN', type='1', description='TOWN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='70978f7128794ab89b2d6ba139758e38', short_id='163', title='CHILDREN', type='4', description='CHILDREN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='711ee727e40545aca473ae9d3f164dc9', short_id='95', title='VALENTINE', type='1', description='VALENTINE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='712ed4a7cb4f40e38803882ac917bdb2', short_id='110', title='THE BAKER', type='5', description='THE BAKER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='71365c925c5c4bc1b059a1b1ddea2f81', short_id='108', title='THE HOUSEMAID', type='5', description='THE HOUSEMAID', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='728d49a565b04cbdb630e64ef05ee631', short_id='10', title='ONLINE DISTRIBUTED PROOFREADING TEAM', type='0', description='ONLINE DISTRIBUTED PROOFREADING TEAM', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='72fd931167ee4c2b9cc367cfeccfd786', short_id='208', title='THE GHOST OF CHRISTMAS PRESENT', type='1', description='THE GHOST OF CHRISTMAS PRESENT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='73b0e0a551dc454690bad3d6756912be', short_id='2', title='A CHRISTMAS CAROL', type='0', description='A CHRISTMAS CAROL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=8, attributes=None),
#  Entity(id='756ba1081f75405dbb6e6ad482e3e417', short_id='219', title='INDEMNITY', type='8', description='INDEMNITY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='75ab4558f5194554a8834f5f4304ebad', short_id='190', title='SHOP', type='4', description='SHOP', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='75ad3bb83f21431696e5e61883149e30', short_id='227', title='FOUNDATION', type='8', description='FOUNDATION', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='76d55ff1d0b94c24be81664f63c5fd16', short_id='22', title='DICK WILKINS', type='5', description='DICK WILKINS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='76f71716f34c4221b6842fdc33f7b8ab', short_id='224', title='MICHAEL S. HART', type='8', description='MICHAEL S. HART', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='79b6449fb65d4da8856ed497c564a6a9', short_id='94', title='ALI BABA', type='1', description='ALI BABA', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='79c9743b91c34addb4078147b4481c0b', short_id='13', title='MR. FEZZIWIG', type='5', description='MR. FEZZIWIG', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='7a5df0bc0a71469dab1e1c922bafc911', short_id='25', title='MRS. CRATCHIT', type='2', description='MRS. CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=14, attributes=None),
#  Entity(id='7ac103a0c6a9467ab7e31e0b484cb555', short_id='157', title='THE MOOR', type='10', description='THE MOOR', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='7c32805ea0eb462c9eb4b5468cb8f402', short_id='91', title='FARMERS', type='1', description='FARMERS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='7c589a1034d94dd8b6f694a1efd4f1b6', short_id='87', title='CITY', type='1', description='CITY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='7d8eb17010dc4eb49da67cc8e357e171', short_id='218', title='LIMITED WARRANTY, DISCLAIMER OF DAMAGES', type='8', description='LIMITED WARRANTY, DISCLAIMER OF DAMAGES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='7f2701241d404a9699b1c0587d07c03e', short_id='45', title="SCROOGE'S CLERK", type='1', description="SCROOGE'S CLERK", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='7f32030293ab434eb8c5730ed22c41c8', short_id='30', title='MRS. FEZZIWIG', type='5', description='MRS. FEZZIWIG', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='7f63082186b34dff845eae842dfa8cd8', short_id='93', title='GHOST', type='1', description='GHOST', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='80a01b1a903a469f9ba407d446709608', short_id='183', title='PHANTOM', type='1', description='PHANTOM', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='831c8b2a06cf403bbcdf7fbad7e55f2c', short_id='220', title='U.S. COPYRIGHT LAW', type='8', description='U.S. COPYRIGHT LAW', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='86bd766291de4dfb8438ac505c327a8c', short_id='217', title='RIGHT OF REPLACEMENT OR REFUND', type='8', description='RIGHT OF REPLACEMENT OR REFUND', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='874d920d39464b7a9dd3ea6f9eee4711', short_id='188', title='JACOB', type='1', description='JACOB', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='87845a23037848d9b58e0be1539a1ab3', short_id='19', title='JOE', type='-1', description='JOE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='88807ce13ab14110bd9234ebb69296ee', short_id='120', title='MOTHER', type='-1', description='MOTHER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='8a076b3c20334e3998624d9899b44eb5', short_id='61', title='COUNTING-HOUSE', type='2', description='COUNTING-HOUSE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='8c96fae6a4b448ac9b8ce3ca99d547d5', short_id='118', title='DOMESTIC BALL', type='5', description='DOMESTIC BALL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='8e5be5b1e63343b8a2f0af6baba70337', short_id='1', title='UNITED STATES', type='8', description='UNITED STATES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='8ffd46a4202346459336e9c4b7e4c10f', short_id='160', title='THE SHIP', type='9', description='THE SHIP', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='9208f851f93148b8aa4f5760351fe935', short_id='12', title='TIM CRATCHIT', type='2', description='TIM CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='92536143892c4b47945d649c2cb0aedd', short_id='158', title='THE HUT', type='4', description='THE HUT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='935aae12b36448bdab54b23483542ed6', short_id='107', title='THE FIDDLER', type='5', description='THE FIDDLER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='952b08ea7e8d48bd8ccc79ad78f3835c', short_id='21', title='MR. TOPPER', type='-1', description='MR. TOPPER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='96872eee0cdd417ba0c16984cf437362', short_id='55', title='THE LORD MAYOR', type='-1', description='THE LORD MAYOR', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='97b48239f4604560ae52d5755439215b', short_id='131', title='SPIRIT OF CHRISTMAS PRESENT', type='1', description='SPIRIT OF CHRISTMAS PRESENT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='97e9671e7d214fb1b9933372f9e39a49', short_id='89', title='MARKET-TOWN', type='1', description='MARKET-TOWN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='993045638448491c8fcdbe9d59b1ea35', short_id='134', title='HOUSE-FRONTS', type='1', description='HOUSE-FRONTS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='995e5585d4574d02b5108c38b9e06832', short_id='98', title='GENII', type='1', description='GENII', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='99a683e3c8fe48f48ba637c55db46d5c', short_id='129', title='GENTLEMEN OF THE FREE-AND-EASY SORT', type='1', description='GENTLEMEN OF THE FREE-AND-EASY SORT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='99bb9034ca064140a0bbcaaa7a405151', short_id='113', title='THE GIRL FROM NEXT DOOR BUT ONE', type='5', description='THE GIRL FROM NEXT DOOR BUT ONE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='9cb193afc5e5423a8f9298f423e790cc', short_id='109', title='THE COOK', type='5', description='THE COOK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='9df2d220303a4171b208a2f5779226b3', short_id='156', title='THE SPIRIT', type='1', description='THE SPIRIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='9efdb8d321d5445e9dfea1fa29a1b173', short_id='209', title="SCROOGE AND MARLEY'S", type='1', description="SCROOGE AND MARLEY'S", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='9f06306c9a944ed2a56e18141480af61', short_id='57', title='ST. DUNSTAN', type='-1', description='ST. DUNSTAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='a3572195248743568b6ce14394394b97', short_id='90', title='BOYS', type='1', description='BOYS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='a55585e910d946ceab19bbcf9584d341', short_id='123', title='THE SECOND OF THE THREE SPIRITS', type='1', description='THE SECOND OF THE THREE SPIRITS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='a576fece771e4165b738d532bce5b66a', short_id='40', title='THE CHIEF MOURNER', type='1', description='THE CHIEF MOURNER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='a5a7bb04b2524d62a85f241d02bff5a9', short_id='72', title='DUTCH MERCHANT', type='7', description='DUTCH MERCHANT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='a5a87c6ac0d5472da37ac2a44386119e', short_id='111', title='THE MILKMAN', type='5', description='THE MILKMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='a5bee48729364eef94dc043c682429a8', short_id='175', title='LONDON', type='-1', description='LONDON', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='a736c92e282d41aaaa1e390030317dd3', short_id='46', title='THE CITY', type='1', description='THE CITY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='a9ebcb82b5694ebf90e11747729afde1', short_id='11', title='PETER CRATCHIT', type='2', description='PETER CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='ab5f859905df47deb7dce3fad43e3a84', short_id='221', title='INTERNAL REVENUE SERVICE', type='8', description='INTERNAL REVENUE SERVICE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='ac2e3b3c40054b84bc026a376297604e', short_id='106', title='CHRISTMAS EVE PARTY', type='5', description='CHRISTMAS EVE PARTY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=12, attributes=None),
#  Entity(id='ac51fc86788d4094ae1d5b566d38ad81', short_id='74', title='ABRAHAMS', type='7', description='ABRAHAMS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='aea296544129403cb2263fde85b5cb43', short_id='189', title="'CHANGE", type='1', description="'CHANGE", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='af878082ebbf453aaac6caa7463348a6', short_id='184', title='BUSINESS MEN', type='1', description='BUSINESS MEN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='b094598505c541a79ead808acf183c24', short_id='75', title='BELSHAZZARS', type='7', description='BELSHAZZARS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='b16019e4f3f449bd9219fa31dbbdb977', short_id='187', title='TWO PERSONS MEETING', type='1', description='TWO PERSONS MEETING', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='b341012ab7b64a7091df7f713976c2fb', short_id='176', title='TWELFTH-NIGHT PARTY', type='1', description='TWELFTH-NIGHT PARTY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='b6b645896dc545a5920fc2c4a00357b9', short_id='26', title='BELINDA CRATCHIT', type='2', description='BELINDA CRATCHIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='b7465414546748a9934eb8e85ab27587', short_id='102', title='DAMASCUS', type='-1', description='DAMASCUS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='b7fde61247a54514a9482ae2a9b4efae', short_id='33', title='SCROOGE', type='1', description='SCROOGE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=123, attributes=None),
#  Entity(id='b8571fd02ddb4b2f8420a5b9eb1c416f', short_id='141', title='CHURCH AND CHAPEL', type='-1', description='CHURCH AND CHAPEL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='b98f7da9e5b345fcbac37f3d2ed726d4', short_id='174', title='UNCLE SCROOGE', type='5', description='UNCLE SCROOGE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='bc2474d410ae4bab8339cd255fc8a183', short_id='166', title='MINERS', type='10', description='MINERS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='bc566ac0a7fa4c88a8d1976175607eb3', short_id='65', title='CHRISTMAS EVE', type='1', description='CHRISTMAS EVE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='bd6d54a7a8d94de1bded3c5807a933ad', short_id='36', title="HAMLET'S FATHER", type='-1', description="HAMLET'S FATHER", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='bd932f7fe3764026b5cc799068856763', short_id='82', title='THE GHOST', type='1', description='THE GHOST', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=13, attributes=None),
#  Entity(id='becaebd5ae8e4c0981e67f34539b0d3c', short_id='206', title='JOE MILLER', type='-1', description='JOE MILLER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='bf75cac4650344729eb11a51fa4786b3', short_id='185', title='MAN WITH A MONSTROUS CHIN', type='-1', description='MAN WITH A MONSTROUS CHIN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='c008362d78374b47b44f4bebe1cbfe0a', short_id='152', title='PETER', type='2', description='PETER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='c03c1461548c4e20a594dd399578cb73', short_id='48', title='NEPHEW', type='1', description='NEPHEW', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='c097a581e9ee46948a4f2eff89009b8f', short_id='78', title="MARLEY'S GHOST", type='1', description="MARLEY'S GHOST", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='c0d4ef2502bb4d428241a2f34c99752d', short_id='204', title='CHURCHYARD', type='1', description='CHURCHYARD', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c0f067e15fbd407ab6d52e261f2b7487', short_id='116', title='FAIR YOUNG GIRL', type='1', description='FAIR YOUNG GIRL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c157def39acd4a6aadbbf13f5a2c3a73', short_id='99', title='PARROT', type='1', description='PARROT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c1e8f6a1790a42cba70228fa79dbf313', short_id='20', title='EBENEZER SCROOGE', type='5', description='EBENEZER SCROOGE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=12, attributes=None),
#  Entity(id='c22dbf4d427146e899c96cafd572d0cc', short_id='85', title='INVISIBLE WORLD', type='1', description='INVISIBLE WORLD', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='c372fdfff70e4c46b6ac4907cf78c900', short_id='76', title='APOSTLES', type='7', description='APOSTLES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c4e8ca318c6046a58ed833be1aa86732', short_id='210', title='THE PORTLY GENTLEMAN', type='1', description='THE PORTLY GENTLEMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='c5490070637e48e596a688dc7262a166', short_id='59', title='THE LITTLE TAILOR', type='-1', description='THE LITTLE TAILOR', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c5655c5a3dea49da8de6775d7fd60bc6', short_id='100', title='ROBIN CRUSOE', type='1', description='ROBIN CRUSOE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='c84df7e888ab4ad29d2708007be5dd70', short_id='178', title='CHRISTMAS HOLIDAYS', type='1', description='CHRISTMAS HOLIDAYS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='cbe6aa4cd959402189cd9a76d0a71ed2', short_id='138', title='HOLLY', type='1', description='HOLLY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='ccd466f13dcf4b699a30e95ed549178d', short_id='52', title='THE GENTLEMAN', type='1', description='THE GENTLEMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='cce4c8578e3b4ca7ac6cb03c33dc9813', short_id='196', title='LAUNDRESS', type='4', description='LAUNDRESS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='cdc960b51aee454aac0468b8568d3ae0', short_id='214', title='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', type='8', description='PROJECT GUTENBERG LITERARY ARCHIVE FOUNDATION', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=8, attributes=None),
#  Entity(id='ce62fb5eacf74c18a8d6b7417a028b47', short_id='14', title='FRED', type='5', description='FRED', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='cee113b74c4a49f29489ed5127301cf5', short_id='104', title='SCHOOLMASTER', type='5', description='SCHOOLMASTER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='cf70df771d6c464e93b7ff99d2ea8142', short_id='3', title='CHARLES DICKENS', type='0', description='CHARLES DICKENS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='d0f3ed3eb4bf4f7bb817e3496c9e33a7', short_id='128', title='FATHER', type='-1', description='FATHER', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='d13d0b9e2a4448d1a0f8c1df7a303dd8', short_id='58', title='THE MAIN STREET', type='-1', description='THE MAIN STREET', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='d20270db61844a6480559bc79103ab73', short_id='162', title='OLD WOMAN', type='4', description='OLD WOMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='d27215aa34204d8794c8a5ea7fb9459f', short_id='215', title='WWW.GUTENBERG.ORG', type='8', description='WWW.GUTENBERG.ORG', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='d43a4bf0218041a6a0d39fa269891322', short_id='32', title='FEZZIWIG', type='5', description='FEZZIWIG', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=11, attributes=None),
#  Entity(id='d936f32f716e48e2b592f2b620472ffa', short_id='140', title="BAKERS' SHOPS", type='1', description="BAKERS' SHOPS", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='d99b325cde304d31bcdb16ba4cd3abbf', short_id='41', title='SCROOGE AND MARLEY', type='1', description='SCROOGE AND MARLEY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='d9f4a9704b20480db8b8c4e3899a3751', short_id='37', title='THE CLERGYMAN', type='1', description='THE CLERGYMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='daf6294d55eb45ee82a26407b59c8caf', short_id='226', title='U.S.', type='8', description='U.S.', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='db2fae4591c34aa1bf38e07a3b3636a3', short_id='60', title='THE ANCIENT TOWER OF A CHURCH', type='1', description='THE ANCIENT TOWER OF A CHURCH', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='db870c9e44834159a707535acb201bc6', short_id='207', title="THE POULTERER'S", type='1', description="THE POULTERER'S", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='dc304fcbaadf4249887139c0a1c1c4fe', short_id='84', title='PHANTOMS', type='1', description='PHANTOMS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='dd038db7190f4fe9a2abb9aadf45808b', short_id='194', title='OLD JOE', type='4', description='OLD JOE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='df1c0f45b5ef434c95bcc99a88a8c0c4', short_id='54', title='THE TREADMILL AND THE POOR LAW', type='1', description='THE TREADMILL AND THE POOR LAW', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='df4bc230438f422682ee570d910724c5', short_id='124', title='THE MASTER OF THE HOUSE', type='-1', description='THE MASTER OF THE HOUSE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='dfcefe8a9d384ca4895e4c468528e286', short_id='56', title='MANSION HOUSE', type='-1', description='MANSION HOUSE', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e00ccddeec394b1ca028756c91a28ab5', short_id='130', title='JOLLY GIANT', type='1', description='JOLLY GIANT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e04fc15dcb884c4d9b29df42619cb091', short_id='172', title="BLIND MAN'S-BUFF PARTY", type='3', description="BLIND MAN'S-BUFF PARTY", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e0d2a6a97f13446e854f7fe23596812a', short_id='83', title='THREE SPIRITS', type='1', description='THREE SPIRITS', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e10066894c9140e893dc2300f6624fd1', short_id='150', title='CHRISTMAS MEAL', type='2', description='CHRISTMAS MEAL', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=7, attributes=None),
#  Entity(id='e2de0fdf4587443295fe5a3b97d9135d', short_id='101', title='FRIDAY', type='1', description='FRIDAY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e3654fbec18041179cc938e41ab7cd78', short_id='88', title='OPEN COUNTRY ROAD', type='1', description='OPEN COUNTRY ROAD', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e478fddb40f044169a81153ee5f8bb3b', short_id='5', title='PHILADELPHIA', type='-1', description='PHILADELPHIA', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=0, attributes=None),
#  Entity(id='e7394767c46c4cf187ebb144ada00564', short_id='199', title="CAROLINE'S HUSBAND", type='6', description="CAROLINE'S HUSBAND", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='e822a860386e4bc1adf865c5051038d3', short_id='68', title='ALDERMEN', type='1', description='ALDERMEN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='e9829f782df6461691c81a1b206ef95a', short_id='38', title='THE CLERK', type='1', description='THE CLERK', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='e9b37dc43c9d4d88afccee6224f7182f', short_id='96', title='ORSON', type='1', description='ORSON', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='ea84881a96d644c5884e6675ee1ff591', short_id='211', title='THE BOY', type='1', description='THE BOY', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='f236a5f31fe74694ab1f435dba471a37', short_id='70', title="SCROOGE'S HOUSE", type='7', description="SCROOGE'S HOUSE", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='f489885b414f4818873b9175c667a6ca', short_id='119', title='SPIRIT', type='1', description='SPIRIT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='f493c3021464426c937467b846fdcbce', short_id='191', title='WOMAN', type='4', description='WOMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=4, attributes=None),
#  Entity(id='f675eb0bc3554c7f8ad1c33d7ff28ced', short_id='179', title='MIDNIGHT', type='1', description='MIDNIGHT', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='f8ee38bcb37f4b92be9db2fc6cfaff6e', short_id='201', title='THE MAN', type='6', description='THE MAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='f92c5df1ba1a497e820ce681bcc06675', short_id='77', title="WINE-MERCHANT'S CELLARS", type='1', description="WINE-MERCHANT'S CELLARS", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='fb5c3f8f24e54e329fac12208336ffe6', short_id='200', title='HALF-DRUNKEN WOMAN', type='6', description='HALF-DRUNKEN WOMAN', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=2, attributes=None),
#  Entity(id='fc18d39cb306425f97dbc98e67477b71', short_id='216', title='PROJECT GUTENBERG™', type='8', description='PROJECT GUTENBERG™', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=5, attributes=None),
#  Entity(id='fc4e0665f6374672a2fe1951bdd3f829', short_id='197', title="UNDERTAKER'S MAN", type='4', description="UNDERTAKER'S MAN", description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=3, attributes=None),
#  Entity(id='fdee948a65da4ee5b6a3e25793dfab52', short_id='15', title='GHOST OF CHRISTMAS PAST', type='1', description='GHOST OF CHRISTMAS PAST', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='fedf3c73a3274d3db77d65c5398a8508', short_id='67', title='THE CORPORATION', type='1', description='THE CORPORATION', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None),
#  Entity(id='ffcb75801b0a4885aa444c93fb0680cd', short_id='205', title='BOY IN SUNDAY CLOTHES', type='1', description='BOY IN SUNDAY CLOTHES', description_embedding=None, name_embedding=None, community_ids=None, text_unit_ids=None, rank=1, attributes=None)]

# %% [markdown]
# Vamos a importar los informes de comunidad. Es interesante leer como con el LLM hemos conseguido hacer un resumen de entidades abstractas que, en principio, no figuran explicitamente en el libro.

# %%
report_df = pd.read_parquet(f"{OUTPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
report_df.head(4)
# Out:
#                                      id  human_readable_id  community  level  \
# 0  4040ff80-3c0a-4698-b513-0d0670425656                 37         37      4
# 1  323af97c-7b5f-45a7-91ad-1a7a5bc6d494                 38         38      4
# 2  62b7bd68-bfd9-4c62-a271-26a492f7010a                 34         34      3
# 3  f8c3132c-0691-4711-88e6-2130fad157d6                 35         35      3
#
#                                                      title  \
# 0    Scrooge's Transformation and Interactions with Ghosts
# 1  Scrooge, Scrooge and Marley's, and The Portly Gentleman
# 2      Scrooge and the Ghosts: A Christmas Carol Community
# 3                    Scrooge, The Clerk, and Christmas Eve
#
#                                                                                                                                                                                                                                                                                                                                                                           summary  \
# 0                                The community revolves around the central character, Scrooge, and his interactions with various entities, most notably the Ghosts of Christmas Past, Present, and Yet to Come. Scrooge's relationships with these entities, as well as his past business partner Marley, significantly influence his character development throughout the story.
# 1                                                          The community revolves around three key entities: Scrooge, Scrooge and Marley's counting-house, and The Portly Gentleman. Scrooge is associated with both Scrooge and Marley's counting-house and The Portly Gentleman, while The Portly Gentleman has a direct relationship with Scrooge and Marley's counting-house.
# 2  The community revolves around the character Scrooge, a miserly businessman, and his interactions with various entities, most notably the Ghosts of Christmas Past, Present, and Yet to Come. These entities, along with others like Jacob Marley, Scrooge's deceased business partner, and the clerk, play significant roles in Scrooge's transformation throughout the story.
# 3                                                                                The community revolves around the character Scrooge, his employee The Clerk, and the event of Christmas Eve. Scrooge shows disdain for Christmas Eve, while The Clerk celebrates it. The Clerk also has a professional relationship with Scrooge, having signed the register of Marley's burial.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                
# 2   7.0
# 3   3.0
#
#                                                                                                                                                           rank_explanation  \
# 0            The impact severity rating is high due to the profound transformation of Scrooge's character and the potential societal implications of his changed behavior.
# 1                                                     The impact severity rating is low due to the limited number of entities and their interactions within the community.
# 2  The impact severity rating is high due to the profound transformation of Scrooge, a central character, and the potential societal implications of his changed behavior.
# 3                                                        The impact severity rating is low as the community is based on a fictional story with no real-world implications.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               findings  \
# 0  [{'explanation': 'Scrooge is initially depicted as a cold, unfeeling, and miserly man who despises Christmas and all things which engender happiness. However, throughout the story, Scrooge undergoes a significant transformation. After being visited by various spirits, including the ghost of Jacob Marley, his former business partner, and the Ghost of Christmas Past, Scrooge changes his ways. He is seen celebrating Christmas Day, buying a turkey for Bob Cratchit, and visiting his nephew's house. He also promises to raise Bob Cratchit's salary and assist his family, becoming a better person in the process [Data: Entities (33); Relationships (144, 158, 132, 134)].', 'summary': 'Scrooge's Character and Transformation'}, {'explanation': 'The Ghosts of Christmas Past, Present, and Yet to Come play a significant role in Scrooge's transformation. These spectral entities visit Scrooge, showing him scenes from his past, present, and potential future. The purpose of these visits is to provide Scrooge with a comprehensive view of his life, allowing him to reflect on his past actions and decisions, and to show him the potential consequences of his current lifestyle. These interactions significantly influence Scrooge's character development [Data: Entities (93, 15, 16, 17); Relationships (144, 158, 27, 28, 29)].', 'summary': 'Role of Ghosts in Scrooge's Transformation'}, {'explanation': 'Scrooge's relationship with his deceased business partner, Marley, is another significant aspect of the story. Despite being dead, Marley visits Scrooge as a ghost, warning him about his life choices and the consequences of his actions. Marley's spectral presence and his concern for Scrooge's fate indicate a deep connection between the two, possibly as past associates or friends [Data: Entities (81, 34); Relationships (132, 100)].', 'summary': 'Scrooge's Relationship with Marley'}, {'explanation': 'Scrooge's workplace, the counting-house, and his employee, the clerk, are also important entities in the community. The clerk is threatened with dismissal by Scrooge for applauding his nephew's speech about Christmas. This interaction provides insight into Scrooge's initial character and his attitude towards Christmas [Data: Entities (212, 49); Relationships (113, 208)].', 'summary': 'Scrooge's Workplace and Employee'}, {'explanation': 'Scrooge interacts with various other entities throughout the story, including the portly gentlemen, the boy in Sunday clothes, and the Poulterer's. These interactions further illustrate Scrooge's transformation, as he changes from a man who refuses to donate to charity to a man who buys a turkey for his employee's family on Christmas Day [Data: Entities (50, 205, 202); Relationships (203, 201, 202)].', 'summary': 'Scrooge's Interaction with Other Entities'}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'explanation': 'Scrooge is a central figure in this community, having direct relationships with both Scrooge and Marley's counting-house and The Portly Gentleman. His association with the counting-house suggests a professional role, while his conversation with The Portly Gentleman indicates personal interactions. The nature of these relationships could provide insights into Scrooge's character and his influence within the community. [Data: Relationships (204, 203)]', 'summary': 'Scrooge's central role'}, {'explanation': 'Scrooge and Marley's counting-house is another key entity in this community. It is associated with both Scrooge and The Portly Gentleman, suggesting its importance as a location where significant interactions occur. The counting-house's role could be crucial in understanding the dynamics of this community. [Data: Entities (209), Relationships (204, 302)]', 'summary': 'Significance of Scrooge and Marley's counting-house'}, {'explanation': 'The Portly Gentleman is a character who interacts with both Scrooge and the counting-house. His presence and interactions could provide insights into the social dynamics within the community. The nature of his conversation with Scrooge and his visit to the counting-house could be significant in understanding the community's narrative. [Data: Entities (210), Relationships (203, 302)]', 'summary': 'Role of The Portly Gentleman'}]
# 2                                                                                                                                                                                                                                                                                                                                  [{'explanation': 'Scrooge, initially depicted as a cold, unfeeling, and miserly man, undergoes a significant transformation throughout the story. This transformation is largely facilitated by his interactions with various spirits, including the ghost of Jacob Marley, his former business partner, and the Ghosts of Christmas Past, Present, and Yet to Come. These spirits show him scenes from his past, present, and future, leading to a change of heart and a promise to assist his clerk's family [Data: Entities (33, 93, 81, 49); Relationships (144, 158, 132, 113)].', 'summary': 'Scrooge's transformation'}, {'explanation': 'The Ghosts of Christmas Past, Present, and Yet to Come play a crucial role in Scrooge's transformation. They guide Scrooge through various scenes from his past, present, and potential future, allowing him to reflect on his actions and their consequences. The Ghosts' interactions with Scrooge are instrumental in his eventual change of heart and his decision to assist his clerk's family [Data: Entities (93, 15, 16, 17); Relationships (144, 27, 28, 29)].', 'summary': 'Role of the Ghosts'}, {'explanation': 'Jacob Marley, Scrooge's deceased business partner, also plays a significant role in Scrooge's transformation. Despite being dead, Marley visits Scrooge as a ghost, warning him about his life choices and the consequences of his actions. Marley's spectral presence and his warnings set the stage for Scrooge's encounters with the Ghosts of Christmas [Data: Entities (81, 34); Relationships (132, 100)].', 'summary': 'Jacob Marley's influence'}, {'explanation': 'Scrooge's relationship with his clerk is another key aspect of the community. Initially, Scrooge is depicted as a harsh employer, threatening to fire his clerk for applauding his nephew's speech. However, following his transformation, Scrooge promises to assist his clerk's family, indicating a significant change in their relationship [Data: Entities (33, 49); Relationships (113)].', 'summary': 'Scrooge's relationship with his clerk'}, {'explanation': 'Scrooge's interactions with other entities, such as the Portly Gentleman and the boy in Sunday clothes, further illustrate his transformation. These interactions, which occur after his encounters with the Ghosts, demonstrate Scrooge's newfound generosity and kindness, contrasting with his initial miserly demeanor [Data: Entities (33, 210, 205); Relationships (203, 206)].', 'summary': 'Scrooge's interactions with other entities'}]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [{'explanation': 'Scrooge, a central character in the story, shows a strong disdain for Christmas Eve. This attitude is a significant aspect of his character and plays a crucial role in the narrative. His disdain for the holiday contrasts sharply with other characters, such as The Clerk, who celebrate it. This contrast could be indicative of Scrooge's isolation and his strained relationships with other characters. [Data: Entities (65), Relationships (122)]', 'summary': 'Scrooge's disdain for Christmas Eve'}, {'explanation': 'The Clerk, another character in the story, celebrates Christmas Eve. This celebration is marked by sliding down Cornhill and running home to Camden Town. The Clerk's celebration of the holiday contrasts with Scrooge's disdain for it, highlighting the different attitudes towards the holiday within the community. This contrast could be indicative of the different social positions and attitudes of the characters. [Data: Entities (65), Relationships (210)]', 'summary': 'The Clerk's celebration of Christmas Eve'}, {'explanation': 'Scrooge is the employer of The Clerk, indicating a professional relationship between the two. The Clerk also signed the register of Marley's burial, further demonstrating their professional connection. This relationship is significant as it provides context for the interactions between Scrooge and The Clerk, and it could be indicative of the power dynamics within the community. [Data: Entities (38), Relationships (103)]', 'summary': 'The professional relationship between Scrooge and The Clerk'}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    full_content_json  \
# 0  {\n    "title": "Scrooge's Transformation and Interactions with Ghosts",\n    "summary": "The community revolves around the central character, Scrooge, and his interactions with various entities, most notably the Ghosts of Christmas Past, Present, and Yet to Come. Scrooge's relationships with these entities, as well as his past business partner Marley, significantly influence his character development throughout the story.",\n    "rating": 7.0,\n    "rating_explanation": "The impact severity rating is high due to the profound transformation of Scrooge's character and the potential societal implications of his changed behavior.",\n    "findings": [\n        {\n            "summary": "Scrooge's Character and Transformation",\n            "explanation": "Scrooge is initially depicted as a cold, unfeeling, and miserly man who despises Christmas and all things which engender happiness. However, throughout the story, Scrooge undergoes a significant transformation. After being visited by various spirits, including the ghost of Jacob Marley, his former business partner, and the Ghost of Christmas Past, Scrooge changes his ways. He is seen celebrating Christmas Day, buying a turkey for Bob Cratchit, and visiting his nephew's house. He also promises to raise Bob Cratchit's salary and assist his family, becoming a better person in the process [Data: Entities (33); Relationships (144, 158, 132, 134)]."\n        },\n        {\n            "summary": "Role of Ghosts in Scrooge's Transformation",\n            "explanation": "The Ghosts of Christmas Past, Present, and Yet to Come play a significant role in Scrooge's transformation. These spectral entities visit Scrooge, showing him scenes from his past, present, and potential future. The purpose of these visits is to provide Scrooge with a comprehensive view of his life, allowing him to reflect on his past actions and decisions, and to show him the potential consequences of his current lifestyle. These interactions significantly influence Scrooge's character development [Data: Entities (93, 15, 16, 17); Relationships (144, 158, 27, 28, 29)]."\n        },\n        {\n            "summary": "Scrooge's Relationship with Marley",\n            "explanation": "Scrooge's relationship with his deceased business partner, Marley, is another significant aspect of the story. Despite being dead, Marley visits Scrooge as a ghost, warning him about his life choices and the consequences of his actions. Marley's spectral presence and his concern for Scrooge's fate indicate a deep connection between the two, possibly as past associates or friends [Data: Entities (81, 34); Relationships (132, 100)]."\n        },\n        {\n            "summary": "Scrooge's Workplace and Employee",\n            "explanation": "Scrooge's workplace, the counting-house, and his employee, the clerk, are also important entities in the community. The clerk is threatened with dismissal by Scrooge for applauding his nephew's speech about Christmas. This interaction provides insight into Scrooge's initial character and his attitude towards Christmas [Data: Entities (212, 49); Relationships (113, 208)]."\n        },\n        {\n            "summary": "Scrooge's Interaction with Other Entities",\n            "explanation": "Scrooge interacts with various other entities throughout the story, including the portly gentlemen, the boy in Sunday clothes, and the Poulterer's. These interactions further illustrate Scrooge's transformation, as he changes from a man who refuses to donate to charity to a man who buys a turkey for his employee's family on Christmas Day [Data: Entities (50, 205, 202); Relationships (203, 201, 202)]."\n        }\n    ]\n}
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       {\n    "title": "Scrooge, Scrooge and Marley's, and The Portly Gentleman",\n    "summary": "The community revolves around three key entities: Scrooge, Scrooge and Marley's counting-house, and The Portly Gentleman. Scrooge is associated with both Scrooge and Marley's counting-house and The Portly Gentleman, while The Portly Gentleman has a direct relationship with Scrooge and Marley's counting-house.",\n    "rating": 3.0,\n    "rating_explanation": "The impact severity rating is low due to the limited number of entities and their interactions within the community.",\n    "findings": [\n        {\n            "summary": "Scrooge's central role",\n            "explanation": "Scrooge is a central figure in this community, having direct relationships with both Scrooge and Marley's counting-house and The Portly Gentleman. His association with the counting-house suggests a professional role, while his conversation with The Portly Gentleman indicates personal interactions. The nature of these relationships could provide insights into Scrooge's character and his influence within the community. [Data: Relationships (204, 203)]"\n        },\n        {\n            "summary": "Significance of Scrooge and Marley's counting-house",\n            "explanation": "Scrooge and Marley's counting-house is another key entity in this community. It is associated with both Scrooge and The Portly Gentleman, suggesting its importance as a location where significant interactions occur. The counting-house's role could be crucial in understanding the dynamics of this community. [Data: Entities (209), Relationships (204, 302)]"\n        },\n        {\n            "summary": "Role of The Portly Gentleman",\n            "explanation": "The Portly Gentleman is a character who interacts with both Scrooge and the counting-house. His presence and interactions could provide insights into the social dynamics within the community. The nature of his conversation with Scrooge and his visit to the counting-house could be significant in understanding the community's narrative. [Data: Entities (210), Relationships (203, 302)]"\n        }\n    ]\n}
# 2                                                                                                                                                                                                                                                                                            {\n    "title": "Scrooge and the Ghosts: A Christmas Carol Community",\n    "summary": "The community revolves around the character Scrooge, a miserly businessman, and his interactions with various entities, most notably the Ghosts of Christmas Past, Present, and Yet to Come. These entities, along with others like Jacob Marley, Scrooge's deceased business partner, and the clerk, play significant roles in Scrooge's transformation throughout the story.",\n    "rating": 7.0,\n    "rating_explanation": "The impact severity rating is high due to the profound transformation of Scrooge, a central character, and the potential societal implications of his changed behavior.",\n    "findings": [\n        {\n            "summary": "Scrooge's transformation",\n            "explanation": "Scrooge, initially depicted as a cold, unfeeling, and miserly man, undergoes a significant transformation throughout the story. This transformation is largely facilitated by his interactions with various spirits, including the ghost of Jacob Marley, his former business partner, and the Ghosts of Christmas Past, Present, and Yet to Come. These spirits show him scenes from his past, present, and future, leading to a change of heart and a promise to assist his clerk's family [Data: Entities (33, 93, 81, 49); Relationships (144, 158, 132, 113)]."\n        },\n        {\n            "summary": "Role of the Ghosts",\n            "explanation": "The Ghosts of Christmas Past, Present, and Yet to Come play a crucial role in Scrooge's transformation. They guide Scrooge through various scenes from his past, present, and potential future, allowing him to reflect on his actions and their consequences. The Ghosts' interactions with Scrooge are instrumental in his eventual change of heart and his decision to assist his clerk's family [Data: Entities (93, 15, 16, 17); Relationships (144, 27, 28, 29)]."\n        },\n        {\n            "summary": "Jacob Marley's influence",\n            "explanation": "Jacob Marley, Scrooge's deceased business partner, also plays a significant role in Scrooge's transformation. Despite being dead, Marley visits Scrooge as a ghost, warning him about his life choices and the consequences of his actions. Marley's spectral presence and his warnings set the stage for Scrooge's encounters with the Ghosts of Christmas [Data: Entities (81, 34); Relationships (132, 100)]."\n        },\n        {\n            "summary": "Scrooge's relationship with his clerk",\n            "explanation": "Scrooge's relationship with his clerk is another key aspect of the community. Initially, Scrooge is depicted as a harsh employer, threatening to fire his clerk for applauding his nephew's speech. However, following his transformation, Scrooge promises to assist his clerk's family, indicating a significant change in their relationship [Data: Entities (33, 49); Relationships (113)]."\n        },\n        {\n            "summary": "Scrooge's interactions with other entities",\n            "explanation": "Scrooge's interactions with other entities, such as the Portly Gentleman and the boy in Sunday clothes, further illustrate his transformation. These interactions, which occur after his encounters with the Ghosts, demonstrate Scrooge's newfound generosity and kindness, contrasting with his initial miserly demeanor [Data: Entities (33, 210, 205); Relationships (203, 206)]."\n        }\n    ]\n}
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  {\n    "title": "Scrooge, The Clerk, and Christmas Eve",\n    "summary": "The community revolves around the character Scrooge, his employee The Clerk, and the event of Christmas Eve. Scrooge shows disdain for Christmas Eve, while The Clerk celebrates it. The Clerk also has a professional relationship with Scrooge, having signed the register of Marley's burial.",\n    "rating": 3.0,\n    "rating_explanation": "The impact severity rating is low as the community is based on a fictional story with no real-world implications.",\n    "findings": [\n        {\n            "summary": "Scrooge's disdain for Christmas Eve",\n            "explanation": "Scrooge, a central character in the story, shows a strong disdain for Christmas Eve. This attitude is a significant aspect of his character and plays a crucial role in the narrative. His disdain for the holiday contrasts sharply with other characters, such as The Clerk, who celebrate it. This contrast could be indicative of Scrooge's isolation and his strained relationships with other characters. [Data: Entities (65), Relationships (122)]"\n        },\n        {\n            "summary": "The Clerk's celebration of Christmas Eve",\n            "explanation": "The Clerk, another character in the story, celebrates Christmas Eve. This celebration is marked by sliding down Cornhill and running home to Camden Town. The Clerk's celebration of the holiday contrasts with Scrooge's disdain for it, highlighting the different attitudes towards the holiday within the community. This contrast could be indicative of the different social positions and attitudes of the characters. [Data: Entities (65), Relationships (210)]"\n        },\n        {\n            "summary": "The professional relationship between Scrooge and The Clerk",\n            "explanation": "Scrooge is the employer of The Clerk, indicating a professional relationship between the two. The Clerk also signed the register of Marley's burial, further demonstrating their professional connection. This relationship is significant as it provides context for the interactions between Scrooge and The Clerk, and it could be indicative of the power dynamics within the community. [Data: Entities (38), Relationships (103)]"\n        }\n    ]\n}
#
#        period  size
# 0  2025-01-13  72.0
# 1  2025-01-13   2.0
# 2  2025-01-13  74.0
# 3  2025-01-13   2.0

# %%
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
reports
# Out:
# [CommunityReport(id='5917a277-8bd0-448e-8e0e-7bfb1f8bd6ee', short_id='29', title="Scrooge's Transformation and the Ghostly Interactions", community_id='29', summary="The community revolves around the central character, Scrooge, and his interactions with various entities, notably the Ghosts and his clerk, Bob Cratchit. The narrative unfolds in the City of London, with Scrooge's office and the counting-house being significant locations. The story is marked by Scrooge's transformation from a cold, unfeeling man to a generous individual, influenced by his encounters with the Ghosts.", full_content="# Scrooge's Transformation and the Ghostly Interactions\n\nThe community revolves around the central character, Scrooge, and his interactions with various entities, notably the Ghosts and his clerk, Bob Cratchit. The narrative unfolds in the City of London, with Scrooge's office and the counting-house being significant locations. The story is marked by Scrooge's transformation from a cold, unfeeling man to a generous individual, influenced by his encounters with the Ghosts.\n\n## Scrooge's transformation\n\nScrooge, initially depicted as a cold, unfeeling, and miserly man, undergoes a significant transformation throughout the story. His transformation is triggered by his encounters with various spirits, including the ghost of Jacob Marley, his former business partner, and the Ghost of Christmas Past. These spirits show him scenes from his past, present, and future, leading to a change of heart. Scrooge is seen celebrating Christmas Day, buying a turkey for Bob Cratchit, and visiting his nephew's house. He also promises to raise Bob Cratchit's salary and assist his family, becoming a better person in the process [Data: Entities (33); Relationships (76, 200, 144, 122, 138, 190, 198, +more)].\n\n## Role of the Ghosts\n\nThe Ghosts play a significant role in the narrative, particularly in influencing Scrooge's transformation. The Ghost of Christmas Past shows Scrooge scenes from his past Christmases, while the Ghost of Christmas Present provides a glimpse into his current life. These supernatural entities make observations and guide Scrooge through past events, playing a significant role in the narrative. Their interactions with Scrooge lead to his eventual transformation, highlighting their crucial role in the story [Data: Entities (93, 15, 16, 17); Relationships (144, 27, 28, 29, +more)].\n\n## Significance of Bob Cratchit\n\nBob Cratchit, Scrooge's clerk, is another key entity in this community. Despite being underpaid and overworked
]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='b9720aa9-5aaf-46bc-88ad-a7c7f1c6701a', short_id='32', title="Christmas Day in 'A Christmas Carol'", community_id='32', summary="The community revolves around the event of Christmas Day in the story 'A Christmas Carol'. The key entities are Christmas Day, Scrooge, Bob Cratchit, and Belinda Cratchit. The relationships between these entities are primarily based on the events that unfold on Christmas Day.", full_content="# Christmas Day in 'A Christmas Carol'\n\nThe community revolves around the event of Christmas Day in the story 'A Christmas Carol'. The key entities are Christmas Day, Scrooge, Bob Cratchit, and Belinda Cratchit. The relationships between these entities are primarily based on the events that unfold on Christmas Day.\n\n## Significance of Christmas Day\n\nChristmas Day is a central entity in this community, serving as the day when the entire story unfolds. It is the day Scrooge wakes up to after being visited by the spirits and is celebrating. The events of the story, including Scrooge buying a turkey, are taking place on Christmas Day, which is a crucial aspect of the narrative. [Data: Entities (139), Relationships (200, 84, 64, 17)]\n\n## Role of Scrooge\n\nScrooge is a key character in this community, being the one who wakes up on Christmas Day after being visited by the spirits and is celebrating the holiday. The relationship between Scrooge and Christmas Day is crucial in understanding the dynamics of this community. [Data: Relationships (200)]\n\n## Role of Bob Cratchit\n\nBob Cratchit is another significant character in this community. The story of Bob Cratchit takes place on Christmas Day, which is a crucial aspect of the narrative. The relationship between Bob Cratchit and Christmas Day is crucial in understanding the dynamics of this community. [Data: Relationships (84)]\n\n## Role of Belinda Cratchit\n\nBelinda Cratchit is a character in the story and a member of the Cratchit family. The story of Belinda Cratchit takes place on Christmas Day, which is a crucial aspect of the narrative. The relationship between Belinda Cratchit, Bob Cratchit, and Christmas Day is crucial in understanding the dynamics of this community. [Data: Entities (26), Relationships (63, 64)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='7ad0b47e-935d-47aa-97d0-26887837d6db', short_id='33', title='Bob Cratchit and the Christmas Story', community_id='33', summary="The community revolves around Bob Cratchit, a character in a Christmas story, and his interactions with other characters and locations. The key entities include Scrooge, Mr. Scrooge's nephew, the Counting-house, and members of the Cratchit family. The relationships between these entities are primarily based on familial ties, employment, and events during Christmas.", full_content="# Bob Cratchit and the Christmas Story\n\nThe community revolves around Bob Cratchit, a character in a Christmas story, and his interactions with other characters and locations. The key entities include Scrooge, Mr. Scrooge's nephew, the Counting-house, and members of the Cratchit family. The relationships between these entities are primarily based on familial ties, employment, and events during Christmas.\n\n## Bob Cratchit's central role\n\nBob Cratchit is the central entity in this community, serving as a clerk for Scrooge and the father of the Cratchit family. His interactions with other characters and locations, such as the Counting-house, Cornhill, and Camden Town, form the basis of the community's structure. Despite his financial struggles, he is portrayed as a cheerful and loving person, which may influence the dynamics within the community. [Data: Entities (31), Relationships (76, 77, 78, 79, +more)]\n\n## Scrooge's interactions with the community\n\nScrooge is another key entity in this community, being the employer of Bob Cratchit and the uncle of Mr. Scrooge's nephew. His interactions with Bob Cratchit at the Counting-house and his generous act of buying a turkey for Bob Cratchit are significant events in the community. The nature of Scrooge's relationship with other entities could influence the dynamics within the community. [Data: Entities (203), Relationships (76, 198, 120)]\n\n## The Cratchit family\n\nThe Cratchit family, including Peter Cratchit, Tim Cratchit, and Martha Cratchit, are significant entities in the community. Their relationships with Bob Cratchit and their involvement in the Christmas story contribute to the community's structure. The dynamics within the Cratchit family could potentially influence the overall dynamics within the community. [Data: Entities (11, 12, 27), Relationships (15, 18, 65)]\n\n## Significance of locations\n\nLocations such as the Counting-house, Cornhill, and Camden Town play significant roles in the community. The Counting-house is the workplace of Bob Cratchit and Scrooge, while Cornhill and Camden Town are places where Bob Cratchit celebrates Christmas Eve. These locations are integral to the community's structure and the events that take place within it. [Data: Entities (61, 62, 63), Relationships (77, 78, 79)]", rank=2.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='d89a231f-c615-428e-8a82-ff3498036b98', short_id='13', title='The Ghost and Scrooge: A Christmas Carol', community_id='13', summary="The community revolves around the character 'The Ghost' from Charles Dickens' 'A Christmas Carol', who interacts with Scrooge, guiding him through different scenes from his past and future. The Ghost has relationships with various entities such as Scrooge, Bob Cratchit, Mrs. Cratchit, Tiny Tim, and others, all of which are associated with the Christmas holidays.", full_content="# The Ghost and Scrooge: A Christmas Carol\n\nThe community revolves around the character 'The Ghost' from Charles Dickens' 'A Christmas Carol', who interacts with Scrooge, guiding him through different scenes from his past and future. The Ghost has relationships with various entities such as Scrooge, Bob Cratchit, Mrs. Cratchit, Tiny Tim, and others, all of which are associated with the Christmas holidays.\n\n## The Ghost as a central character\n\nThe Ghost is a central entity in this community, serving as a guide for Scrooge on a journey of self-discovery and redemption. The Ghost shows Scrooge scenes from his past and informs him about the future of Tiny Tim. The Ghost's visit serves as a warning to Scrooge about his life choices, prompting a profound transformation in Scrooge's character. [Data: Entities (82), Relationships (133, 90, 61, 38, 235, +more)]\n\n## Scrooge's transformation\n\nScrooge is another key entity in this community, undergoing a significant transformation throughout the text. Scrooge is expecting a visitation from The Ghost when the bell tolls one. The Ghost guides Scrooge on a journey of self-discovery and redemption, showing him scenes from his past and informing him about the future of Tiny Tim. The Ghost's visit serves as a warning to Scrooge about his life choices, prompting a profound transformation in Scrooge's character. [Data: Relationships (133, 187, 188, 184, +more)]\n\n## The Ghost's interactions with other characters\n\nThe Ghost interacts with various characters in the story, showing Scrooge scenes from their lives. These characters include Bob Cratchit, Mrs. Cratchit, Tiny Tim, and others. The Ghost's interactions with these characters provide Scrooge with a deeper understanding of their lives and the impact of his actions on them. [Data: Relationships (90, 61, 235, 234, 236, +more)]\n\n## The Ghost's association with Christmas holidays\n\nThe Ghost is closely associated with the Christmas holidays, guiding Scrooge through different scenes from his past and future during this time. The Ghost's life on the globe ends at midnight, marking the end of the Christmas holidays. The Ghost's association with the Christmas holidays is significant in understanding the timing and context of its interactions with Scrooge and other characters. [Data: Entities (178, 179), Relationships (187, 188, 232, 233, +more)]", rank=7.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id
' Shops\n\nThe Spirit is known for sprinkling incense on dinners at the bakers' shops. This unique touch to its supernatural presence suggests that the Spirit's influence extends to everyday places and activities within the community. The Spirit's actions at the bakers' shops could potentially affect the dining experiences of the community members [Data: Entities (140), Relationships (252)].\n\n## Spirit's Presentation of Ignorance and Want\n\nThe Spirit presents Ignorance and Want to Scrooge as symbols. These symbolic figures represent societal issues that Scrooge is made aware of. The presentation of these symbols by the Spirit could potentially influence Scrooge's understanding and perception of societal issues, thereby affecting his actions and decisions [Data: Entities (181, 182), Relationships (253, 254)].", rank=7.5, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='9e8ca358-ee26-40a2-a5f3-877a9d911482', short_id='17', title='The Cratchit Family and Christmas Meal', community_id='17', summary="The community revolves around the Cratchit family, with Mrs. Cratchit, Bob Cratchit, and their children including Tiny Tim, Peter, Martha, Master Peter, Miss Belinda, and the two young Cratchits. The family's interactions and relationships are centered around the preparation and participation in the Christmas meal. Scrooge, an external entity, has significant relationships with the family members, particularly Bob Cratchit, Tiny Tim, and Peter.", full_content="# The Cratchit Family and Christmas Meal\n\nThe community revolves around the Cratchit family, with Mrs. Cratchit, Bob Cratchit, and their children including Tiny Tim, Peter, Martha, Master Peter, Miss Belinda, and the two young Cratchits. The family's interactions and relationships are centered around the preparation and participation in the Christmas meal. Scrooge, an external entity, has significant relationships with the family members, particularly Bob Cratchit, Tiny Tim, and Peter.\n\n## Mrs. Cratchit's central role in the family\n\nMrs. Cratchit is a key figure in the Cratchit family, being the wife of Bob Cratchit and the mother of their children. She is responsible for the preparation of the Christmas meal, indicating her central role in the family's activities. Mrs. Cratchit also has a significant relationship with Scrooge, Bob's employer, although it is marked by negativity [Data: Entities (25); Relationships (59, 50, 58, 60, 53, 55, 51, 56, 57)]\n\n## Bob Cratchit's relationship with Scrooge\n\nBob Cratchit, the husband of Mrs. Cratchit and father of their children, works alongside Scrooge. Despite Scrooge's negative reputation, Bob holds him in high regard, referring to him as the Founder of the Feast. This relationship is significant as it connects the Cratchit family with Scrooge, an external entity [Data: Entities (151); Relationships (174, 50, 82, 86, 87, 83, 88)]\n\n## Tiny Tim's health and relationship with Scrooge\n\nTiny Tim, the youngest son of Bob and Mrs. Cratchit, is physically weak and disabled, making his health a major concern for the family. Interestingly, Scrooge treats Tiny Tim like a second son and is deeply concerned about his future, indicating a significant relationship between them [Data: Entities (144); Relationships (173, 82, 262)]\n\n## Peter's future prospects\n\nPeter, one of the Cratchit children, is expected to become a man of business in the future. This suggests that Peter might have a significant role in the family's future economic stability. His relationship with Scrooge, who is a businessman himself, could be influential in this regard [Data: Entities (152); Relationships (197, 87, 265)]\n\n## The Christmas meal as a family event\n\nThe Christmas meal is a significant event for the Cratchit family, with all family members contributing to its preparation. This event not only signifies the family's unity but also their economic status, as the meal is a significant expenditure for the family. The meal also serves as a connection point for Scrooge, who is indirectly involved in the event through his relationships with the family members [Data: Entities (150); Relationships (86, 58, 266, 268, 269, 270)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id
]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='8433dba8-9be5-497b-b75c-49128dac6ae3', short_id='20', title="Scrooge's Visit to The Hut", community_id='20', summary="The community revolves around 'The Hut', a place where a cheerful company, including children and an old woman, is gathered to celebrate Christmas. Scrooge visits this place with the Spirit, indicating a significant event in the narrative.", full_content="# Scrooge's Visit to The Hut\n\nThe community revolves around 'The Hut', a place where a cheerful company, including children and an old woman, is gathered to celebrate Christmas. Scrooge visits this place with the Spirit, indicating a significant event in the narrative.\n\n## The Hut as the central location\n\n'The Hut' is the central entity in this community, serving as the location for a Christmas celebration. This place is the common link between all other entities, suggesting its significance in the narrative. The Hut's association with the festive gathering could potentially lead to insights about the nature of the celebration and the characters involved. [Data: Entities (158), Relationships (178, 273, 275, 274)]\n\n## Presence of Children\n\nChildren are present in the hut, indicating a family-oriented gathering. Their presence could potentially provide insights into the familial dynamics within the community and the nature of the celebration. [Data: Entities(163), Relationships (275)]\n\n## Role of the Old Woman\n\nThe old woman is a character present in the hut. Her presence could potentially provide insights into the age dynamics within the community and her role in the celebration. [Data: Entities(162), Relationships (274)]\n\n## Scrooge's Visit\n\nScrooge visits the hut with the Spirit, indicating a significant event in the narrative. This visit could potentially provide insights into Scrooge's character development and his relationship with the other characters. [Data: Relationships (178)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='4fb3c57c-e92d-4fbd-900d-ef918c80ea93', short_id='21', title='The Shop and its Visitors', community_id='21', summary='The community revolves around a shop, run by an old man, and visited by various characters including Scrooge, a man in faded black, and two women. The shop is described as a place of infamous resort, dealing in various items of questionable value.', full_content="# The Shop and its Visitors\n\nThe community revolves around a shop, run by an old man, and visited by various characters including Scrooge, a man in faded black, and two women. The shop is described as a place of infamous resort, dealing in various items of questionable value.\n\n## The Shop as the central location\n\nThe shop is the central entity in this community, serving as a meeting point for various characters. It is described as a place of infamous resort, dealing in iron, old rags, bottles, bones, and greasy offal. The shop's reputation and the nature of its dealings could potentially lead to issues such as conflicts or disputes among its visitors. [Data: Entities (190), Relationships (193, 288, 290, 278, 289, +more)]\n\n## The Old Man's role in the community\n\nThe Old Man is another key entity in this community, being the owner of the shop. Despite his age, he maintains a lively and spirited demeanor. His character and his role in running the shop could be significant in understanding the dynamics of this community. [Data: Entities(161), Relationships (278, 273)]\n\n## The Visitors of the Shop\n\nThe shop is visited by various characters, including Scrooge, a man in faded black, and two women. These visitors interact with each other and with the shop, contributing to the dynamics of the community. The nature of their interactions and their reasons for visiting the shop could be significant in understanding the community. [Data: Relationships (193, 68, 290, 67, 289)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='9402a5be-861d-41e7-bbd9-cdc60f1d27b4', short_id='22', title="Ebenezer Scrooge and the Characters of 'A Christmas Carol'", community_id='22', summary="The community revolves around the character Ebenezer Scrooge from the story 'A Christmas Carol'. Scrooge has relationships with several other characters, including Belle, Fan, the Ghost of Jacob Marley, and Dick Wilkins. These relationships provide insight into Scrooge's past and his transformation throughout the story.", full_content="# Ebenezer Scrooge and the Characters of 'A Christmas Carol'\n\nThe community revolves around the character Ebenezer Scrooge from the story 'A Christmas Carol'. Scrooge has relationships with several other characters, including Belle, Fan, the Ghost of Jacob Marley, and Dick Wilkins. These relationships provide insight into Scrooge's past and his transformation throughout the story.\n\n## Ebenezer Scrooge as the central character\n\nEbenezer Scrooge is the central character in this community, serving as the main protagonist in 'A Christmas Carol'. He is depicted as a grasping, covetous old man, who is visited by the ghost of his former business partner, Jacob Marley. Scrooge's relationships with other characters provide insight into his past and his transformation
the nature of the celebration and the reactions it provokes. [Data: Entities (160), Relationships (180, 277)]\n\n## 'Men on Board' as key characters\n\n'Men on Board' are another key entity in this community, being the characters who are on the ship visited by Scrooge and the Spirit. The nature of 'Men on Board' and their celebration could be a potential source of threat, depending on their objectives and the reactions they provoke. The relationship between 'Men on Board' and the ship is crucial in understanding the dynamics of this community. [Data: Entities(165), Relationships (277)]\n\n## Role of Scrooge and the Spirit\n\nScrooge and the Spirit visit the ship, indicating their involvement in the community's dynamics. Their visit to the ship could be a potential source of threat, depending on the nature of their visit and the reactions it provokes. The relationship between Scrooge, the Spirit, and the ship is crucial in understanding the dynamics of this community. [Data: Relationships (180)]", rank=2.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='def25d51-29eb-4363-9981-200d597cea16', short_id='10', title='The Moor and its Inhabitants', community_id='10', summary="The community revolves around 'The Moor', a bleak and desolate place visited by Scrooge and the Spirit. The Moor is inhabited by miners who live and work there.", full_content="# The Moor and its Inhabitants\n\nThe community revolves around 'The Moor', a bleak and desolate place visited by Scrooge and the Spirit. The Moor is inhabited by miners who live and work there.\n\n## The Moor as a central location\n\n'The Moor' is the central entity in this community, described as a bleak and desolate place. It is visited by Scrooge and the Spirit, suggesting its significance in the narrative. The Moor's desolate nature could potentially reflect on the living conditions and lifestyle of its inhabitants. [Data: Entities (157), Relationships (177, 272)]\n\n## Role of Miners in the community\n\nMiners are the inhabitants of The Moor, living and working in this desolate place. Their presence suggests a hardworking and resilient community, capable of enduring harsh conditions. The relationship between the miners and The Moor is crucial in understanding the dynamics of this community. [Data: Entities (166), Relationships (272)]\n\n## Scrooge's visit to The Moor\n\nScrooge visits The Moor with the Spirit, indicating an external interest or concern in the community. This visit could potentially impact the community, depending on the nature of Scrooge's interactions and the reactions they provoke. The relationship between Scrooge and The Moor is significant in understanding the external influences on this community. [Data: Relationships (177)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None),
#  CommunityReport(id='d62a1c75-1a96-4a0b-b507-eab6eb2df9be', short_id='11', title='The Lighthouse and the Two Men', community_id='11', summary='The community revolves around the Lighthouse, a solitary structure on a reef of sunken rocks, and the Two Men who are celebrating Christmas there. The Lighthouse is visited by Scrooge and the Spirit, indicating a connection to a larger narrative.', full_content="# The Lighthouse and the Two Men\n\nThe community revolves around the Lighthouse, a solitary structure on a reef of sunken rocks, and the Two Men who are celebrating Christmas there. The Lighthouse is visited by Scrooge and the Spirit, indicating a connection to a larger narrative.\n\n## The Lighthouse as a central location\n\nThe Lighthouse is a key entity in this community, serving as the location where the Two Men are celebrating Christmas. It is described as a solitary structure built on a reef of sunken rocks, suggesting its isolation and potential vulnerability. The Lighthouse is also visited by Scrooge and the Spirit, indicating its connection to a larger narrative. However, the limited interaction of the Lighthouse with the broader community reduces its potential impact. [Data: Entities (159), Relationships (179, 276)]\n\n## The Two Men's role in the community\n\nThe Two Men are another key entity in this community, being the characters who are celebrating Christmas in the Lighthouse. Their celebration suggests a sense of camaraderie and resilience despite their isolated location. However, their limited interaction with the broader community and their dependence on the Lighthouse for their narrative significance reduces their potential impact. [Data: Entities (164), Relationships (276)]\n\n## Scrooge's visit to the Lighthouse\n\nScrooge's visit to the Lighthouse with the Spirit is a significant event in this community. This visit connects the isolated Lighthouse and the Two Men to a larger narrative, potentially amplifying their significance. However, the limited details about Scrooge's visit and its implications for the community reduce its potential impact. [Data: Relationships (179)]", rank=3.0, full_content_embedding=None, attributes=None, size=None, period=None)]

cannot survive without widespread\npublic support and donations to carry out its mission of\nincreasing the number of public domain and licensed works that can be\nfreely distributed in machine-readable form accessible by the widest\narray of equipment including outdated equipment. Many small donations\n($1 to $5,000) are particularly important to maintaining tax exempt\nstatus with the IRS.\n\nThe Foundation is committed to complying with the laws regulating\ncharities and charitable donations in all 50 states of the United\nStates. Compliance requirements are not uniform and it takes a\nconsiderable effort, much paperwork and many fees to meet and keep up\nwith these requirements. We do not solicit donations in locations\nwhere we have not received written confirmation of compliance. To SEND\nDONATIONS or determine the status of compliance for any particular state\nvisit www.gutenberg.org/donate.\n\nWhile we cannot and do not solicit contributions from states where we\nhave not met the solicitation requirements, we know of no prohibition\nagainst accepting unsolicited donations from donors in such states who\napproach us with offers to donate.\n\nInternational donations are gratefully ac ...

# %% [markdown]
# <div style="text-align: justify;">
#
# Este bloque de código configura todo el entorno necesario para realizar consultas mediante el enfoque GraphRAG. En primer lugar, se leen y procesan las salidas de la indexación: se cargan los datos de entidades, embeddings, reportes de comunidades y unidades de texto desde archivos Parquet, y se transforman en estructuras de datos alineadas con nuestro modelo de conocimiento.
#
# A continuación, se establece una conexión con una base de datos vectorial (LanceDB) a través de un objeto llamado `description_embedding_store`, que almacenará las representaciones vectoriales de las descripciones de las entidades.
#
# El código procede a configurar la interfaz con el API de OpenAI, definiendo el token (que en este ejemplo se deja vacío por motivos de seguridad), el modelo LLM (en este caso, GPT-4-32k) y el modelo de embeddings (text-embedding-ada-002). Se crea también un codificador de tokens mediante la biblioteca `tiktoken`, el cual es esencial para gestionar la longitud de los textos en función del límite de tokens del modelo.
#
# Con estos elementos, se construye un objeto `LocalSearchMixedContext`, que actúa como ensamblador del contexto para las consultas. Este objeto integra los reportes de comunidades, las unidades de texto, las entidades, las relaciones (y opcionalmente las covariables) junto con el almacenamiento de embeddings, lo que permite componer el contexto relevante a partir de diversas fuentes de información.
#
# Finalmente, se definen dos conjuntos de parámetros: uno para la construcción del contexto (`local_context_params`), que incluye proporciones de contribución de las diferentes fuentes y límites de tokens, y otro para el LLM (`llm_params`), con parámetros como el número máximo de tokens y la temperatura de generación. Con estos parámetros, se instancia el motor de búsqueda local (`LocalSearch`), que es el componente encargado de generar respuestas basadas en el contexto integrado, devolviendo resultados en formato de múltiples párrafos.
#
# En resumen, este código orquesta la integración de datos indexados, la conexión con la base de datos vectorial, la configuración de los modelos de OpenAI y la construcción del contexto de búsqueda, para finalmente crear un motor de búsqueda  capaz de responder consultas.
#
# </div>

# %%
# setup (see also ../../local_search.ipynb)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)

description_embedding_store = LanceDBVectorStore(
    collection_name="default-entity-description",
)
description_embedding_store.connect(db_uri=LANCEDB_URI)
#covariate_df = pd.read_parquet(f"{OUTPUT_DIR}/{COVARIATE_TABLE}.parquet")
#claims = read_indexer_covariates(covariate_df)
#covariates = {"claims": claims}
report_df = pd.read_parquet(f"{OUTPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
text_unit_df = pd.read_parquet(f"{OUTPUT_DIR}/{TEXT_UNIT_TABLE}.parquet")
text_units = read_indexer_text_units(text_unit_df)

api_key = " "
llm_model = "gpt-4-32k"

embedding_model = "text-embedding-ada-002"

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_version= "2024-02-15-preview",
    api_base= "https://azureopenaimark3.openai.azure.com/" ,
    deployment_name = "gpt-4-32k",
    api_type=OpenaiApiType.AzureOpenAI,  
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

text_embedder = OpenAIEmbedding(
    api_key=api_key,
    api_base= "https://azureopenaimark3.openai.azure.com/",
    api_version= "2024-02-15-preview",
    api_type=OpenaiApiType.AzureOpenAI,
    model=embedding_model,
    deployment_name= "embedding-ada-v2",
    max_retries=20,
)

context_builder = LocalSearchMixedContext(
    community_reports=reports,
    text_units=text_units,
    entities=entities,
    relationships=relationships,
    #covariates=covariates,
    entity_text_embeddings=description_embedding_store,
    embedding_vectorstore_key=EntityVectorStoreKey.ID,  # if the vectorstore uses entity title as ids, set this to EntityVectorStoreKey.TITLE
    text_embedder=text_embedder,
    token_encoder=token_encoder,
)

local_context_params = {
    "text_unit_prop": 0.5,
    "community_prop": 0.1,
    "conversation_history_max_turns": 5,
    "conversation_history_user_turns_only": True,
    "top_k_mapped_entities": 10,
    "top_k_relationships": 10,
    "include_entity_rank": True,
    "include_relationship_weight": True,
    "include_community_rank": False,
    "return_candidate_context": False,
    "embedding_vectorstore_key": EntityVectorStoreKey.ID,  # set this to EntityVectorStoreKey.TITLE if the vectorstore uses entity title as ids
    "max_tokens": 1_000,
    "requests_per_minute": 1_000  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 5000)
}

llm_params = {
    "max_tokens": 1_000,  # change this based on the token limit you have on your model (if you are using a model with 8k limit, a good setting could be 1000=1500)
    "temperature": 0.0,
}

search_engine = LocalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    llm_params=llm_params,
    context_builder_params=local_context_params,
    response_type="multiple paragraphs",  # free form text describing the response type and format, can be anything, e.g. prioritized list, single paragraph, multiple paragraphs, multiple-page report
)

# %% [markdown]
# Probamos con esta consulta para evaluar el desempeño del sistema. Nos hubiera gustado experimentar modificando y ajustando los parámetros—como la proporción de contribución de cada fuente en el contexto o el límite de tokens—para optimizar la configuración. Sin embargo, debido a que cada consulta a la API de OpenAI tiene un costo asociado, no ha sido posible realizar pruebas extensivas con diferentes combinaciones de parámetros.

# %%
result = await search_engine.asearch("Tell me about Scrooge")
print(result.response)
# Out:
# Scrooge is a prominent entity in the data set, appearing in various forms and with a significant number of relationships. The entity "Scrooge" has the highest number of relationships, with a total of 123 [Data: Entities (33)]. This suggests that Scrooge is a central figure or character in the context of the data.
#
# There are also other entities that seem to be related to Scrooge. "Ebenezer Scrooge" has 12 relationships [Data: Entities (20)], "Master Scrooge" has 4 relationships [Data: Entities (105)], and "Uncle Scrooge" has 2 relationships [Data: Entities (174)]. This could indicate that these are different titles or roles that Scrooge has, or they could be different characters entirely.
#
# There are also entities that seem to be related to Scrooge in a familial or professional context. "Mr. Scrooge's Nephew" has 3 relationships [Data: Entities (203)], and "Scrooge's Nephew" has 4 relationships [Data: Entities (43)]. This suggests that Scrooge has a nephew who is also a significant character. "Scrooge's Counting-House" is another entity with 1 relationship [Data: Entities (44)], which could indicate that Scrooge is a businessman or has some sort of professional role.
#
# In conclusion, Scrooge appears to be a central character with various roles and relationships. He seems to have a nephew and a professional establishment, suggesting a complex character with a significant role in his context. However, without more specific data or context, it's difficult to provide a more detailed analysis.
